# %% [markdown]
# This notebook is adapted from https://github.com/DrKenReid/VAE-for-Molecule-Discovery.git

# %% [markdown]
# # Variational Autoencoder for Molecule Discovery
#
# This tutorial demonstrates how to use a Variational Autoencoder (VAE) for generating novel molecular structures. This approach is particularly useful in drug discovery, where we aim to generate new potential drug candidates.
#
# **Click runtime -> change runtime type -> GPU**
#
# 1. Setting Up the Environment:
# We'll use PyTorch for deep learning and RDKit for cheminformatics. PyTorch is chosen for its flexibility and ease of use, while RDKit is an industry-standard tool for handling molecular data.

# %%
# !pip install rdkit torch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from rdkit import Chem
import pandas as pd
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.3.5-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading rdkit-2025.3.5-cp311-cp311-manylinux_2_28_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 45.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.0 MB/s eta 0:00:00
# Installing collected packages: rdkit, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 rdkit-2025.3.5

# %% [markdown]
# 2. Data Preparation: We use the QM9 dataset, a standard benchmark in molecular machine learning. It contains about 134,000 small organic molecules.

# %%
def load_qm9_dataset(url: str = "https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/qm9.csv") -> pd.DataFrame:
    """
    Download and load the QM9 dataset.

    This function downloads the QM9 dataset from the specified URL using wget,
    then loads it into a pandas DataFrame. It extracts the SMILES strings
    from the DataFrame for further processing.

    Args:
        url (str): The URL of the QM9 dataset CSV file.
                   Defaults to the DeepChem hosted QM9 dataset.

    Returns:
        pd.DataFrame: The loaded QM9 dataset as a pandas DataFrame.

    Raises:
        subprocess.CalledProcessError: If the wget command fails.
        pd.errors.EmptyDataError: If the CSV file is empty or cannot be read.

    Note:
        This function requires wget to be installed and accessible in the system path.
        It saves the downloaded file as 'qm9.csv' in the current directory.
    """
    import subprocess

    # Download the QM9 dataset
    try:
        subprocess.run(['wget', url], check=True)
        print(f"Dataset downloaded successfully from {url}")
    except subprocess.CalledProcessError as e:
        print(f"Failed to download dataset: {e}")
        raise

    # Load the dataset
    try:
        df = pd.read_csv('qm9.csv')
        print(f"Loaded QM9 dataset with {len(df)} entries")
        return df
    except pd.errors.EmptyDataError:
        print("The CSV file is empty or could not be read")
        raise

# go
df = load_qm9_dataset()
smiles_list = df['smiles'].tolist()
print(f"Extracted {len(smiles_list)} SMILES strings from the dataset")
# Out:
# Dataset downloaded successfully from https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/qm9.csv
# Loaded QM9 dataset with 133885 entries
# Extracted 133885 SMILES strings from the dataset

# %% [markdown]
# Creating a Vocabulary: we create a vocabulary from the SMILES strings. This allows us to represent molecules as sequences of tokens that our model can process.

# %%
from typing import List, Dict

def create_vocabulary(smiles_list: List[str]) -> Dict[str, int]:
    """
    Create a vocabulary mapping from SMILES characters to integer indices.

    This function generates a vocabulary dictionary from a list of SMILES strings.
    It includes special tokens for start ('<') and end ('>') of sequences, and
    assigns a unique integer index to each unique character found in the SMILES strings.

    Args:
        smiles_list (List[str]): A list of SMILES strings to create the vocabulary from.

    Returns:
        Dict[str, int]: A dictionary mapping characters to their corresponding integer indices.

    Example:
        >>> smiles_list = ['CC(=O)OC1=CC=CC=C1C(=O)O', 'C1=CC=C(C=C1)C(=O)O']
        >>> vocab = create_vocabulary(smiles_list)
        >>> print(vocab)
        {'<': 0, '>': 1, 'C': 2, '(': 3, '=': 4, 'O': 5, ')': 6, '1': 7}

    Note:
        The returned vocabulary will always include '<' and '>' as the first two entries,
        representing start and end tokens respectively.
    """
    vocab = {'<': 0, '>': 1}  # Start and end tokens
    for smiles in smiles_list:
        for char in smiles:
            if char not in vocab:
                vocab[char] = len(vocab)
    return vocab

vocab = create_vocabulary(smiles_list)

# %% [markdown]
# 3. Dataset Creation: We create a custom dataset that converts SMILES strings into one-hot encoded tensors. This representation allows the model to process the molecular data efficiently.

# %%
class SMILESDataset(Dataset):
    """
    A PyTorch Dataset for SMILES strings.

    This dataset converts SMILES strings into one-hot encoded tensors based on a given vocabulary.
    It adds start ('<') and end ('>') tokens to each SMILES string before encoding.

    Attributes:
        smiles_list (List[str]): A list of SMILES strings.
        vocab (Dict[str, int]): A dictionary mapping characters to their corresponding indices.
        vocab_size (int): The size of the vocabulary.

    """

    def __init__(self, smiles_list: List[str], vocab: Dict[str, int], max_length: int = 100):
        """
        Initialize the SMILESDataset.

        Args:
            smiles_list (List[str]): A list of SMILES strings to be encoded.
            vocab (Dict[str, int]): A dictionary mapping characters to their corresponding indices.
        """
        self.smiles_list = smiles_list
        self.vocab = vocab
        self.vocab_size = len(vocab)
        self.max_length = max_length

    def __len__(self) -> int:
        """
        Get the number of items in the dataset.

        Returns:
            int: The number of SMILES strings in the dataset.
        """
        return len(self.smiles_list)

    def __getitem__(self, idx: int) -> torch.Tensor:
        """
        Get a one-hot encoded tensor for a SMILES string at the given index.

        Args:
            idx (int): The index of the SMILES string to retrieve.

        Returns:
            torch.Tensor: A one-hot encoded tensor representing the SMILES string.
                          Shape: (len(smiles), vocab_size)

        Note:
            Start ('<') and end ('>') tokens are added to the SMILES string before encoding.
            If a character in the SMILES string is not in the vocabulary, it is encoded as the first token (index 0).
        """

        smiles = '<' + self.smiles_list[idx] + '>'
        encoded = torch.zeros(self.max_length, self.vocab_size)
        for i, c in enumerate(smiles[:self.max_length]):
            encoded[i, self.vocab.get(c, 0)] = 1
        return encoded

# %% [markdown]
# 4. Model Architecture: We use a VAE architecture, which consists of an encoder, a latent space, and a decoder. This architecture is chosen because it can learn a compact representation of the input data and generate new samples from this representation.

# %%
class VAE(nn.Module):
    """
    Variational Autoencoder (VAE) for SMILES string generation.

    This VAE encodes SMILES strings into a latent space and decodes latent
    vectors back into SMILES strings. It uses GRU layers for both encoding and decoding.

    Attributes:
        vocab_size (int): Size of the SMILES vocabulary.
        hidden_dim (int): Dimension of the hidden state in GRU layers.
        latent_dim (int): Dimension of the latent space.
        encoder (nn.GRU): GRU layer for encoding input sequences.
        fc_mu (nn.Linear): Fully connected layer for mean of latent space.
        fc_logvar (nn.Linear): Fully connected layer for log variance of latent space.
        decoder (nn.GRU): GRU layer for decoding latent vectors.
        fc_output (nn.Linear): Fully connected layer for output probabilities.
    """

    def __init__(self, vocab_size: int, hidden_dim: int, latent_dim: int):
        """
        Initialize the VAE model.

        Args:
            vocab_size (int): Size of the SMILES vocabulary.
            hidden_dim (int): Dimension of the hidden state in GRU layers.
            latent_dim (int): Dimension of the latent space.
        """
        super(VAE, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_dim = hidden_dim
        self.latent_dim = latent_dim

        self.encoder = nn.GRU(vocab_size, hidden_dim, batch_first=True)
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)

        self.decoder = nn.GRU(vocab_size + latent_dim, hidden_dim, batch_first=True)
        self.fc_output = nn.Linear(hidden_dim, vocab_size)

    def encode(self, x: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor]:
        """
        Encode input sequences into the latent space.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, seq_len, vocab_size).

        Returns:
            tuple[torch.Tensor, torch.Tensor]: Mean and log variance of the latent space distribution.
        """
        _, h = self.encoder(x)
        h = h.squeeze(0)
        return self.fc_mu(h), self.fc_logvar(h)

    def reparameterize(self, mu: torch.Tensor, logvar: torch.Tensor) -> torch.Tensor:
        """
        Perform the reparameterization trick to sample from the latent space.

        Args:
            mu (torch.Tensor): Mean of the latent space distribution.
            logvar (torch.Tensor): Log variance of the latent space distribution.

        Returns:
            torch.Tensor: Sampled latent vector.
        """
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z: torch.Tensor, max_length: int) -> torch.Tensor:
        """
        Decode latent vectors into sequences.

        Args:
            z (torch.Tensor): Latent vector of shape (batch_size, latent_dim).
            max_length (int): Maximum length of the generated sequence.

        Returns:
            torch.Tensor: Decoded sequences of shape (batch_size, max_length, vocab_size).
        """
        batch_size = z.size(0)
        h = torch.zeros(1, batch_size, self.hidden_dim).to(z.device)
        x = torch.zeros(batch_size, 1, self.vocab_size).to(z.device)
        outputs = []

        for _ in range(max_length):
            z_input = z.unsqueeze(1).repeat(1, 1, 1)
            decoder_input = torch.cat([x, z_input], dim=2)
            output, h = self.decoder(decoder_input, h)
            output = self.fc_output(output)
            outputs.append(output)
            x = torch.softmax(output, dim=-1)

        return torch.cat(outputs, dim=1)

    def forward(self, x: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """
        Forward pass through the VAE.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, seq_len, vocab_size).

        Returns:
            tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
                - Reconstructed input of shape (batch_size, seq_len, vocab_size)
                - Mean of the latent space distribution
                - Log variance of the latent space distribution
        """
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z, x.size(1)), mu, logvar

# %% [markdown]
# 5. Training the Model: We train the model using a combination of reconstruction loss (binary [cross-entropy](https://en.wikipedia.org/wiki/Cross-entropy)) and [KL divergence](https://en.wikipedia.org/wiki/Kullback%E2%80%93Leibler_divergence).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import os

def loss_function(recon_x: torch.Tensor, x: torch.Tensor, mu: torch.Tensor, logvar: torch.Tensor) -> torch.Tensor:
    BCE = nn.functional.binary_cross_entropy_with_logits(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + 0.1 * KLD

def custom_collate(batch):
    return torch.stack(batch)

# Determine the number of workers based on system resources
num_workers = min(2, os.cpu_count() or 1)

# DataLoader setup
batch_size = 128
dataset = SMILESDataset(smiles_list, vocab, max_length=100)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=custom_collate,
                        num_workers=num_workers, pin_memory=True)

# Model initialization
vocab_size = len(vocab)
hidden_dim = 256
latent_dim = 64

model = VAE(vocab_size, hidden_dim, latent_dim)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Optimizer initialization
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# Learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# Initialize mixed precision training if CUDA is available
use_amp = torch.cuda.is_available()
scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

# Training loop
num_epochs = 3
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for batch in dataloader:
        batch = batch.to(device, non_blocking=True)
        optimizer.zero_grad(set_to_none=True)

        # Use autocast only if CUDA is available
        with torch.cuda.amp.autocast(enabled=use_amp):
            recon_batch, mu, logvar = model(batch)
            loss = loss_function(recon_batch, batch, mu, logvar)

        # Backward pass and optimization with gradient scaling if CUDA is available
        if use_amp:
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            loss.backward()
            optimizer.step()

        total_loss += loss.item()

    # Print epoch results
    avg_loss = total_loss / len(dataloader.dataset)
    print(f'Epoch {epoch+1}, Average Loss: {avg_loss:.4f}')

    # Update learning rate
    scheduler.step(avg_loss)

    # Print current learning rate
    current_lr = optimizer.param_groups[0]['lr']
    print(f'Current learning rate: {current_lr:.6f}')

print("Training complete!")
# Out:
# /tmp/ipython-input-2996218216.py:41: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# /tmp/ipython-input-2996218216.py:53: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Epoch 1, Average Loss: 94.2261
# Current learning rate: 0.001000
# Epoch 2, Average Loss: 50.1733
# Current learning rate: 0.001000
# Epoch 3, Average Loss: 47.1990
# Current learning rate: 0.001000
# Training complete!

# %% [markdown]
# 6. Generating New Molecules: After training, we use the decoder to generate new molecular structures.

# %%
def generate_smiles(model: torch.nn.Module, vocab: Dict[str, int], num_samples: int = 10, max_length: int = 100) -> List[str]:
    """
    Generate SMILES strings using the trained VAE model.

    This function generates a specified number of SMILES strings by sampling from the
    latent space and decoding the samples using the VAE's decoder.

    Args:
        model (torch.nn.Module): The trained VAE model.
        vocab (Dict[str, int]): The vocabulary mapping characters to indices.
        num_samples (int, optional): Number of SMILES strings to generate. Defaults to 10.
        max_length (int, optional): Maximum length of generated SMILES strings. Defaults to 100.

    Returns:
        List[str]: A list of generated SMILES strings.

    Note:
        - The function uses greedy decoding (taking the most probable character at each step).
        - Generation stops when the end token '>' is produced or max_length is reached.
        - Invalid characters (not in vocabulary) are ignored in the output.
    """
    model.eval()  # Set the model to evaluation mode
    inv_vocab = {v: k for k, v in vocab.items()}  # Invert vocabulary for decoding
    generated_smiles = []
    device = next(model.parameters()).device  # Get the device of the model

    with torch.no_grad():  # Disable gradient computation
        for _ in range(num_samples):
            # Sample from the latent space
            z = torch.randn(1, model.latent_dim).to(device)
            x = torch.zeros(1, 1, model.vocab_size).to(device)
            x[0, 0, vocab['<']] = 1  # Start token
            h = torch.zeros(1, 1, model.hidden_dim).to(device)

            smiles = ''
            for _ in range(max_length):
                z_input = z.unsqueeze(1)
                decoder_input = torch.cat([x, z_input], dim=2)
                output, h = model.decoder(decoder_input, h)
                output = model.fc_output(output)

                probs = torch.softmax(output.squeeze(0), dim=-1)
                next_char = torch.multinomial(probs, 1).item()

                if next_char == vocab['>']:  # End token
                    break

                smiles += inv_vocab.get(next_char, '')
                x = torch.zeros(1, 1, model.vocab_size).to(device)
                x[0, 0, next_char] = 1

            generated_smiles.append(smiles)

    return generated_smiles

# Generate and print some SMILES strings
num_samples = 10000
generated_smiles = generate_smiles(model, vocab, num_samples=num_samples)
print(f"Generated {num_samples} SMILES strings:")
for i, smiles in enumerate(generated_smiles, 1):
    print(f"{i}. {smiles}")
# Out:
# Generated 10000 SMILES strings:
# 1. ]
# 2. H##4n=2]111
# 3. NNCCCCCCC2C
# 4. CC#CCC1CNO2O1=
# 5. c)H(]
# 6. <CC==(N#==C1#
# 7. <CC11CC21O
# 8. <CCC2CCCC(CCCC3NC
# 9. <CC(CC1CCC1)2CC1C
# 10. [-
# 11. <CC(CCCNCCCCCO1
# 12. )
# 13. <CCOCCC21C12=1121#
# 14. <CCC1(CCN=CCCCCN3
# 15. cO5NC
# 16. ]4CO=#N1
# 17. nCC11NN12
# 18. 2+C1CC=1C)C)#1
# 19. <CC1CCCC)(==1)#
# 20. =<N1N==N#CO-NN]OO1
# 21. []o]-H555c-n]c4-cnc(H[n3HconF[45(5]c+5n4]5-o+)5-H[cnno-]Hnn]4cFo[Hcc4-+-cn4c5][]5[=5oc4n55cHonc[[Fc
# 22. cOO1)
# 23. <CCCCCCCCCOC12
# 24. <CC1C2CCNCC)1
# 25. (+#C3
# 26. <CC11COC()CCO)C
# 27. <NCC1O3=C1
# 28. <CCC11ONCCCC2C
# 29. C#=11112
# 30. 1-CC#CCC=CCN=C1
# 31. #OCCCO2=C
# 32. <OCCC1CNCCO#OO34
# 33. <CCCCCCC11)2(CC2)3
# 34. 2[-COON2
# 35. <CCC121CC#=CCC)C
# 36. -O3CF2=-#O
# 37.
# 38. <CC(C=C(CCCCCC#
# 39. <C#1(2C4))=()=
# 40. 1CN1#CC)=12
# 41. [CCCCCCCCCNCC1
# 42. <C1C(21=(12no=)1)CO
# 43. HnN]O#
# 44. 2
# 45. cNC)=2CCOC
# 46. NH](
# 47. cCC=CC1C1)#OCOCO
# 48. <CC(1C(C)((CC)O
# 49. =4o+###O
# 50. <CC11On)1221)N=1N
# 51. <CC2CCC22CCCC=C1#1CN
# 52. <CC21CC4C1C1]1
# 53. <CN11C1O=NC2
# 54. <O=12CCONC))C2=N
# 55. <CCC(()O1C)N1
# 56. <CC1O1=2C1111C1)
# 57. O3((NO#CC#
# 58. <CC1CC(#CC(1NCCC
# 59. <CCCCCNCC(OC1CC3C
# 60.
# 61. 5CC3O(C
# 62. 1#F]+(ocon5=<)(5cc-[[[5oc+---5n[<<o[n]ccoH42<<5)55o[]<O2[<45<<-]o5H[[<45F-oH<5<<n<-n5]o<F[c4<5H5<<]5
# 63. 3HC1C2)CC)CO1)1#1
# 64. <CC1C)2CCCCCC(
# 65. <CCC=CCC)C1CCO22
# 66. #C4)=o21
# 67. <CC1CCC1(CCC2C)
# 68. <CC(1)CC=C=1)O)C=O
# 69. <CCC=(CC(CC=CNC3
# 70. =CC(O22CCN#C#C11
# 71. -OC=1CCN1#
# 72. --[
# 73. 113o#1#
# 74. =N111C#)12
# 75. 2(-3]cn#++#-<3<O+<#=<]3#[NN1#12O
# 76. -25)CC(+o4CC25o(-c(<(<--(Fo]NN5=15+5<-H]H<<4<<5<<H<<(5-<n5<5<(3<+c<5<<(<+o-5)+<<+(<<F5<<<<<<<o[<F(O<
# 77. 5CC11O(22
# 78. 1<F=#O
# 79. oO+NC#=1O11
# 80. N1(1(C
# 81. )CCC#CC1OO(N
# 82. <
# 83. <CCCCCCC)1COC1C2
# 84. <CC(3CCO1CC12C)#=
# 85. c[11N12O==1
# 86. -CCNOCC2C1
# 87. <CCO(CCN2CC1N3)2
# 88. <OCCN1CCCO)CCC)
# 89. <CC11CCOOCO
# 90. 3FCCC12C1OOC)#1C
# 91. +2((OCC1
# 92. nN]]c[[-4cH##[NON32
# 93. HFn[3#OO)3O4
# 94. =C)CCC1C)(CCCC21=1
# 95.
# 96. oCC#N2(CN=11C
# 97. +]O]CO)C+O
# 98. 4F5H-
# 99. <#CC(OC)CC)((C1
# 100. <C11C1C)(N=32C)#
# 101. 5CC1O==CN
# 102. <3C1CCCCCC(2
# 103. <CCCC2F2CNO
# 104. <C#1=(C1CCC#1
# 105. <CCCCOC)1CCCCC#2
# 106. <OC1CCCNCN#1)C1O
# 107. <CC1C1(CC2C1)))
# 108. =-4
# 109. 5
# 110. 2OOCCCCC1#12
# 111. n5F2[-o]#+F+5o(<-+54
# 112. 2
# 113. [<CC1C=NCN2
# 114. <CNCCCCC==(CNOC2
# 115. cCHnH((-o(+o-(n55(#on<
# 116. C=O1C2CO
# 117. +
# 118. CCN==2
# 119. 5FF1N3C
# 120. )H[n#O1
# 121. O=C1C
# 122. <CCC=22)C2C2=C)3
# 123. <CO11(C1(CO112C
# 124. <CCC1NCCCCO22132
# 125. CCCC2CC(CCCC1C)O
# 126. OH=[+CO
# 127. <CCO2=1OO=CC2CC1
# 128. o3O+C1C1NN#
# 129. <CNCO(CC2NCC1C12
# 130. 4]3-
# 131. OCCCCCCC1COCC
# 132. HN(C21C1C5C==C=O
# 133. 1<C4O=12NOHO=
# 134. <CC2((COCC1#)=C1N
# 135. ON]1N3)OC2C)=22
# 136. O)2+N[]
# 137. NNN+CC()C1CCCC
# 138. nFOF<(HH+F4[(+C(<C<<<+)+(+5<<<5<<<<<<<<
# 139. <CCCC22CCC1(2OCCO
# 140. 2]HO#
# 141. <CC2(2CO=C1CC)31=
# 142. <OCCCO1(CNC=CN
# 143. +N112OCC#1=
# 144. C
# 145. 4CCCCCC=C
# 146. <CCCC2O21CCCC
# 147. ]#C1-O1=
# 148. <CCCCCCOOO=1CCC12#
# 149. <1(COOC)2=1#=)
# 150. F1-1FFO55o]+)<3=+c-nC4+<<<#3nc1<-<3=<<<<O<[c4+<]n-4)<(c<51<#5<c3<<<][<(#Coc5-+o-oH<+55)+[<<)C<(++]2c
# 151. <CC1CCCOOC11C2O
# 152. <CCCC1CCCNCOC1CCC2
# 153. 4N(C(CCCC)1O
# 154. [OCC12OC(OCC2)1C
# 155. c((2#H
# 156.
# 157. <CC(12CCCCN)C222C
# 158. oo1CCC1+C122
# 159. )##3OO#OOO
# 160. c)-
# 161. C3CC()CC)111O)
# 162. <CCCOOCCC#C11C1
# 163. cCCC1C1(2CNO2=
# 164. ]-
# 165. <OC=(C)31=C=O1C2
# 166. OCC=123CCC3C)=O
# 167. 4)#CC=C12CC=
# 168. <CCCCCC(C3)))CC2
# 169. <CC12C)C2O=1CC
# 170. OOOCC#OC2=CO
# 171. <CC=CCOCC)O
# 172. Fc(OCCC22
# 173. <CCCC(=C2CCONC2
# 174. oC1((OCCO)13(31[NO1CN
# 175. <CCCC2OC2CCCCC#
# 176. <CCC11C(CC#1CCC
# 177. 31CC2C1CC=N#
# 178. OCCCC1C))CN
# 179. <5NCO=C=N==-==#==-1ON2O2OO+CO#44#O[NO3NNO1
# 180. <CCC11=1C=C=C4N1=
# 181. <CC11C2(CCCOCCCC
# 182. 1O51C22CCC11
# 183. <CC(C(2C2=CC#CO=
# 184. <CC1CCN3C1)13CC113
# 185. [C#H+FC2
# 186. Fc#CCONCNO11#O)
# 187. 3CC1NO22O
# 188. <CC(2)22CCCCC)N2CC=
# 189. <CC1O(CCC2#O31
# 190. <CC1C4CN21)CCCO3
# 191. <OC1112C#21OCC
# 192. 4o#1CC((C((CCCC(=C[1=
# 193. -(H3F3-2=+1#F=45[(-c-o1n-3c3-3<5]5+--<5
# 194. <CC1C2C(OCC)1#(C2OO
# 195. o2o
# 196. =<+]]4o3cn<cnn<ccH<c<-c<34<<n<c<+<n[]cn[c<<<(<(c<(H<]<)H<<HnoHon-H<<Hn3+<+cH2c<<nc[1c<<<<n<<+(<5cHHc
# 197. <nc1=12C2CO
# 198. 5=nNC3)=CN
# 199. 4OHOO1=1NC
# 200. <CC11COC)Co1)O)
# 201. 2o[4H-+o[OO]#
# 202. c-CCC=OC1
# 203. F1)C11=1CCC#
# 204. #
# 205. O=nFN=OO#2N=#-F=ONN2#2
# 206. HH][
# 207. oHn()+)]o(53]33n3-(2Fc]cc5O+c+1]n[<
# 208. OC1211
# 209. F111COC3)O
# 210. <CC1CCCCCOC()C1
# 211. <((=32
# 212. c-35H55++]o3(5+n4nHo([[on[CcN+]5ccH323]o[55]5H+)3o-4H#H
# 213. [nF=O
# 214. <CC1cnC1C(C1)NO
# 215. <CC11C=C=ONC#C2
# 216. <#C1O)CCN11C
# 217. <CCC2C2NCCCCN1)2OOO
# 218. 5CCN1CC=3C2O2
# 219. COCC11)CCN
# 220. n#H3n4-c)c+]-]FFo]F5[+3+54H5[+]o-]45coNo5nc2(Hc5(35c[[(Hon]nc+-c5H+n5H4n5-5[o]2+1<4c-+-c-5(5-)--5+-]
# 221. HCC1CCC11COC)N22
# 222. <C=C1CCC=OCNCCCC1O2
# 223. <CCC)C2NC=1)C)=2
# 224. <CC12ON=C3C)CCCO
# 225. <CO1CC2COCCC1O=
# 226. OCCC=CC1CCCCC3CO22
# 227. <CC(CCCC1(1CCC=
# 228. C
# 229. ]]o-3O(]H5]]+(cc35+nO44cC545Co]ocFcc[c5cn+noc
# 230. FO1#12=
# 231. N=44##111O)C=
# 232.
# 233. cCNCC11CN1C=))
# 234. <CCC1C)=C11CC32OC312
# 235. <CN((OC(CN()CCNN
# 236. <CC#NCOCC(CCOOC
# 237. <CCCC)C=CCCCONC3
# 238. <CCC(NC2CCCCCCN
# 239. CCC
# 240. H#CCCCC1NOC3
# 241. <CCCC(NCOCN(CCC==
# 242. <=1OCCC2C=CCN1)
# 243. O(CC=CCNN#N231
# 244. cO1][2nc4+<<<+[o<2<4nc<5<+5<+cF<<<(<<45<<5<3<)<<<oC5H<2-<Cn4+H31<<<<N<<<Ho42<<<<<<<c+cc-<<<<<<CH<[<-
# 245. <C#11OCC)CC1C
# 246. <ON1#(nC11CN)N2
# 247. occnNc+nnFFnon5H+]]Fc55c[+]5<)555[n-<+<<on))[oc]<+[O<([c]c<3<<<o<+<<-c45<)cF<+nHc<c<<<5<4(#5<c+HocH)
# 248. 2C=CCC2COC11CN2
# 249. O2#OCC2OC
# 250. ()53n1#=1C
# 251. <C11)CONC(=NCCC=O
# 252. <FCCC(CCCCO)1)1
# 253. <cO1(C=3HC)CO
# 254. o
# 255. <CCCC2OCOCN11CN#
# 256. C3C1)2CCCCC2
# 257. o)CCC)1(=1=FN
# 258. =+
# 259. <CCC1C)CCC(3)O1O2
# 260. 3(COCC=CCCC1O#N
# 261. <CCCC=O=C1CCN
# 262. <CCC(CCCC1(C=OO
# 263. FFCC12)()2OO
# 264. <CC1CCCCCC2C2)#2
# 265. 2=#(CN
# 266. oO1CCC(C)=)
# 267. F#-]OO#ONNOOC=4+OCO=
# 268. <CCCH113CCNCNN
# 269. #]=1COC1
# 270. 232#5o#O4[(=N1
# 271. 5)C1)OC2O2NO
# 272. <C1OCCN2OCONO=C1C
# 273. c(]H[[cc5-1
# 274. 1)#1O1C#2
# 275. #CC=C)1C1OC)
# 276. 22NON
# 277. cCN(CNCCC11CO2N
# 278. oC1CC(N1)1((3=
# 279. FCC1NCCCC)2CCNCCC2C
# 280. <C#C=CC)CN2C1CNC
# 281. [=OOOC1OO
# 282. ]111C=CNC11#)3
# 283. )CCC(NC=CCCC)CO3
# 284. )#C1CC(CC))C
# 285. OO1=1(O2C)11
# 286. OFOOC#411#
# 287. 4Cn3
# 288. 2[C1C(CC2N1241
# 289. F3F==CC
# 290. <CNCCOCC22C2C
# 291.
# 292. <OCCCCN2)CC)1CC)C1O1
# 293. +Nnn[NC1#1-ONnoO
# 294. <=C1CCOC11OCC(2
# 295. N5cn
# 296. <CCC1CCCCCO1==OO
# 297. <CCC2=(COOO2CN1O)1
# 298. C+NC#H=412(H1o-+=<oc(<<<<C<<<#<<<<<<2N)=5(=4<+O<<+<5<C5[=<<2<<<<4o<2<<C<<-CO#<<O<F+<n<-<C<=<=<c<=<C4
# 299. FF1no(-<2()#(
# 300. <OC2(C3CC))NONCCN
# 301. <#1(C)CCC1CCCC))
# 302. -C+33=OO
# 303. 225CNC1OO#1N
# 304. <CC#(C1211C(1CC
# 305. c-n[H[o+cc2o235F]ncF(c[C+5+]5o41o-o4+]]C)c]4n-FoN+c4[F[nc[
# 306. 4nNoF-<]cN#CC1COC3N2C=12
# 307. 5C-+n3<3<o<<<<<<<<<<-o<C<=2((-)<15<<O<<<)<<<<+5<<<N<<<[#C112)N2=H41[]o<<<<<<<<<<<<<<<<<<<]c<c<nCF3F(
# 308. #)H5=[c-++
# 309. n]cnHc53-o3o+n]-c-o54o[c
# 310. 5-5n332]<<<<<<<F<<H)<<<+o<<ccc#<<<5<<=<C<<<<<<n<<<<<5<<<<c<<5cn<<<<<<O<<<<<]+-5<<<H<<3o<<<<<<<<<<<<<
# 311. CCC)#C(1CNO
# 312. <OCOCCCC=22OCCCC11
# 313. ccC#CC2N)=2232#C1#=
# 314. +CC=CCOC1C()C1C
# 315. <C=1CO)(C==C)C2
# 316. <NC(=CCC)11==C2
# 317. c3=CCC=CN
# 318. F)
# 319. )]C(C1)NCCOCO)
# 320. <C111CC(#==CCC
# 321. ]n-H3nOC#
# 322. CCC(C))
# 323. C4CC1CC#2=C1O
# 324. ()
# 325. (C1OCN1C))C1
# 326. ON1(1C2C112O
# 327. NC#1C12C1=O23
# 328. <+51#=C)=C#
# 329. <CCC12COC1OO1
# 330. <CC1(C21OCC1C1O11
# 331. 1CCCCCCOCCC2)=2
# 332. <NCCCCC=2OCO=
# 333. <CCCC1C5C=C11
# 334. ocn4[n5#O4
# 335. ONC34=1CN[co+31)-#55#O3+c[4o)+#Hn#cc+-#5F5FHn]4HNC-45C([HcC4c13#442(c)5n3+(Hc<+o++n-o5n)5(n[=[5cH55C
# 336. [[=]cc-ooH3C5[(c2+45<o<-2]<<Ho4]C55+<5+Nn[-++]n+-<+4<-F<<<<5c-<4-HcHc5o5F<c-FH5[(c(c555<==35c-)c5]-c
# 337. )-4#C3CC
# 338. H(
# 339. =5=((55H#=(]o(4=45+1(o+5#51no]51-[]oc5HF)5H35-5#5=]((5-n53#c45+([[nc)]<5-1+2o(#1o[555F+Fo)O4oF455on3
# 340. <CC1(CCCCC1C12=CC
# 341. <CCC121C2)CC3N##F
# 342. <OC1C2C1CCC
# 343. <CC1O))1CCC=O2
# 344. <CCCC(C(1)2C1CC)
# 345. -FO1#C1C23#1
# 346. )#(ON1O
# 347. <#CCCCCC(CCCO(N2CN1
# 348. <NCC1CO=N2
# 349. 2=F1)5O(=1c)-H-(54NCc513]Hn(42(ccH5H-)15o3oHo-H+F(n4Nc54+n2#2n]4[(+]o5#](5FH5+4(443+([F<oHn([-n2c5Nc
# 350. <CO#C11#O2
# 351. <CC#1CC()O1=C1=1
# 352. Hnc3n-ncc#=
# 353.
# 354. <COCCCCCC)C(2C1O)C
# 355.
# 356. <CC1CCC1CCCCC)#)
# 357. <OC1C2(4CC(CC1)CC2
# 358. <CCCCCC())C1O2CO1
# 359. <C11C(1NCCNCCCC)=O1
# 360. <CC1(3CCO(N3OCO
# 361. O]C(N)CC=OO=1
# 362. c)]
# 363. <CC((C)2C1)(c1N)
# 364. o+4n+(N]-
# 365. <CO1COCCC1C=CC)2
# 366. <C2CCC1C(C()1=)C
# 367. <CC#CC1CCCNC(=(O=N
# 368. <cCCCCC=C21)2NO
# 369. <C1nc
# 370. 3
# 371. oo
# 372. <C#C12)1NC=21CC2
# 373. <CCCCCC2CC11CC#2
# 374. <CC1C3CC1)2C2C=2CN3
# 375. NHcCcC=O=)
# 376. )]()-(1=1O
# 377. 4CCCCC1CCCC212
# 378. 1)F3-cN[oc[n-n[Hcc+[4
# 379. C)N(c42<<o<<<<<<<<<<<<<5+No<<<<<<<<3cn+C<1-<#<<<o<<<==2cC
# 380. <CCCCCC11#=C1O32
# 381. <CC122CCC12#1C1CCO
# 382. N(C1CCCCO
# 383. <CCCO(N(CC111C12O
# 384. <CC11CC#(CC+1C2CNO)
# 385. 3CCCCCC(CC=(1C1)O
# 386. OOCOCO=O2OOOO
# 387. <NCC11OCCC))
# 388. OCC1CCOCCCC1
# 389. 5(o13nF[nN=OC1(CCC11O(C1CC#C#C))33O1C
# 390. +H5=COCNN
# 391. <CC11(1CC1OCN)C
# 392. 1-1--O1O
# 393. <CC1(Cn=)4NC1)23
# 394. <CCCC(C2CCCC2O
# 395. <CO112C(CCCCC(1C
# 396. <CCCC22CC=12O)
# 397. <[C12CC)o[NCOH
# 398. cCC=CC)CCOOO11
# 399. C=[OC(1O
# 400. <C#CCNCCOC=CCC
# 401. -C1()C2C1OC)CCO1NO2
# 402. ]=1=OOC2CC
# 403. 2=CC=F=-35F(2-o55<<<<<<<<<<<<<-<N3([-]-+<5-]<5<<5H<+=<<<<5CCC(FC<5<1<<<<<<<#<ON]<<<<3<c<<n(<<<-Cn<<<
# 404. F1H#
# 405.
# 406. [NCC11OOCCO1CC#
# 407. F4(]ooH+]oon)onon(H4+3c]5cn+
# 408. <NCCC1O2CO1=N3N
# 409. oC-n3+n-4O3c5CoH3[c[[cc(H--n<o4-H(+3c<oc[5[]+-H]o[)55[(n-3o4(4[)(1c-c4-ON<[]2]o55O]Hcc=<5)+3oc<]Hc+n
# 410. +NCCC=C1CC2C)1
# 411. )NC1(C==3111232
# 412. #5
# 413. <C=(C=C1C=3N)NCCN2=
# 414. -=c#5n2535nc4n#]HFF[-<[+Hc<[+c+]5H<ncc]
# 415. NOCCCC(2COCCC
# 416. <CCC1)(=C=C1CC21=
# 417. <CCO2CCCCC1CCNO
# 418. oCCC(C2CCCO2NN2
# 419. <CC1C)C(C(C#=C
# 420. [2OCCCCCCOCN22
# 421. <C11CC(CC2NCC1=O1
# 422. <OCCCCCCOCC=3C
# 423. -
# 424. 1N2COC=CN
# 425. C=O=O#=
# 426. <[C11COC(CC11HC==1221
# 427. +3CCCC()OCC1
# 428. (-]F-o1H5<<1)<<o<-<<<<<4<<<<<OoNC1<<<<<5<<<<<<<2<<<<5<<1<<(<<<)<<<<c]<]<<5(-(F<<<<5<O<O[<<<<<+<<C<<c
# 429. <CC12(2NC)N1OCC2C
# 430. -c251CCCC[#1OC1#1O
# 431. <CCCCC11N=3CCCO
# 432. 534OC#NCO
# 433. <CC112=CC=CCCOC
# 434. +=O1CC1C1C2O
# 435. )[CO1OOON
# 436. <CC12COCC#(C)2C3
# 437. <CC1CCO21CCC))
# 438. cONC11CNCN=OC1
# 439. <CCCCCC)3NOC=11OO
# 440. <CNCCCN1(CC1N=
# 441. +oO5=#=
# 442. <CC1CCCN1(CC1)C2
# 443. 43=CNNCC)
# 444. +3
# 445. 5NC1COC1CN11#
# 446. +
# 447. 3N=F#2F-[-1n+HF-53+o[]+N-no5o[4O+(+Foo-(4]]]]5544-55c=5554H+o<5]]<c<]c5[nOn+n<o[5<-cHcH3<<+F[]4]4#-n
# 448. H+Co=)1)ON)1C11
# 449. <OCC=NCCCCCn13)
# 450. 4C-2Hc]45c-5)HH5<c<<<<n<[55C+n<-c]con<c<[<c5<51C[Cn53[+o[+[<55[Fc][<[-]<#c++]<(<<<<4o<5o3c5nn5n+<o<<
# 451. (#+H-5-#4OOOOO2CO=O#
# 452. )#+=4Fc1=oo=3+21#((oFH]#-c445[555((5+3#cFCC3<4C5)))5-F+(5(4(o5o5-F5-<-<]F(-<=c]<5<<-C55<4+5-2<-4-<5F
# 453. <CC12C1C(C22CO2
# 454. 4CCCOC2C(O2NO#2
# 455. +NC1CCN)CC=)#=C
# 456. F-c54-]355cc+cncC
# 457. <CCCCCCCOC))NC2#)N
# 458. #=1(CCCCC1OC)ON1312
# 459. 2NNN1N
# 460. #CCCCCOCCC21CCON2O
# 461. +n
# 462. OH)Ccc4<c<<<Hn<<[[2c+cno4H]OCO=CONO
# 463. <CC11CC1=CCCC21
# 464. 2n2ONO
# 465. oH2#O#N1
# 466. +4[cnFn5H5
# 467. OOCNC1C=2OC=O
# 468. 4-)
# 469. =#CC13((=C3
# 470. <CC(CN(O1C(CCNN1
# 471. #CC121NOCCC1O1N
# 472. <CCC1CC
# 473. <CC((CC(C1C=O)1=O1C
# 474. <CC1CCC2COOC23OCN=1
# 475. <C(1CC)C[OO=
# 476. <CCCCCON12)(11C(
# 477. <<C1NN22CC=C3C(1
# 478. <OOC2NC3CN1O11
# 479. <OC1CCN2)COO
# 480. <C1CC11C)CCCOCCCO
# 481. <CC=#CCCC=)N1O21#
# 482. +3C(CCNC
# 483. <CCC11C1==))2C2NC1
# 484. <C=1CC(NCCO=CO1
# 485. 5C1CCON2ON
# 486. <4=CCO=O3CNCO2
# 487. <CCC(N)NC3CF1O
# 488. <C1N(313CC)HO)
# 489. <CCCC2C=C)C1CC1CCN
# 490. <CCCCC==3COCCC2O
# 491. +3+OCO1
# 492. F]54cooooc+=4<<5(5[<15c<=(o<[+cn<<H<53)-4-4<o)c2c5<<-<[<<4<c54c(5
# 493. F=cc1OFOC]
# 494. <CCCOC22CC()OCC)2
# 495. c5ncO
# 496. +NO1=
# 497. 5n3n]1OO
# 498. #=11C2CC11CC11=1
# 499. [OC1CN3OCCC1O
# 500. <CCC1C2CO(2C=CC1
# 501. <CC1(CC=1CO2CO2C
# 502. 5]#=5OOFCO
# 503. 3(nFN4)<-4#--44C-n5O(<(]--n55F<+5<55Ho55<o<<-<<N#<[4n5++-4H-<=<55o-4[]5)=o]F<<5<)+=2<5H1Ho55-5]<(oC<
# 504. n(C1==NC(C4(
# 505. -14ncnn5oo
# 506. o[O[#FCC=C1=
# 507. Hc[1NNO
# 508. <CCC1COC1C1)(C22
# 509. <CC1CCCC(COCFC
# 510. <CC1CC)C12CC#2OC)
# 511. <OCCCCN=CC)())
# 512. <CC1C1N2)CCFCCC2
# 513. CO1CnCC)O(C)CnC1C1O
# 514. -]CC(#(CC=3CCC))CO
# 515. [F-2coo)+c-=((-5
# 516. <CC1C(1)CC41CC)12
# 517. <C#FCCOO)C3COOOO
# 518. <CC1=C2CC#(OOC)32
# 519. <CCC12OC31122#11
# 520. CCHO(=CN
# 521. <CCC1=CC1C312C
# 522. C(
# 523. <Cn112C42C3
# 524. <ONCC2=NC1CC(COO=
# 525.
# 526. -H1#NNOON#
# 527. )=5o-554[O2-O=
# 528. =+3+#NN2
# 529. NH2=NCFC1)OCN3
# 530. <CC(1CCN3C()2=1C
# 531. <CC(C(()=N24N=N11C
# 532. <C111OCCC)NC#O
# 533. <NCC(CC12CCCO11COO1
# 534. <CCNCCCCC21C3C1O
# 535. 4CCCCNC#CCCC12
# 536. <CC=1CNCCCC1
# 537. (2CCC11NC1OCO2
# 538. COOC#O1NOC#OOO111O--C
# 539. <ONC(ONOCO)3C(1
# 540. 1C#1)CCCCC)NCOOC2
# 541. +OOC2C22C1C
# 542. <CCCC=
# 543. nN+=1###=N#1CN
# 544. 3O#[
# 545. <CC12H2CC(O1=CC
# 546. <CC2C32CCCC)(3N=C2
# 547. 5c4[=CCC2N1ON
# 548. <OCCC=(CC)C1CCCC=
# 549. <OCC1)CCC1C2CCC3
# 550. <CC=C=OCO
# 551. <CCCCCC1NCC)C11O
# 552. 5<o3)1O5()4oH)H-F-(C[Oc<c<<<no5#N()55Fo45H[[H]o
# 553. 3]-#CCC2#NCO#
# 554. <-[CCCCC1
# 555. <CCC=21OC(4CCC(22O
# 556. OC=1OO#C2OC
# 557. F-ON+4o53-n5
# 558. <CCCC31CCC))12C1
# 559. [CCCCC2=CO11ONO
# 560. <CCC1CCCC3#CCC1
# 561. H[[n]3
# 562. <NNN11O1
# 563. <CCCCNC#=C1N)31
# 564. <CCC(C(CCOC)2C)1
# 565. <CC(CC2=CC(C)
# 566. 32CO[O==C4NN#
# 567. <CN12COC)NC)CN=1
# 568.
# 569. <CC1=C21C=1OCC1C1)
# 570. <CC(221N1CFFNC)N
# 571. <CC11C(CO()=CC2C)C1
# 572. <CCC2O(C=COO(#23]=O
# 573. [1C(1C2OOOCC1C
# 574. 3-
# 575. )[
# 576. #3#O]1(o=<-<=5<<5<<<<<<<<<<<<+ON(<(<<<5<<<<<4<<<<<c-<1<<<C-<<<<<<C<<<C<<<-<<<(<<F<<<<<<F5<<<)<5<(H<<
# 577. 2<CCCCCCC2)11N
# 578. <CC1==N3NCCC1C)NN
# 579. <CC1CCCCCCC)C)CC[3
# 580. <CCCC21C2C(2112212
# 581. [FOC1CC=CCC=C2)O2
# 582. <CCO1CCCCCO1N11
# 583. <OCCCC2CC1CCCO2C#
# 584. 1N-]+cc[++c+cHn+4]c4c[<cF455(c<oo+<nF5F(H-]-[#4nH5554c4[5c5co54(F+55+55-55cn5-F5c[+c]c5555F4Hc+-5[c[
# 585. <CC1CC(CCOCC23O
# 586. H4n=
# 587. <CCCC2(C1C1C)CC1N2
# 588. (1+O2)C12NCC=(C)O11
# 589. <C#1COCNO1)C1CC1
# 590. o5oH34]3N<5<4c-<-1co4<[<o[<nn<<+<oco<c(<c5c<co<<+c(<c<<<5c<c<<cc[<<FFc5<n5<cH<H]<<c<<ccc<c<<c<<4ccF<
# 591. <C1CO2(()OC=)CCC2
# 592.
# 593. <OCC112C)C)CC2)C#
# 594. NC1CCO(=CCCC111
# 595.
# 596. <CCCCC1)CCC)11C3
# 597. 1O
# 598. <CC11CNO(CCC=11
# 599. <ONNO#OCNC#
# 600. <CCC2O)1NC(1O)))2CON
# 601. <NCC12N1OCCCC)
# 602. <CCCC(1N(21CC1
# 603. <CC1NNCCO13C#OCCNFN
# 604. <CCC(C=C(22CCC)
# 605. CCC1CCOC1C)=131
# 606. <CC(C(1113OC2)11C
# 607. <CC(C=CH#=Cn)1C1
# 608. N+[ono[nc]+5])[4(o-5o5c[-5[Fc+542n5cc(55[5]H[FO-(]5-[o
# 609. =N1C112O
# 610. 3]o)-O4FC(C=CCC=OCCNOCC)
# 611. <C#C(#CCCO(C11
# 612. <CC1CC))OCO1N
# 613. ]o
# 614. oOCCC1C2CC1
# 615.
# 616. [)HHnF<5+n5]3]=-2HF
# 617. <=C2
# 618. F-ncHn5][][
# 619. 2=
# 620. HH5o#5-[<<<<<55-)<N<<C+CNC1(C1N(C21C((C(C1ON=CO11
# 621. 41C
# 622. oCCC1OOCNCC22##C
# 623. 3nF[O=O4COO3#C#O
# 624. -o5
# 625. N-34(C#CC=N2
# 626. FO#CC11=1C)OCC(2=1
# 627. O3512CC21C=)C))O(
# 628. <CCCCCCN1CCCCC(3CC3
# 629. cn55H]nc4+255-cH[[+-HHN5o]nc1HcncH]cn5HccOcc#4(Hcn[n2+5+(Fc4n(on4o34o425H5Focc
# 630. C5O#1ONNCC221OOCNF
# 631. <CCCCCN1CCCCC()12
# 632. <COC1CC2)=C2==NO
# 633. FC1CC=CC1
# 634. C[CN2NO#C)1
# 635. <OCC=OC=CCCCC2)C
# 636. <OC1=212C1CC(C1=1
# 637. C-41O
# 638. NON=CC1NCCCN)
# 639. <CC33(C2CN())C1C#
# 640. <NCOC1CCOO1#
# 641. <CC1CCCC1CCCC)
# 642. +]((N(F5)11(354(F(<<<<(<((<<<1<(<O<(OH5<<
# 643. [n4-(3C1
# 644. OO(1C)1CO1[1C-CCO)C
# 645. <C[12CC=C(1C)))
# 646. <CC(CCCCCCO13
# 647. NCC1=CCCN1)
# 648. <c=1CC3)==O)13
# 649. O#C11=2=
# 650. <CCC1COCC1)C)12O
# 651. 1NH3NC
# 652. <CCCC1CC2ON2O
# 653. n[=--
# 654. <CCCOCCC1C33CC)33
# 655. <CC#1CCCCCCCCC1N
# 656. 1OCC=C1CC
# 657.
# 658. <C11CCCC)CCC1ONOC1
# 659. Co1#1C2C
# 660. <CCC=CO3=O=C#C
# 661. #C11NCC)1C(N=)
# 662. 4cN(C3H=3N(C<45<<<<<<<<<<-<<<<<<<<<<<NC<<<<<<<<<<<c<<<<<<<<<<-<<<<<<c<<<<<<<<<<<5<<<<<<<<<<<=<<<+<<<
# 663. Oo-C3HH3<(<<<<3<-<5<13]<<<<<5Co+
# 664. 4CCCNCCC)=O(C
# 665. <HC1CCCC1H+CO1
# 666. <=C12)=CCC2C
# 667. <CC1C2OCC)C2)CCC#
# 668. 411O
# 669. F#=1CCC1O1
# 670. <CC12#=CC(C)1)1+=
# 671. <CCC(CCCC1CC3N)
# 672. <O1CN23)=2
# 673. 3NNCC1C#1O
# 674. 4NO
# 675. #1+
# 676. O5CCC##COCOO
# 677. HCCCC#CCCC)()
# 678. <CNC2C)N=C11
# 679. (CCCCC2C1==31
# 680. <CC=12CC()C=OC2O1
# 681. #C4#COO1O#1
# 682. <C=1CCCCCC=CCN2)=N)O
# 683. ]c]
# 684. ][C+1CCN
# 685. 5<CCCC=CCOOOCH=
# 686. <NCCN=1OCC2=2)
# 687. <CCC(2)CCO)())
# 688. cNCCO=)C(CC21
# 689. <CC1(2CC2(1(21)
# 690. <CCCO-)CCCCOC#
# 691. <C1(CCC1NC=CCCO=
# 692. <C31=CN(33)CCo)N
# 693. #+2CCNO)OOC##C
# 694. NCCCCCCCOCN#O
# 695. #=CC11C=OC(
# 696. ())O1O
# 697. <1C#1CCCCCC2
# 698. -+=53#OONOOOOCC1O
# 699. ]53#c-]NCO311=C=1)O2ON
# 700. <CCCOC==1))O12C1
# 701. <CC1=2CN1CNOCC12
# 702. CC(COOC=1#NC
# 703. nNC[C4NOO2
# 704. <CC=2CO)=CC3CCC
# 705. ccn
# 706. (NC(C(C#22CC
# 707. cF5-4)]]cCH#C
# 708. <O==1CCCCCO))OCC=
# 709. cO#COC)O2OCCN=
# 710. #3o1CCNCO#CNO#C
# 711. <CCCCCC32(C11121
# 712. <C1C1(O=CN(CO=3))
# 713. <CC2CCCOCCCCC1C12N
# 714. <CC1C1CCO=CC2
# 715. [1C1)O)C)1)CCC1#
# 716. -3HCC=C1##]
# 717. <OCC)CCC((ON(
# 718. <OCCCC2CC)#O1NCO1O
# 719. <CC1CCCOC1)C)=2N2C
# 720. +1o+o
# 721. H1#N25===oF
# 722. 2c5n[N]1Oc+555H[1c
# 723. NH]
# 724. <C(1)(CCOCCC1C))2C
# 725. <CONOCCCNC1CO2=N
# 726. on3O2O21
# 727. N2#
# 728. +C-12COON
# 729. 4O=C11)CCC
# 730. <OOCC(CCCC12
# 731. <CCCCC2OCC(1
# 732. n[4#FnO]+N[5[O)4HFnn5-cH+o3+o4o4cc++-]nc]nH[oHn-[n5OHo[nFo(-cn]+)F5-5[Hcn-5#C(-c]cH--n#4[c+)F+5co+[)
# 733. <NC1CCCC11CCCCN#1
# 734. <CC1C(CCCCCCOOOC
# 735. <CC=22CCCCC12C3ON
# 736. <CC1C2NO)CCC2==42
# 737. O#=
# 738. <CC1CCCCC4)CC)
# 739. NCC[()2O2O2C1
# 740. C[F1N
# 741. 1OC1C1212OC))C
# 742. nFCH+#N3n2+c5cc5n3[[n<(-)[o(c1N#1CN
# 743. <CC(OC(OCC(=3N
# 744. <CC()1C(C(CCCC(CC
# 745. HCnNon3o2<o[+<5<<<<<<cOCC11(CC==C)2=121C
# 746. <CCCCC
# 747. (on
# 748. n#O1C(OOC+
# 749. CCCCC22C#CCC=C1NO
# 750. <C1C=1C
# 751. <CC1C1CO2CC1N=
# 752. <CCC(C21CCC1O2=1O1
# 753. 1+==C4CC21(NCCCNN
# 754. cO5
# 755. <CCCOCC(CCC)2CO=2N
# 756. <CCCCCCCCCO2)21
# 757. 1+nnnc
# 758. Hc31C(CO)C)H)21
# 759. [nCC1C(21NO1)NO
# 760. -CCC11)=CO2O1
# 761. CCCCC2=2312N3N2
# 762. <=CCNCC3N1C4CCNC2O
# 763. 2)-N#NOO
# 764. <C(CCCCC1C1ONC=(21
# 765. F4++=+<511C11
# 766. (1N112HH)5+F4o#<<-<<<H<<-<--1=N<<<O)#<)c<F<N(C<-c<4[=<<<#+<<((<[3Fo#5Hc4<([<<<<)<N#C][o<5]-<<<+<<N<(
# 767. 3C-#545++[+c[c)+c+c<F44c5[4(cHcc(F]<4nNn)-H[5(-)-[=Hn3NH(3Fc]c[[oon+--<n3n)-55cc]n5-54-5cHc)5
# 768. <C1CCCcCCCC)C2C)
# 769. -2NO
# 770. 4OCC1O1CCCC)C1C
# 771. OF1C1)#21
# 772. <C=CC1C)CO=)NC(C1C
# 773. <CCCCCO1CCN)OON12
# 774. #NOC111C11CC11
# 775. <ONCCCC2OCC)NN1O]
# 776. <N1CCC21CCC2CNO
# 777. <CC1CCCC)C11C#11
# 778. <CCC(2CC2CN=CCO
# 779. nNC1(O221CCOCO1)
# 780. <CC11CCCCO1C=1N=
# 781. #3CO=F#
# 782. <CCCCCCOOCCC=
# 783. CCC1C)C(1CC1CN)O
# 784. <CC1CC12CCCCC1CN2
# 785. #
# 786. +3CC12CN22C12)
# 787. nc(+2o(n=5(5c<C4<c<[43C5<n)O+<c[<n4c[1n2[c5o
# 788. [NOCCCC
# 789. 444[O+#NOCC
# 790. <CC1C2CC2C()O)12O
# 791. OnCC1FCCO222
# 792. 3(C1CN4CCNCOC1N
# 793. Fo1CNN)1)=N1
# 794. 42O4O
# 795. <NCNOCC=CC=OCC2CC(=)
# 796. <CCCCCCCCC=1N2O
# 797. <OC=CCCC2C)O=C2
# 798. <NC1C1CC=CCC1=2
# 799. <C#11=CC(NC))CN(
# 800. <cCOCCC2C2CCC41O(
# 801. <CC1CCC((C
# 802. ([+o
# 803. <O3OC22C11C1N
# 804. +NcF#
# 805. 2+445#]4n]N4[F4[5FO--
# 806. C
# 807. []#C#
# 808. C#CCN12CCN1=
# 809. <OC1C2CCC1)CC1
# 810. <CCCCOCNCCCCNNC2
# 811. n4CCC(CCC21=
# 812. -CC1CC21C#((C
# 813. -CCCC1(
# 814. <CC11CCC1C=NN)O
# 815. [1(+
# 816. <CCCCOCN=CC1C=)2C
# 817. #=-NO-1(+--oc4((nC=[=O=C(OONC
# 818. <CC1NCCCCOO31C12
# 819. <CC11(CCOCC)O31
# 820. <CCCCCNCC(C2C1]#
# 821. <CC#N=)C)C2OO2N32
# 822. 1((c]-5-<<=<[<FC[#<<<c3<<<555Hc+(<=<<<<]55<=H5(4++<<H+)4=<<<<F<(#<<41o<<)<<<O+<<5N#oC<<]nC<]<<<F(c<<
# 823. <NC11(2213CN=C)
# 824. 1[COn+o5o[oc[H]cc+22<(C4[=[+Hn-C2c-nnn-o+#HN+n-+]cF5)-H<oF(o]CHF+=ccHFF3Hc5[oHcc3cco5Hn5[[n55c3<]oF[
# 825. 2n-+H2-[H44F5c5c<-c]o3FFc-]n[[[(54ocon]#<<-3<c5<]4[4<<n<<<<+HF](45NoH55<+<]4Hc<<nHc#<-5<nn55[[-#4H+(
# 826. =411-NCNO##=O
# 827. <CC1CCOCC(CCC1C1
# 828. <CN112CNC)C2O1C1
# 829. <(Ocn]C
# 830. #C1CCCC(CONC
# 831. [-c(-oc)<-54+555<n4<<<<<4<<<+<<n55o<<+<<455<<<<1oc<<<c]<<c+<<]+<<<<(-n+[<<<=-5<(<<<<<<[+<#F<<c<<55<<
# 832. HOO2)11C2FC112
# 833. H]ccO2-O4=
# 834. 4OCC3C21CCCC1C==C
# 835. FOCCCnCC=CC2C
# 836. =
# 837. <CCCCC1))==OCCO1
# 838. <CO1C)CO21)
# 839. oo)-
# 840. 5N<4C=C1#OC()2O
# 841. <CCC()COC1CCCC=)
# 842. =N[5+nc5FOCCn+(cCNCONCO
# 843. <CCC=O(CO11C)C
# 844. <c1C1CNCO#CCO4CC
# 845. <CCCC2C)NCC)CC1CO
# 846. -+2]
# 847. <CC11CC(C1)C11)
# 848. <CNC13CCO1CCN()2)1
# 849. 11
# 850. =<ONC1CC2CCC
# 851. 4#CCC12
# 852. )c
# 853. +[CCO1#N#NOC1]1F
# 854. cc(<<-2)NF=3O==]
# 855. ]21=CC(CC)CC3
# 856. 5+]n
# 857. F111CC1CCC1C#
# 858. <CO1O=1C)(1O==2
# 859. <CN1(C1C(1)=O=)N1=3
# 860. +C
# 861. ==C[C<oF+C+-<
# 862. <C=C1CC1COC=N3CC2
# 863. +CCCN1C1CO2
# 864. )CC=CCO2=O1#
# 865. N=oO
# 866. <ONNCCCCC11)CCO
# 867. <CCCCCCC1C=CNC#
# 868. <[CC(CN1OOHO3
# 869. F1131F2c3nF4]3cH
# 870. <CC1CC2)C21C)CCC
# 871. -=OCC1C2NN11NN
# 872. FCC11
# 873. <NC1CC=NCCC1OC11#
# 874. [[CO#CC##C
# 875. NN=CCOC11C)3#
# 876. <CC#CC2CCC1COO)CC3
# 877. <OOCCCC2C11NN
# 878. oOC(CCCCCNCO)
# 879. NNC#CC=OO2=111
# 880. n
# 881. O-](1(3)
# 882. O]1
# 883. ]3CN2CCNC)O2O
# 884. +[++Ho--<o2NN5<3O5++cF5#]-F]4Hc[4[C55<2[5<5N5c+<Hc[<55F55Co<5o-Hn+]
# 885. <CCCOOCCCOCC)1N
# 886. )OOC12)#=H11
# 887. <OOCCC21O4)OC23ON
# 888. <CC1(2C1C(CC11CO
# 889. <CC2C1C1CCO=1N
# 890. <]CCn1CO(CNC1NO)N
# 891. )+cc+]#1N1ONN=1
# 892. no[4ON=OO
# 893. cc51FO1#1F
# 894. 35CC#=#1
# 895.
# 896. <O=
# 897. <CC12CC)NCCC(1)2n2N
# 898. [+cCNNO11NN
# 899. <CCCC3(CC#3CN2
# 900. <C11CNC=3COCCOCC3
# 901. <C1COC)#CCC1O332
# 902. <CO1C=1CCCOOCC2NO12C
# 903. (C]#C
# 904. <CCC1O)(C1=2CC)4
# 905. <CC=CC=CO=C3=1CN)
# 906. 5nNCC12)=O
# 907. 4)[1[<<<<5<<F<<<<<<<<<<<<<CNC<2<<<<5<<<<C<<<<<<<<<<(+1<<<<<<<<<<<<<<(C<<<<<<<<<<<<<52<-<<<<<<<<<<<<<
# 908. 5H[4][ocHHo5
# 909. o]-o(n<(C[C#=HOc4]4n25F<<o<+52+5<4<[o]2<<<2<<+#<<<145<)<2<-<<55<25554c<o5<-<<<<<-+<<(+F5]<<<<-5[<o<F
# 910. )5CCC1CC(C2CCO1
# 911. <CCC#CC1=CC3C
# 912. <CC=1(C1=CNCO2
# 913. <C111C(3CCCCCCC2COC
# 914.
# 915. HO#=OCCCOO
# 916. +CC1CC1C#1CCC=#
# 917. <OC12CC(CCCCN
# 918. <CC1CC22CCC1C))
# 919. (+4]514
# 920. 5+cO<
# 921. oCCCCN1O1CC2
# 922. o=C112)COCO
# 923. <CC1NCC=OO2(1
# 924. 12+NH2#
# 925. <CCCC(C1CCCC1COOC
# 926. <OC=2O=1=OON
# 927. NCCCOC3C1
# 928. 3(]OC2C
# 929. <CC1213C(C(CO)C)22
# 930. (c3Nc
# 931. [nCO
# 932. 5cC1C1C)CC)11)#
# 933. #Ooc1(4#Cc(H3<<n[(1o<co5Co<<55<3<<<<<5<5<5<-(5N[-<<c5[<oC5<<[5<C<<<o1Cc[45F<c<o5<2+<<H<<2<cc<]+<<(+5
# 934. 434##+#-OO=N1
# 935. +1
# 936. <CC#1CC(C11OCO2
# 937. <CCCCCCCCCC=C31
# 938. cO#)o#+o2-<<2<5c-]<5<C=<o<5-5C<<<C-oO5([5(54<+)o-c(2<+<nH<-<3-<CC
# 939. <CC1=)O=(=O3C32
# 940. 3NOC1CO2C#2N
# 941. H#[o[<<<<<)-54cc<<(OH4<<<<N<<<(<-<<<5<5+<-3o<5<<<<(<<C+<c<<<<<<<<<<<HH<+<c<<o<<n<5<<n<<<-3<1<<<<<<<[
# 942. 1()<(=1-5<+OF=1<<#<<<<<<<4+13<<C5
# 943. <CCC1CCC)C#COC3
# 944. ]OCO#C1OCC1
# 945. ]-+4HH+1[5(]+5(555+o5c-c-[[-2+c33H-5N5)5=5N5<C35455Hon5n-35335oH25co-5555555-c5N5=5c5]555c+]3((#-5]n
# 946. F-##C
# 947. FOC1C1C1CCOCC)1
# 948. oF-+]55C=N(+HFno]-5nnc(+#5(4-FH
# 949. OCC1CCCCO(C3OC
# 950. CNOC(CCC)1)11)C
# 951. <CN1COC(31))=OO
# 952. <CCCCCC1)CCCC()]2N)
# 953. <CC1((=)NCC
# 954. <CN1CCC13C2#)
# 955. O-4#1=11
# 956. <CCCNCC1))CC)C)O)
# 957. <CCCC(C(C3))CC12C1
# 958. <CC1#23NCC1CN
# 959. <CCC11CCNC11C1
# 960. 5C1C1(CC2CO11=
# 961. 4CC(CC3)=1=)
# 962.
# 963. c
# 964. O1CN1#CO21C###
# 965. N=42N3(2=)NO==3FC1+O<<<1O[]155F<51<<<O4C<[<<<<5oo-<-((Co(+<=<<N<<(<-55<<55[<#(#<<<<<<(<<#<5<<<]<<<<N
# 966. ](CC=COFC)CC121
# 967. <NN1CCC)C(CC()CC2C
# 968. FCCC1c)1N21NC2
# 969. <CC112OCCC1CC1
# 970. <CC1(OC2C=)1=1#
# 971. <OCCCC=CCH1C=
# 972. COCC1=()1CN3
# 973. <OC1C2C=CO)1O12=
# 974. <=N=C#O(=C1)CC#OO
# 975. <CC1NC()CCNCCC
# 976. <CCCCCCC1)#=C1C2
# 977. <CC1(CN)(CCC1C))#O
# 978. <CC1CCCCC))NCC3
# 979. <CC1C1C#1C)1N2O12
# 980. <C=C132(=)=CCNCC
# 981. N]1-#=C11
# 982. ]Cn12C(21CC)2n1c
# 983. <CCCCCOCCCO
# 984. <#CCCC#O=1NC1
# 985. 1CCCCO2C=(NNC))
# 986. )=F]4OC
# 987. 3CC1C=1C=CC))1COC2C
# 988. 5F41)N
# 989. FCCCCN1=
# 990. )H)OF<nH(+)1+<c<<<
# 991. <CCCCCCO()o(OC)O
# 992. O)(5<2[CCCCCC1)C=131=
# 993. N#31CO
# 994. ((NN-
# 995. <CC1COCC1O(C1=
# 996. <CO1C1CCC)CC1O
# 997. <CC(((CO((CNC1C2CO1
# 998. <]+11
# 999. <CCN(2C=32#N2NOC
# 1000. 344]OOO#
# 1001. <CC1()CCNC(=)C
# 1002. C=)[4n-nFF[cHcH<H]52cFc#==(O=O
# 1003. <CCNOCC1()2C12CC
# 1004. +FF-45)4(Hoo4<-[+<-]-]4+5n=Fc+-52<H)4n+<<]ncF+<+5<H2(5<[+42FH<n[[[o-2]<n[cC25)55<C5c+-5OnF5Fc54Ho-5(
# 1005. o4+N11C111
# 1006. <C=1C2C1(C))CCCNN
# 1007. +O-4
# 1008. <#C(CC(NC1)C=COC
# 1009. <CC1=41COC3C1O232
# 1010. -5HH255HC1O1CC(21(3CC
# 1011. n3o12=N#112O
# 1012. (NOnCCCC21CNC(COCC#)OOO
# 1013. F
# 1014. n44==CC1C
# 1015. ]
# 1016. <CC1CCO((C2(O123
# 1017. <CCC1CCCCO1=C1CO
# 1018. -1c
# 1019. <OCCCCCC(=NCCC))N
# 1020. Co[nc-)NO[152#FOC12C(CCC)CCNO)2
# 1021. <C=1OCC2)CC=)OO
# 1022. -C11
# 1023. N)==CCC)CC2N4=241
# 1024. <CCC1(2CC2C=C12C1+O
# 1025. <N1CCCCC2CCCCCON)#
# 1026. 5==
# 1027. <OC1OCNC#)N1CC
# 1028. oo1[]
# 1029. <CC1=NCC1C1CCOCC
# 1030. ((no[-+4+o5oc++5n5(n]Co1]n5N45c-N5++cOnn]=5c555+-nHn5o[]c#5]4O]ocn5nc5
# 1031. 3ccC1)O)ON)
# 1032. <CC((3CCCC))12)O1
# 1033. <CC1CC2CN=CC)2C1122
# 1034. FOC[=nCOF1N]C154(]5(#5[FH)CoC[5H[]C5-n<C([55<5<<5-o45N-(N+F55[5[C(+<<H(<=)1)5-<5==H53+<#O#<(+5+<<N<5
# 1035. <CC12(1)CCCC1CCO2O
# 1036. #C=CC#1CC)CC2
# 1037. (2=
# 1038. 54FcFFN+O1=N=ONNCO
# 1039. FOCC1C1NOCNCC#
# 1040. <CCC1CCCCC2CCN2
# 1041. <OCC21O1C)CC=)CCC1
# 1042. +=1
# 1043. 2CC1#=C=CC(N4#
# 1044. 4H]]O1NNN1#O
# 1045. -+COO
# 1046. CFC#=C)C#=O#
# 1047. CCCCNCFOCC)N#
# 1048. #<C1COC)C()=CCC1
# 1049. <CCC1)C1O=3)#N1O
# 1050. <5NC1NOOCC1
# 1051. 5#CC11OC1O
# 1052. <(CCCCCCCC=N1O1
# 1053. [-OCC#1O4
# 1054. O
# 1055. <OC(((3=))2))N
# 1056. [CCC1CC=CC(CC2
# 1057. [N35H4]5-(+5-11-Oo5#-)25cF-+5525-c(5c=#o#(5Nc]<5[<4<+(]#<c<<O<<<<cC<<(Ncc][+4<55]<<5(<<c<<-4-oN55<5<
# 1058. 24C#C1CN
# 1059. <NC1CCCCCO#C1C1#
# 1060. [<o+1)o)
# 1061. <CCC2C2=C=CCCCNCCNN
# 1062. H=CCCCC1O2O
# 1063. CCC=CC)C()C2OOC1O
# 1064. <cCCCCCC(NCC3NCO
# 1065. <CC1C)C(C2C)C)CO
# 1066. FHocOCO
# 1067.
# 1068. )3N
# 1069. onn1[-55on5cn[Hn5+n]]-+c]=][3453o1]-n]5on]][ncHo
# 1070. <CC1C1CN)CC21C#O2
# 1071. #C#=1N)CC2
# 1072. (OC1C3C122C=21OCO1C
# 1073. cHON=#N=-O
# 1074. =C(C()(C)
# 1075. 44#C#CO2N#1
# 1076. <CC1CCC)C1CC)N1OC3
# 1077. <O#CCCC3)2
# 1078. <5CN#(1CO2(1
# 1079. <CCCCCCC(3)OOC=))N
# 1080. <C=1133CC3OC))C=2
# 1081. <CC1CC2CO)2CCC
# 1082. <ON1CoCC)()C))3=N=
# 1083. <OCO(3)CO(OCCC1)
# 1084. -NN54=[13CCO#
# 1085. <CC12CO(OCCCCN)1O
# 1086. OCC1#C2C=)OO1
# 1087. 4<#NOC#N
# 1088. o14O#4#11
# 1089. +FcOO1=2
# 1090. <COCNC21CCC#CN2
# 1091. <C1C(C(CC2N2=OO
# 1092. <=C1(2CNCOC1=)C2C1
# 1093. <FC2CCCC)C(CCCCO2
# 1094. HONCCCCCCC
# 1095. <CC1CCOCCC2C(CC2
# 1096. <CCCCC[NCCO3CCC=
# 1097. <CCC(=CCC3CO123
# 1098. <C1C=C2CCC+N)C#N
# 1099. <<C11=NOHC3C)2=1)2
# 1100. nF1CC2CC2(22
# 1101. <CC11CC#C1=CCCCCC
# 1102. <CCCCCCCCCCCOC1
# 1103. =OOC=CC(C=NCOOC
# 1104. <CC1=C)2C((OCOC
# 1105. <OC1CCCNC1O1C)O=
# 1106. <CCCCCCCCOC11
# 1107. =#4C=CC#C
# 1108. O
# 1109. O24O=NNO
# 1110. <CO1CCC2CCCC=
# 1111. -1cn]H
# 1112. <CCC(OCC#C(1C2C#O
# 1113. ]1+5)H3++5-H
# 1114. 1CC1(=OC2==CNCC1
# 1115. CC(C1C2C(1CC2C1C
# 1116. #)O11CCC)=2#N
# 1117. 4(o]F#
# 1118. FFOC2C)C
# 1119. <CCC11CCC=)
# 1120. <CCC2C1)CNCC13C13=
# 1121. <C1(ncOCn)NO)N)
# 1122. <CC=CCNCNNNCC1
# 1123. <CCCCCC1CCCCCC)1
# 1124. FF3#CON##ON#22
# 1125. ])=CC1)#NNC]2
# 1126. <CCC(2C)(CCOC
# 1127. <CC1CCCC2CC)CCC##
# 1128. ]CN311C
# 1129. -(OC=12N
# 1130. 5N)<1NC+1<<<<<<))
# 1131. <CC(23CC=CCO2C1
# 1132. <CCO1(CCC(1C1C(CCO#
# 1133. <Cn11((]1(CO2))(121CC12
# 1134. -CCO1CC2CC=1C
# 1135. #OC1(=2(C)131)C
# 1136. <CC1CN(CCN1OO1O
# 1137. )CcFccc5+=+[4HFcH4c-+=-ncccH+c=Hncc45HcH[[]-]c-c[H2[+n5c+n[nHc]+2ccnoc-[cF])FoncoonnonFcnoc]]55o-4oc
# 1138. Hc1N
# 1139. [CCC1CC=1=)=N121O
# 1140. O=5
# 1141. HC112C)2CN3CCO23
# 1142. =CCOCCCCNCOC)=
# 1143. No2n<O(C1CCCNC2
# 1144. n-o]n)FH=F
# 1145. <C=1())C11C1C1C1
# 1146. <CCCC2(CCC))CONC2C
# 1147. (CCCCCCCCC=CCCN)
# 1148. [H=O4
# 1149. <C1CCOC2C1(21)N1)
# 1150. 12C=NOOOOCOC
# 1151. <NC1C11CCCC211N
# 1152. [c[c
# 1153. 4-1CC1(C
# 1154. (2nHNN3C
# 1155. #
# 1156. 4H+F5#NCC1OC2CCCN#CO
# 1157. CC(C12C1N1
# 1158. 5cOc=
# 1159. <CC1=(NCNC=C1CC2
# 1160. No3O
# 1161. 3#cnHo(N<4-(o+[5
# 1162. +=4C(CNC#CN=
# 1163. <CC12OC))N=#1#C)
# 1164. =-4-4)C(1CO111C
# 1165. <C=CNcCN1CC(CCC#CNO[
# 1166. C31CC12
# 1167. OoNFN#4O4N
# 1168. <CC11C2)1C2C1ON1
# 1169. <CN11COCC+CCCCO1C
# 1170. 5CCC1C-C3CC1C2O
# 1171. <-]n415n<1N+nF+<4+<<<n=5<3<1o(5<
# 1172. <CCC1CO1C)C(C2
# 1173. <CCF1NCCCC)O2#
# 1174. <OCCOCCC1OO=C2C
# 1175. <1C)CCCC2CCOC3=
# 1176. <CCC(2C](#N)OC)O
# 1177. n4o1N
# 1178. <COCCC3CC1CC111
# 1179. o[4n1CCOCC=CN(=N
# 1180. HCCCCCC2COCC
# 1181. CCNC1C1O)C=C
# 1182. <N)NNN
# 1183. <CC11C=(C1=C)CO)
# 1184. <CcC(C2C)12=CCO
# 1185. 4=C=1OCOC12
# 1186. <CCCCC)=CCCCCN
# 1187. FCCCC=C=#OO#
# 1188. 35N4]-oH=n-no<5-<(cco+[n4)n-co[=[c(4cn)=c(c<+5]]nC4[ccn5H<n5<nc]
# 1189. <OC1=#3CN(2C#)C113
# 1190. HNC(C=CC1CC1CN
# 1191. )1n)-cC5(3O5onF+(2N[#<O](+[5n-+5-+#[51<[)oF5H<<<55<-Oo-H+FO<<55Hc-5+5-5#4<+[(<[[]<<5c<F<]F<[C[+<<5+F
# 1192.
# 1193. FN#OCNCC
# 1194. <CC1=C(11COCC)OC#
# 1195. (CCCCCC2C3OCN1
# 1196. 5<#O5CCCC=
# 1197. C(OO#
# 1198. 51N#CC##O=12
# 1199. 2N+)#COO#
# 1200. <CC1C)C)()=OCCO
# 1201. 2CCCCNCCCNOCCO
# 1202. (3[)O#F2#
# 1203. )NCCC]11=NC##
# 1204. 2#CCC=NCCC=OC
# 1205. <CCC1=2CN(C1CC=#O)N3
# 1206. (<CC1OC=CCNOO2CC
# 1207. <C1C1nN21OCC)OOCC2
# 1208. <cC[]nNN2cCCn)NC)NC
# 1209. <N#1n3)22)O
# 1210. <CC1N(1)C2))OC2C
# 1211. <C=(CC(CC=2CCCC2C
# 1212. <OCC1(CCCCC(=C1=
# 1213. #N14COOO
# 1214. <OC(OC)1O1CCC22C=
# 1215. H=#nFN1O)1
# 1216. N=1]=(((4)(<oc4H<<1<(F41C-<]#-<
# 1217. <CCCCC2CCCC3COCC#O3
# 1218. <COCCCCCCC(CC)O=
# 1219. #OC1CCCCCC1CC)2C
# 1220. HC1N
# 1221. 5c-o==
# 1222. H-CC11C2C
# 1223. <CNC2=CCC2OCO
# 1224. [N11NC=N=CO
# 1225. o3
# 1226.
# 1227. #O4C#1#
# 1228. +#C=2CCCCOCO2#C2
# 1229. <CCCCCOC132OC)1=
# 1230. O(C=2()C4=
# 1231. -OC#1=11COC2)
# 1232. <OC13C2C2C31C231
# 1233. <CC1COC2(((N))
# 1234. )=COC1==2CCOO1O1=
# 1235. =CC(CCCN(CCCC(O
# 1236. 5o
# 1237. <O#C112C)=CC
# 1238. <]CC(1)C21OCC1NCC2
# 1239. <)CCCCC)2C=1OO1
# 1240. <CC((C2OC=OC)C)113=O
# 1241. <NOCCO=O1O
# 1242. <CC=1CC21OON=
# 1243. <OCCCCCCCC3C)CC1OC
# 1244. O])CCOC1
# 1245. <CC1CCO1NCO=2O232
# 1246. <CCC1COC1(CNCCCCO
# 1247. <CC1C3)(1CCCC1C)N2
# 1248. 2O#C)22
# 1249. -24O-5+#4(
# 1250. O===C
# 1251. <C111C(CC)oCC3H)22CC1
# 1252. <OCCOC1CNC1N=(11
# 1253. <C1CC1)=C1)C2CC
# 1254. <CN12CCC1C()31CC1
# 1255. <CC(CC1]C)
# 1256. <CC=12C1OCCC1CC
# 1257. #N(-5n5n(c<=#(<5+<C2<5]<<-+<3<<5<<<<<4<O<5<<<+<c-4n-<o)<<<O5OoNo<<-<<<=
# 1258. <C11C1=)CC13CO
# 1259. <CC1C2CCC#CNC)CN)1C221N
# 1260. <CC11C(2N3=OC2
# 1261. <CC1CC(CO))(22
# 1262. <CC1=1CC2CCC))CCOO2
# 1263. <CNCCCC1))C)3O
# 1264. -n)=on1cN
# 1265. ]#([O2
# 1266. CCC1CC(OOCC121C
# 1267. OOC=C=C1COOO
# 1268. <CCC(=2C==C)CC1#2
# 1269. #NF=C2=OC==
# 1270. <CC2CCC=C=ON1N
# 1271. <CC12C1CCC1N=CC2
# 1272. <CCCCCCCCCCC11CO
# 1273. <CCCOCOC1C)
# 1274. o-O5OO2
# 1275. -
# 1276. <CC11CO(CC==CN)O2O
# 1277. (OC1OCCOCCCC=42
# 1278. <CCCCCC)C1CO1OC1C1
# 1279. H4-3OnF--(+<<<<c5<34244C]33<]<n<<<c]4o5HH<-<<<<(<H<oH<4<<<<<<<5<F<<<<<<<<<ncH<<<43c[5o<<(3=c5<<o<<<<
# 1280. <COCCC=CCOOO
# 1281. <nOC22)CC11
# 1282. -+##
# 1283. 2O11O2#
# 1284. [oc[nc4+F3]5]FF+c<<F+n5#3n5H4F5]+F]+-o]c-5)<n4CHF#Hnn5c-[5+4nc<)c]5nFOccn[+]+[(noF]2n5+cnn]3[]5-54F4
# 1285. )N1#C1O1#NFC1NF#
# 1286. <C=CC1CC)CCCO22
# 1287.
# 1288. H+CC)CCO=C142C
# 1289. <OC1CCCCCOC=1C)
# 1290. <NO1CCC2=N
# 1291. <CCC2C)33C)
# 1292.
# 1293. n41)c+no]+(+(No--4
# 1294. cCC1CCC12C3CO
# 1295. 51C1CC2C2O
# 1296. o)5-)=O1ON#
# 1297. <-[C==C223N=C
# 1298. <CN11)CC1C1C
# 1299.
# 1300. <CC#CN(=OOCC2N
# 1301. <CC1=)CC)2C=C121
# 1302. <CCCCC21(2OOCO=
# 1303. CCOCC2NN)CCCCC
# 1304. H<CC(1=NcCO))211C#
# 1305. oCOCNN3CC1C3CCCO
# 1306. <CC1==C==NCNC)
# 1307. <CCCCCO)2CC11
# 1308. [+-COOC
# 1309. =cCC1OC]CCC
# 1310. <CC1n==)=12N2
# 1311. C(on1NN
# 1312. <C#CCCN)C1OCC12
# 1313. <NCCCCOOC3OCC1O2
# 1314. <CCCC22O=))=(
# 1315. C)(2C2#1
# 1316. <=C1CCC2C11N21O2
# 1317. c([O11C1
# 1318. <N=C11NOCC1#)CCC2O
# 1319. <CCCCCCC3CC1O3
# 1320. <CO1CCCCCC)1C)=2)2
# 1321. 4NC(NO#C
# 1322. <CC1(CNC1)1C)C2C
# 1323. <CC1nOCCCCCC)F12
# 1324. <==C111OCC2OC#
# 1325. <CCCCC=CC()=CC2=22
# 1326. <CC1CCCCCC1CCO
# 1327. n1C4C1NCCC21N1C1
# 1328. OCC1COCCCC=)22C
# 1329. (Nc#23]
# 1330. 2OCC#2C2C1O
# 1331. <CC#CCC==CCCNO1=
# 1332. <CCC=1123C=CC112
# 1333. 4NCCC21CO2N
# 1334. <NCC(CC)NC2C
# 1335. cNNC#CCCOCO
# 1336. 1COCC1CC11CC2
# 1337. OCCCCCO2C=C
# 1338. c
# 1339. (4335[
# 1340. =CCCCC1#1NCCC11
# 1341. <NCCC1CC))
# 1342. <C112(oCCN2O#)C
# 1343. c3F]o[4nF]on][HnF-
# 1344. -CCC(11)#)O2
# 1345. oOoCONCO#
# 1346. 13C1OC=
# 1347. =-1N#
# 1348. <OCCCCC1CCCCO1
# 1349. [O]Hc
# 1350. <CC12cnCC1CC2CONC)O
# 1351. FOOCCC1C2C)CC1
# 1352. 1)1cCO1CCO22#
# 1353. O=C1#C3C13C
# 1354. C2HC425C+3c
# 1355. 5C#[)n(5F#<][<(<n(<<<[-<5<<C<<]<<-<<<<<<<<<<<<<<<<<<<<<4<<<<<<<<<<<<4+n<<<<<<3)c5<5o<-<<n5c<<<H<]-<<
# 1356. H+OC(C1C21=
# 1357. N#11)C)1CCC1CN2=
# 1358. <C1=O=2C1)12C11CNN
# 1359. <CCC1C1CC)OCC=
# 1360. -cH2coF)3noo([=n(HnH
# 1361. C3
# 1362. <C111=CCCO#)2C4OO
# 1363. <C111(CC(212CC11)
# 1364. <C(C)1C=(=O1
# 1365. <OC11CCC(C)OCO
# 1366. ]CCCCC)O1#CC2C
# 1367. 5CC1=CCC3CCON
# 1368. <CCCC2C3C=C1)CO
# 1369. NNN4CCCO)CCOO
# 1370. ])CCCOCF
# 1371. 4[CCC)1)))
# 1372. <CC]CC(2CCC)((O)==
# 1373. 53n3+#H[]#1(COOO
# 1374. -2F12OO
# 1375. <CC1CCCCCC3N22=
# 1376. oC=5+]5o2
# 1377. <CCCCC=11N#NO
# 1378. o+H#Fno1+-ncn]n([]2
# 1379. ]O=11CCCNNN
# 1380. <CCCNO1(N2(CC
# 1381. +CC11CC2CC2
# 1382. C=1CCCCO3OCC
# 1383. n=]24o[5C34]H[(5n
# 1384. <OC1(OCCCC1O)C)CN3
# 1385. HNC1C=CCN1C1114
# 1386. (c3+c[-o4C[]ooHH[]
# 1387. <FCCC=OC312C1CCO
# 1388. <CC(C=CC(=OCCN2=2
# 1389. <CCC1OCCCCCCNCO=
# 1390. 4oCC(CCCHCO
# 1391. 4CCCC12CCN=
# 1392. <CCC1HC=N2O222
# 1393. <CCC2C#CC#2)C1(1
# 1394. <C=1CCOC2C=2C1O2
# 1395. 1NCNOOC
# 1396. <C21((CC(C1C21
# 1397. <CC1C=OC(OCOC2)N
# 1398. <C1cCCc2)O(C31CC12
# 1399. 3N23N4=O
# 1400. <o2C1=1OCCO
# 1401. <CCO=2CNO(=12=
# 1402. <CC()CCC+OO)1NO
# 1403. <CN1(1CC=OC2C13
# 1404. <OC11OC)1C11C)NC2
# 1405. =4(H<nCc)#<-<<<5<<<<o<+o<<<<<<H5-c<<<<<<H<<3<<<<<<<<<<<4<<<<+<<-<<<<<<5<o<<c<<<<-<<<<<<n<<<<<<<<#<<-
# 1406. <CCC12C1CCCCCC)2
# 1407. H(+
# 1408. <C=12CCCC2C=CC)CNN
# 1409. <CCC11C(C((OC1)CO1O
# 1410. 2=CCOONCNON4OCON==OCO#OCO2O#O14O
# 1411. CNC12CCCC2=
# 1412. (o==ON))(O
# 1413. =1F=1NO
# 1414. <CCCCC1NC2O)C
# 1415. <NC=)CC)COCCn13O
# 1416. <C=1C=2C=2=CC)CCC1O2
# 1417. <CC12CCOOCOCCOC1
# 1418. <C(1(C3n1)1CCC1
# 1419. <CC(CCCCCC=C)#N
# 1420. <C=CCCCC1O1=13O
# 1421. 3)
# 1422. 2H-)O#OOF11
# 1423. HF<NNC++cn<<H<2-<<<1<<-<<3<NcCc<[<<5N<<<<(c5H3<<<<<=<<--[5o+<<<<<N5<cC<-C(-<<<n<<<<)1+35<1<<<<<<5cO[
# 1424. <CCC1(1O)=)222
# 1425. <CCCC21)2CCC11=22
# 1426. #<CoOOCC))1C)OON2
# 1427. =(O]1(#35-]<54)<<<<<=<5<)<<<<<N5<<<<<<<<<4<o<<<<O<<<<<<<<<<<<<<<<<<<o<<<<<<<<(<<o<<<<<<-<<<<1<<5<<5<
# 1428. =NOCC(C(CC1=)O2O)C3
# 1429. 5CFC
# 1430. COOC
# 1431. 2
# 1432. 1)C1N1
# 1433. FN2=1OnC1OOC#
# 1434. C12O1
# 1435. H(4
# 1436. OCCC2C)CC(12C=C
# 1437. FOC1CCCCOo1CNCC2C
# 1438. (CCC(#NC=C1
# 1439. [CC12
# 1440. NC11O12CC1#N32
# 1441. CCCC1C)CNO
# 1442. [c]1=O)C1N
# 1443. <CN112COCC2N1CC2=
# 1444. O1+11=#1N=CNOOO
# 1445. <CCC14CON3)3=O312HO
# 1446. C1(CCCCC11C
# 1447. <N=2C(CC[C3CCOOCO)
# 1448. <CCC(O1CCCN=N1O12
# 1449. oCCCC)122CCCC1O2
# 1450. 4<-(1=
# 1451. 23CC(=2
# 1452. <CC12CC21C3C1)1#42
# 1453. ]c#OON
# 1454. <CC1CCCCCCC(OCC
# 1455. #CCCCCCCN))C#C1
# 1456. 2Cc#O1)==CC=O
# 1457. n##CC1CC
# 1458. C]CC)3C(C11))[NOO
# 1459. 4CO1NOOOOOO
# 1460. [N#
# 1461. <CCC=1CCOCCC1)O22
# 1462. <CCCCO)CCCOO322
# 1463. -5O(HC5)1(-F-c4+)((<5oFC(3-#-+c5<()<+(o5<<(+o<+O(<F<--(<<--<<<<<<<<<<<<<<<<<5<5)(<<C]<(<-o5+<<<<<<<<
# 1464. <NCCCCCC=C2
# 1465. <CC1CN1CC2OCC1C1=
# 1466. <NCCCCC=COCC12
# 1467. <CCCCCCCON=NN=
# 1468.
# 1469. <CCC12C2C2CC))12
# 1470. o3OOCCC=N1C#11C#C)
# 1471. ]cnCcN)HH
# 1472. cC11C)(=C1NCCC1CC
# 1473. <CC1OCC1N(C)ONCC
# 1474. nn
# 1475. <CCCC=)NCCCC)C1C3
# 1476. 2#+#O
# 1477. <CC12CC1CC)(OCC#1N
# 1478. (-5oc<-5n<3o+[<nc)<<<5H5<O<<<<<<H=(5o<<<<<<<<<<<5<<nn<<+c<-<ccH<<<<<5<<c<<<<<-<<55<<<<)<]<<<<<<<<5<-
# 1479. #COHFC(4=c]nc-#52CFn4H+]n])--o-)n)[[3n-)n+[c-(-5]F-CH[55co-[ncHFc5HH4
# 1480. )O2=CCC2CCCOO1O
# 1481. <CCC)CO3C(12C2)#
# 1482. <CC11CCC1CCC2C)
# 1483. #2#1CO
# 1484. [cFC
# 1485. <CCCNCCOFCC#C2O
# 1486. )CCO1CCCC=2NOCC1
# 1487. +F4
# 1488. (FOCCCCCCCOOOC
# 1489. =CCCCCCCC=1C
# 1490. <C#1CC#C)OC=C=O2=3O
# 1491.
# 1492. <CC1((nC=(1O)
# 1493. CO#1=]ON
# 1494. nCN#CNCCCONN))1
# 1495. <CC=CCCCCCNOCC
# 1496. -<C1C2C=(cOCOO
# 1497. N1CCC1CNNC2=11
# 1498. [OCCC41OCCO
# 1499. =CC2CCONO213#11
# 1500. OCCC11C2=CO
# 1501. <ON1NC()C1C#1CC)C#
# 1502. ]#2=O#
# 1503. <C#NC1CCC(CCOO=2
# 1504. <CC21CNC2COOC(OOC
# 1505. [4=-N1=(NCCN
# 1506. <CC1C=33N1CCCC
# 1507. c-1][[-F-F]3)]F[)cn]5H=+[51nH35oH]o-#o4c54Fn]n-n]4[cn
# 1508. ][C2CCC1COC1N)2O
# 1509. <CC1CCCCCC(23CF1
# 1510. (]][[]ONCCCOOC3
# 1511. ][3#]C1(+43[+O
# 1512. 2oCCOONO=)
# 1513. <CCC12CCCNC1(C
# 1514. <CCC1CO1OC2
# 1515. [+12HOHCOO==
# 1516. N)C=O=
# 1517. 53525Oc1<[-+<<Hc35<c45n+-<<<+<<<<<<<o<(<<<55<<<<5<<<<o<<<C<o(<n<<<<<<<<<#3<<<<<C<<+<<<<]<F4<<<<<<<<5
# 1518. )C((CCC=1CC2COC)
# 1519. <CCCCCOOOC=1C)
# 1520. <-+1C2CNC2C2
# 1521. )1C11CCCON)C21
# 1522. 3)-oF[(O=N==CCC1NCO31=
# 1523. <CC1CCOC1CC1CO#O
# 1524. <CCC2C1OOC)O
# 1525. HcN535-(c+nNc[[<C([H1(11C
# 1526. O[C1O1CCC(1COC
# 1527. cCC1C)OOCOC-
# 1528. H
# 1529. O]#55C5]=o]F#nn<5(c4]+<(<<+<o(5<41-(<<<<c[5<n4n<4]Hc1<<+<<[<<<<<<<+5<H<nc5n(<Fn[<3<<<<-13<<<o<<<<<<5
# 1530. 5CCC(CCON1CCNC
# 1531. FOCC(C12CN)COC#
# 1532. c+1C2C=2
# 1533. C3CC#)]5nO)<C<#)[<((<<<<N<<<4<<<<<<5<<<<<o<<<<<<<<<<]<<<<<-4<<<<<<<<<<5o<)<N<<<<<<<<<<<<<<<<<<<<<<<<
# 1534. <NC#C(2(CCCN212
# 1535. 5n
# 1536. O[OCOC)C1OCO)
# 1537. 3
# 1538. <CC(1OCC#(()12OO
# 1539. F4o[
# 1540. OH2O1
# 1541. c)3#2#NO1O
# 1542. <CCC1=CCC2(
# 1543. <C1C1#N21)C)O1N)
# 1544. <CCCCC211C1C2NO
# 1545. cc((1N()
# 1546. oOCC1CCO#C)2
# 1547. [(#c1c+[c[n)C+]c5nnoH2=5o<]-o5no<3FH(5(---c(2H5o]n5n<]oc+F(<<<+o<-<<(]ncNc[+o<H+3ccc#<o5n<)<n<(H]]c]
# 1548. <CC1CCC2(CNC=212#
# 1549. OoOO=O=)#
# 1550. 25-+N=O
# 1551. <OCCC2CCCOC))=CC
# 1552. <CC1CCC1C12O=1)
# 1553. #HNO=11C1
# 1554. +CCO)OCC=(CC1C2
# 1555. 3(-nON)OOCOC3=
# 1556. <CCC(CCO=(CCCO)=)11
# 1557. 1F(Hnn<+OC=C11CC(33C
# 1558. <CC1C=C)=CNC1
# 1559. <N#N1NC(CCCC#C
# 1560. <CC1C1C(2CC)CC
# 1561. )3#5#1O2
# 1562. ]OccnCO)2n2[)3N
# 1563. <ONCCCC(=CCNC=21
# 1564. <CCCCCC)CCCC2CCC
# 1565. 3O#OO=1OO#
# 1566. <CCN1)O31=CCCC))O2
# 1567. <C1CC2C(C2C2C=#
# 1568. (OCC12O11C3CO
# 1569. <#N=CO((CCC31
# 1570. <C1c13CCC2C
# 1571. <CCC(2CC1C)1)2])
# 1572.
# 1573.
# 1574. HCC1NCCCNCC1=CCF(C)N1)NO2
# 1575. O-CNC2C(12CCCCC(N#1
# 1576. ]NC(1N2(COO2
# 1577. <CCCCo=3C312N2C11
# 1578. o<CCCCONC31N2
# 1579. N
# 1580. <CCCC=(O1C=2#3])
# 1581. <CCCCC#CC1C)O2CCN
# 1582. <C#1CC)CN1=1C3NC1
# 1583. #
# 1584. <C#(1C2OC#C1)C1N
# 1585. <C=1OC2C1NC##21
# 1586. O1ONCO=
# 1587. 1[4+5N##C2C
# 1588. ==CC1CNCN1
# 1589. <CC11C((2C)H=CC1)
# 1590. <C=CC1C1C1NCCC)
# 1591. cC
# 1592. <1O=1C2C(CCO1C)
# 1593. Cc
# 1594. <CCC2CCC(C=)C)C)C1
# 1595. ONCO1=CC#O
# 1596. cn]4oc<5
# 1597. n4CCCO#O#NN4O=4
# 1598. =-2CO]=
# 1599. <C1==COCCC1N1NO3
# 1600. <N#1C)(C2=C4C)O1O
# 1601. #]C=2==2NCC2)+1
# 1602. +21CCC#C
# 1603. )3C#O##ON1
# 1604. [(133[Oo1F24)+O](5c+N5c1]<(n2[C<1c<5F+<3o<+<F15##<<[<#(<22o<(3C<<+1-(++<5(<3Nn#]3]<(<<<<5<<<155c<23<
# 1605. <CCCCCC#2o12214NC2
# 1606. =C1OC11N32OC2
# 1607. <CO131C1CCCC3C1
# 1608. <CC=CCC=)C1CCCCCN
# 1609. OCN#1C2CC1C=1NCC
# 1610.
# 1611. =C1C)#C1CCnO
# 1612. <OCCCC2CCC(C=O2
# 1613. <CCC2CCCCo)OC=N
# 1614. 5CN1CN2=CCC2()1
# 1615. cn3-ON#[
# 1616. <CNCC2NCC
# 1617. <CCCCCCO)12(#1)
# 1618. <CC1COCNOCC13CCOCO
# 1619. )FCCNCC2
# 1620. <NCCC=1OC2O1
# 1621. 11]=(O#
# 1622. <CNCC=3C2)COCCOO
# 1623. -CCC1CCCC(NC12
# 1624. 2HN#()CCO1
# 1625. <C11=(CCC1OC)OCO
# 1626. [51CN=N)(3CCN[OO2)NC
# 1627. ]=NO1#C3CC)
# 1628. <CC1CCC2CC)NOC==o
# 1629. <CC1CCO=)==O)CCC2
# 1630. <<CCONCCCCCCCO2
# 1631. +N=C#NO21C
# 1632. <CC1211NNC=OCCNC1
# 1633. <CC111=CCC2O1C21
# 1634.
# 1635. <#C1OCCO3
# 1636. O=on]#=ON1F#
# 1637. <N1(nCCNCC(21)
# 1638. <O#C1CC](C12
# 1639. <C=C[#CCC(OC1C)C=3
# 1640. <#CC2C22(C)C11
# 1641. <CC11COC1CC1)3N
# 1642. ]-3+1CCCC#=1CN
# 1643. <CCC1CC2C)CC)OO#=
# 1644. <CCNCCCCCCCCC#C22
# 1645.
# 1646. <CCC12COC2)C=NC=
# 1647. 3CC12OOO)1#O)C2
# 1648. <2CCCCC2C2C21CO
# 1649.
# 1650. HF1#=#=##2)1
# 1651. NOC(CCCC1CO11
# 1652. <CC1(CCC2C)C2(C)C3)
# 1653. [5FN-H4<=4c<n5<<n<[<<<C<<<<<n<-<o1Hn<-N<n[<<<<<5<<<<<<<c<+n-<<<]53<-<<n<]-n<<<<<<<3<<<<<<<<<<<<]<<<<
# 1654. <COOCC212OCCCN)O1
# 1655. <CCCC(CCOCCC21
# 1656. <CCCCCO11CCCOC#C)1
# 1657. <CC1C=CO1C1CCOC2
# 1658. <OC2OCCC=O2C11
# 1659. HCN=CO1NO2#
# 1660. <CCCCCC1COC#CO11
# 1661. <C#11O)1C==
# 1662. <CC1C1CC(CCN)N22
# 1663. <c-n[H
# 1664. FC#1(2CC2N1C)#=)OC
# 1665. <OC1NNCCOC(C))(=11
# 1666. <NC=C(C1)3O=
# 1667. <C1112C)(C(CC33NC
# 1668. <C=12CCCC=C(COC3)
# 1669. COCCO#C1(23O
# 1670. =CCCCC)2OCO
# 1671. F[-1+#]3)1
# 1672. 41#1OO#
# 1673. 2O1CC)O1C#[
# 1674. <CC1C3C1C)CCC311#
# 1675. 1n
# 1676. <C=CN==1C=2C=CO
# 1677. <C=C(C1CC=(C1CC)#2
# 1678. )O44C11
# 1679. O1]3]=54-](=1+55n3F<n=3[2=(-c+(<<<<+<<3<+<F#<<(<<<<n3<<5c+<+5<+H<5<c-<45F+<<<3F<3<+<<5<H5--F<-F<O553
# 1680. 32[==ONOO#OC=
# 1681. <CC1CC(C1CCCOC1O
# 1682. 2o4-O
# 1683. <C11CO)11)N111C2=)
# 1684. <OC(C3CC3CCO#1)1)=NOC
# 1685. <CC12#C(11#CCO11
# 1686. )-)5n
# 1687. <CC(1CC1(1C(==1)=
# 1688. C#C23CCCC1
# 1689. <CCCCCCC1=C())3
# 1690. [o]
# 1691. 4==CC=1
# 1692. <CO1C(CCC2))OCCC
# 1693. <CC((CCOOCCCCCCC2N
# 1694. #3C]COCCCH=)1
# 1695. <CC#CC1CCC)CCCC
# 1696. ]5n3F=CN=O=
# 1697. CO2O4NCO1N
# 1698. (=CCO2COO=
# 1699. CC=)O1O=N#
# 1700. #=OC1N(CCC()C4
# 1701. )[N12=2C2OO
# 1702. <CCNC1=C)2N(C3C2
# 1703. <CC11CCCCC2CO(CC1=2
# 1704.
# 1705. <C=CCOCC1)2CC2OCNC
# 1706. C#OC#(=CCN1
# 1707. )-C)(2OCC=CO2CC=12O
# 1708. O=CC(CCCCC)3CNO
# 1709. <CN1CC1C3)N(CCCC
# 1710. 4[nC-H(1N1O1
# 1711. <CO(1(232=C1=O
# 1712. 2#C111O=C21
# 1713. cn=[]cH[FcFo<5[5c<H[CcccF-cCcHno<(oc[<<n[n(n]o++no)<[c]5n5255)nHc(3c5ncnn(4]+[+cc(N]4cc]n+nCn<c5c3c]
# 1714. (#--1N1CO1#
# 1715. <CC1C(C1C1((=O
# 1716. ++1COCNO##4N=CC#N#OO#OO===O
# 1717. =NN<1[F<[<<cNC11)CC))2CCC)C24C
# 1718. #3#-cn51([4(--+n<-+4+[5H3-c]on<[4<5+55o3<<
# 1719. <CCC(1CN121C)C=N
# 1720. <CCCCC1CCC1=CC122
# 1721. cC=NCO
# 1722. <OC1CN1CC=CONC11
# 1723. <CCCCCCNCCO2C1C
# 1724. -=CCC=COC
# 1725. -#cn43[<F[cnnc-[ocn5c<cH]553[5nFc
# 1726. <CC1112N2)3
# 1727. =4]3-41cC1]oc+-5+(5]on<<<<5(cC552(o<cn]cF<<<-<<4<+[5<+Nc<5
# 1728. <CC1(()CC)C)CCO
# 1729. 4O5[3CC11(
# 1730. [CC1)2CC1CCC)C
# 1731. <CCCCC=CO)CCN
# 1732. C4=11CC)2)
# 1733. 1H]]#OC
# 1734.
# 1735. <CC11CCC3COCNO2
# 1736. (F(C5<2=<[]]2<25<<<<<5<5<<<<<<1<<C<<<<<<<<<<<<-)<<<<<<<<F<o5<<c<[-c<<<<<<<<<<<<<<<<-<<H<-c<<<5<<<<<<
# 1737. 1#]=(CC1OF2
# 1738. )CNHCCCC(CCO1C2[C2)=
# 1739. 1o]n
# 1740. -O#C1C)CCOCN
# 1741. <CCCCCNO)1C1CH)2
# 1742. #n]=O1O-(c(o(](54
# 1743. <CC1O#CCCCCC)1CC
# 1744. )COCCC)CC)CCO
# 1745. <CCCC1H=)1CNOC122
# 1746. <C1N=(CCC3N))
# 1747. =
# 1748. <C11CCO1C(NCC)C
# 1749. <CC1CCN1=COC=OO422
# 1750. (FC#CNC1N2
# 1751. <CCC=CCCCCC121
# 1752. F[o)2O
# 1753. <CCN=1CC2(1)1)2
# 1754. <CN(C(C()C1CC)C))
# 1755. <OC1CC(O3CC)=CCC1
# 1756. nC4CCC]NN
# 1757. <OCON4COCCNN(C112
# 1758. <OC1CC1C1C(CCC
# 1759. 4#5(]cc[cn+Fn]Hn4oo-[[5cn1[oo[nH-F[3c4nn+Hn
# 1760. CncH=2C
# 1761. <CC1C())C))2)211
# 1762. <C=121CCNCO)OC3
# 1763. <CC1C12CCCC1)CC11
# 1764. <CCCCCCC=1C2)C
# 1765. <CCCOOC2C)=CCC11N
# 1766. <CC12CC1CCC)#1
# 1767. )1)12#C3
# 1768. <cCCC2CH2C1CO
# 1769. 3n4
# 1770. 4
# 1771. <CCC=OCC3CCCCC2111
# 1772. <CC1(C2CCCCCCC2
# 1773. <CCC(C=3CC33CO)C3CN
# 1774. <5C1CCC2C2O
# 1775. <COC=C=CC(ONC3CC
# 1776. <OCC12CCO2NC=N)2
# 1777. <CC(N(CC=1CC1C)N
# 1778. [C=C23CO=OCCC
# 1779. H#
# 1780. <CC1(C)CNCC(C1+(C2=
# 1781. <CCCCCOCCC
# 1782. <C11CNC=1=1CCHCCNN1=
# 1783. <OCC1CNCCCCCC2O
# 1784. <NC1H31NCCC(NNC2
# 1785. 5cn(]-<nNF5<5<=<+(]o5c<<<4<1<<<5<-<<<3-<H<<<5<<<<-+H=[<<<o<<co<<c<<<<CC<)O<<<n55<3-<5<<<FC4c+FC<<[<(
# 1786. <OC1C22COCC)11C
# 1787. Cn4+55-(3CC=CC2(CC1)21CC1
# 1788. oO11CO=)2C1ON
# 1789. <CC1CCCCCNNC
# 1790. oc1)=1C
# 1791. 525=-C#=(12-
# 1792. <CC1COCC=)C1C33C22
# 1793. cCCCCCC1=C#CC1
# 1794. <CCC1CCC1N3(#1#
# 1795. ]C1N=2NCC=
# 1796. n-+]CCOOO2
# 1797. nCCOCC312
# 1798. <CC11CO2OCC1)O)
# 1799. C
# 1800. HCCCC=(OOC113(1N
# 1801. ()5+4#NC1C)2=
# 1802. 4CC1C))CCCCC22O
# 1803. <N(1CC(((CCCN)C)
# 1804. OCCCOCCCCCOCC#)1
# 1805. <CC11(CCOCNCCON)1
# 1806. C1OC2#C=C#C1
# 1807. -+3CN=##1NOO]OOC#O=
# 1808. OF5NF
# 1809. <C11CCCO(C2COOO21
# 1810. <CO1CC=1CNC
# 1811. <NCCCCCC(1COOO
# 1812. #][
# 1813. <CC12CC)CCCCC=21C
# 1814. <CC1CC(()C=NO=
# 1815. <CCCC1CCC)CNCC=C
# 1816. <CC12C2C)CCCCCN11O
# 1817. <CC(2CC=CC
# 1818. 5[#
# 1819. nc[C1O()(C
# 1820. <CCOCOC1)1)CCO2CO)
# 1821. []#CO#=
# 1822. <CC12OC(=CNC((NO31
# 1823. <CC1O3(CC2)))CO=N
# 1824. <O1121O2)On12
# 1825. ]2=nN3c5]5-o5+nF]o5n]4cn5oF
# 1826. <CCCCOO1(C1C)O
# 1827. <FCC(2CCC)C)1
# 1828. cNno)#F(Fn-<]FC11OFC1
# 1829. (cN#+
# 1830. <OC12C1C)NCCC=2N
# 1831. -c(n5F5<[-4<H<<o<<+c<nNon4cHc[ncn5n11#N]
# 1832. <OCC)CC)(1NCC=O
# 1833. NC(N2
# 1834. [CC1CCOCOC3=O1O
# 1835. 43OO#]O1C]O11O#
# 1836. [CCCC1CO1#1
# 1837. (CCCC=CCCCC((N#CC
# 1838. ]
# 1839. <CC112OC1CC1C)(==122
# 1840. OO[=C223)1OC
# 1841. 4=n]-HNOCON
# 1842. <CC1OCCCC2CCCNCC2
# 1843. CO[(((5n<-(++FH15(<<<<<(<<<<55o<<<<<<<5<<)H3<<<<<<<<-<<<<<<<<<<<<<<H<<<<<<(<<<<([<<<<<)(<<(n<<<<<<<<
# 1844. NC=CCCCCO31CO
# 1845. =1H42(((]
# 1846. 141()[NCC#1C1C1CCCC#=#O#C
# 1847. 1#N#NN1C#1O
# 1848. <C=1==C1(3C1CC=2
# 1849. 3)NcHO-OCC#
# 1850. -N1CCC()12
# 1851. H=1cOC2NO1ON
# 1852. O1N)[=1=[#C
# 1853. CCCC1CCON
# 1854. <CC11)C2C1CC)11O
# 1855. <CC1(OC1C)N)C1OO
# 1856. H111CC2=##C=
# 1857. <CC1((1C)3CCCCCCO1
# 1858. <CCCC12CC))(C(1C1
# 1859. <CC(CNCF23=ON#
# 1860. #F5()--H(HcH]+nnHon5(n1]4]2cH(]N354-4c]]
# 1861. HNCCNCCC2N==1
# 1862. 3CC1C=(N1O
# 1863. FF(nC[-(coo]-no-5(
# 1864. <CC1CCNNNNCOC)C(2O
# 1865. <CC#C1C2CCC)CC2
# 1866. <C1([1c1]1C#ONNC
# 1867. <NCCO(11C=CCNO2
# 1868. <CCCCCNO3)CCC=22N
# 1869. (FCCCC[(CCC11#2
# 1870. on
# 1871. )OC1112CO1C(
# 1872. <CCCCCCC1CO#CCCOC
# 1873. <CCOC(C1C(CN)C=)ON
# 1874. <CC1C2C=(C(CO)C
# 1875. <CC(2CCn)1OCCCC3
# 1876. )OC1CCCN2CC=C1CC1
# 1877. F[#CCC(CO)=C
# 1878. C-5+]Onc-F5c5
# 1879. <NCOn1OCC(=)CO
# 1880. <OC1CCC1C)C2NC3
# 1881. N+
# 1882. <COC12CNCCCCNNN
# 1883. <CC11CNOC)CN
# 1884. <C=CC12=2C1N=2
# 1885. <C#1)CCCCCO)1NCC
# 1886. HCC1COC22NO21
# 1887. <CC1CC12C)(C==C]CO
# 1888. <CC=1)CC(COC)2
# 1889. <C=C1(CC312CC#2
# 1890. C-OO)CC
# 1891. ON1((2NCCC(C1=CC2
# 1892. <CCC(CCC=(2C#N111C42
# 1893. oCC1211NOC=2)CC
# 1894. <CCC(CCCC(1O1)23O
# 1895. cc#1=CC#N
# 1896. <CCCC12)=1NOCC2O2
# 1897. <C)CCCCCN1OC)C13(CC2
# 1898. <NCCC(CCCCCOCCNO
# 1899. 4-C(CC)C)N2N1
# 1900. <NC1=NC=C3=O)=
# 1901. ]+-+45-55C2+34<5NH
# 1902. <OC(CC21CCC
# 1903. O+11OOC#O
# 1904. =N1nOcO1114O
# 1905. +CC1N=CC1=1CCC1=
# 1906. (C11==CC==1C
# 1907. =)CCCNC#2)C
# 1908. <NCCCCCC
# 1909. <OCCC211(C32CC1)
# 1910. -2N1)1N=N1
# 1911. F
# 1912. 4
# 1913. 3CNCC2#O#11
# 1914. <CC(1C))C)C)11O
# 1915. C4
# 1916. <(11((CC3CN2CCOC
# 1917. <CN1OC(=CCCC2)2
# 1918. #-OCCCCC+2C
# 1919. 1NO#CC1CCC
# 1920. (+=C1)1CCC1O=O
# 1921. <CC12CC(C=OCCC)
# 1922. 34=
# 1923. #
# 1924. 3cCC1C131COC23
# 1925. <CN(C(1CC=CC222C#
# 1926. <CC1CO2CC21)1))C=
# 1927. F((F[c(5(c5+H515<-H4<]54<55]c4-c(55o<on<<4[<o<<+(<c2554+]<<<<<55(5(<<n<<<[H<c<<5o<nn<<<C<<<]<<5-c+<<
# 1928. C-++#=1O
# 1929. cC1C#2CCCC)CN
# 1930. [
# 1931. on=n(OC
# 1932. ##CC##1CCN2
# 1933. <CC11C2=C)=()O=C
# 1934. +CC1OCCC1N
# 1935. 3=NCOCOC)N
# 1936. <CC1C23CC(C2C)#
# 1937. <CC=CCCOCCCCN)=222
# 1938. <+115+1(1+25F+F+(((5-[[525(=2-
# 1939. nCCC=CC)1C2
# 1940. <)c1=3NC(O()OC1
# 1941. #)-=55o<<5<<<H<<<3#-c<5++o5H=]c(<F(+55<5<<35oH(c<-<5<n<55([+5-[<<--[4<4<<o]<[++[cH]+55<-<5co[<n<[<+C
# 1942. 25(3=FCC)2#)1N
# 1943. oO(CC=N(CCC1
# 1944. +o(
# 1945. FCCCCC1O))O=
# 1946. OC#CCCCO)CN)11
# 1947. <CCC=CO13CCC1)N)
# 1948. <CC1C(CO(2COC=C=
# 1949. <CCCCCN=)(O3
# 1950. <CCCCCCCC1)12CON
# 1951. <CC112C)()1COCC11)
# 1952.
# 1953. (H=N3o]=+3H<<FF[5<-<<)O5<52<(C<<H=<Hc<5c<<5H51]<<<<<<c-o[<5-<<+<<(<(<55<-[<[o<<<<<H<<-+[<5<<H[<-<<5<
# 1954. (5-2-N=C=N#1
# 1955. n=oCNCOOFO
# 1956. CCC1=2C))CNCO
# 1957. cCC](n)NCNN)
# 1958. <CCCC=CC(CC3OCO=CC
# 1959. ==1N=11#))
# 1960. +#-O1C
# 1961. <CC1C=2C2OC2CC#)
# 1962. <OC1C(CC=1CCC
# 1963. <CCCC)#COCOC1=)
# 1964. ]F
# 1965. <ONCCC=O11CC=1N2
# 1966. 5CC11C#CC1CC))==1
# 1967. <#CC1CCCCOCCO
# 1968. =N]H
# 1969. <cC1CCC1CCCC=13
# 1970. <CCCNNCC(C)OOC=
# 1971. <OCC2=COO=C2#
# 1972. ]nNN213CCO1
# 1973. <CCC2CCCC=NCCCCOO
# 1974. -
# 1975. nF]1N3#5#=N=#C
# 1976. -H(On(Oc1FC1NNCC)OCC)=
# 1977. <CC11CCCCC33OC)2O
# 1978. <CCC1=C2OC
# 1979. <CC1CCC12(C2C2O
# 1980. OcC1(C)#C[=CO1
# 1981. <COCCON21C(C1OC
# 1982. <CCCO(O=CCC(C=N
# 1983. <CCCCOCCCCNNN1C2C2
# 1984. ]OC1COCN3
# 1985. <C(#C2CC1OCCCO
# 1986. <OC(1CCC
# 1987. <CC1C1CC1)(O)2CC1=
# 1988. 4
# 1989. <CCCOCC11NO3C1
# 1990. <C11CCNCC)C((C21
# 1991. =-NC#CONN
# 1992. HC4=1
# 1993. 4o11(C1CC=C
# 1994. ==-5N<3<
# 1995. F)
# 1996.
# 1997. -([o34]o=
# 1998. <C)11(OCN1O
# 1999. -OOCCC)N3C2=N2-
# 2000. <C1CCCC12CCOC=1C)N
# 2001. #(2()
# 2002. <C=C1(=C3CCCCCC2C
# 2003. <C1C=2CCCCC=CC=22
# 2004. <CCCCC2=#CNCCCC=C1
# 2005. <CC12CCCC)CCCO#C1
# 2006. OCC1OCCNCC1=CC
# 2007. <=NC11C13C1O)
# 2008. <CC1#1)OCC(C=1=O=
# 2009. <CCCCCCC)2)COC
# 2010. ([]34c
# 2011. +CCCC11=)OOCNO
# 2012. 4CF1C((NC2#C#1
# 2013. #oC)(C
# 2014. <CCCNCCONOC)CC
# 2015. <#C=C#COCCCC
# 2016. #)=)-nHnH+nC3n5o+45H4#o5H5-5+4
# 2017. 2F+-1O=1N21NO#
# 2018. CCC11CCC1(#1
# 2019. H4oCO===NOC
# 2020. <OC1N=OCC=CCC1FCC
# 2021. <CC1#()CO12)C
# 2022. CC(N1CCCN
# 2023. cnNCC111CO=OO
# 2024. =
# 2025. <OCO=N1NC)=C2C#=2
# 2026. )
# 2027. <CCCCCC=CCC)C3=1
# 2028. O=
# 2029. F24
# 2030. H#5
# 2031. <C=1NC=OCC2C#)11
# 2032. CFNCNNC
# 2033. cOo1CONCN#N
# 2034. C3NN=1O3ON
# 2035. N2CC1O3C#O2
# 2036. )[3o33(+-ocn[F=)][]c55n-(N-H-n<[+H<n<-[N]+545<3c]<-++[c5+nc525FoF-3c5-<-o]-<=cc][+c55-nn[5)n52n]+-5<
# 2037. <CC1CCCCCCC=4C=C=
# 2038. -F1(=]oc-<4C54[)<<F<+2<c<2<<F<<-c<[<<<1<<(<<<<<n<<+<<C<<+N<<<<<<<<<<[<(<<5<<<5+<535<<<<n<5<<<<=<<<<o
# 2039. c]5F+oH#+-oH(cn-[5cCo)+5O[-[(4c53]coc5+o3+o5H4cc)]oo(<5<+-[5+455o[5)<5FFn<n-5C5nccc<5c)-o[]nN-5c5]53
# 2040. NcC1=C22
# 2041. O-(N
# 2042. =+n[#251#2C1##O#
# 2043. ]1C3([5<<<(<<<<<<n<<#[5#5F<F3<<<5<<<<OHnn<54c<<5+<<<<<c(OcN#+c5<<[<[<<<<C+5(1+NFO[]cc5<<<<<<<<2<<((C
# 2044. [5O==O
# 2045. HO1(
# 2046. <CCCCC1(CN1CCC)
# 2047. 23CCCCC)1=CO#222
# 2048. <CCC2CC1CC1)C21
# 2049. <CC1CC=CCC(CC=1=1
# 2050. no[C+(OH+5n=]]O3]14]35c](=3N
# 2051. <NC1OCC2))21C2O
# 2052. )nNC#=C
# 2053. (CO1CO2OCC]2+O)
# 2054. <CC11OCCCOC2CCO
# 2055. <CC1C12CCCC3N)31
# 2056. <C==CCHC1)NC=C)
# 2057. <=CCC)CCCOCCC#
# 2058. <CC1CC)CCC1=#)
# 2059. C4C1==(CCO1
# 2060. 4OC11C(CO1C11#
# 2061. <CC1COCC1OCCO1
# 2062. <CC1CO=CC31C1CCOC3)
# 2063. (CCCC1#NCCC)O
# 2064. <CC1CCCCOC2O1
# 2065. <CC(CC=1)CCN2)31
# 2066. O-(CO1O#O=2O
# 2067. <CC1(C()C)(CC==O
# 2068.
# 2069. <CCCC(CCC=C3C
# 2070. <CCC212NNC))11
# 2071. <CCCC1C)C=CCC#
# 2072. <CCC((C(CCCC(C1=CCO
# 2073. <CCCCC(1CC=CNCCC)
# 2074. 2]o1C#
# 2075. <CO1CCC)NC1CC()323
# 2076. <CCC((2C(3=C2C=
# 2077. <2#11(N31CO=)=2C
# 2078. <CC111CC)=CC=21
# 2079. <CC1(O))C=CC32C
# 2080. N=#OO]OOO
# 2081. <CC112#(NC(C1NC1)2=2O
# 2082. N
# 2083. FO-4OOOO[OF
# 2084. <CCC1CCCC=(C=#(C
# 2085. [n-n-O+FF=1
# 2086. <CC1CCC2C1CC)4==O1
# 2087. ]1C#==C1
# 2088. 1NF1C#N)##=2N
# 2089. Co
# 2090. <CC122(=CC)C)CCO
# 2091. <OC11)C2C2C)C=2CC
# 2092. F[OH
# 2093. +CCC)C1=C)11N2
# 2094. <CC11C)CC(C2C=C
# 2095. <CCCC(CCCCOO11C2
# 2096. <#1C()1CCC2ONCC2C
# 2097. <CCCCCO11CC)C
# 2098. Cc
# 2099. CN
# 2100. <4C1CC1CC)CO1O]
# 2101. <CC1CCNC)CCCCC1
# 2102. 3N4))-=OC#O
# 2103. o4N3C#=ON
# 2104. c5+
# 2105. <OCCCCCCC)CCNC1=O
# 2106. <N=oC2NCC)COOC)CO223
# 2107. 1C]5CO1CCCON)NC
# 2108. -()O1#5c[)C5[<n2<H1HH5#o4c5on<<o<c<n(H<(n41--+52o<<45[H<N(<<o<H<4(+c(<1On2[<5[-+<H=o<54<+55-oF5+c5+5
# ...
# 9317. <N((CCC1CN1=CC11C2
# 9318. )=cN1)
# 9319. 334-[5]4CCC]
# 9320. HO=]n34F]nncc)o[
# 9321. ##C1(11FN2O
# 9322. <CCCCCCCCC=CCC2
# 9323. CC11#OC1C)CC(3=ONC
# 9324. =ONO1COCC1CC11
# 9325. 5-CC11CC11N2
# 9326. <CC1CCCCOC))2NO1
# 9327. O=
# 9328. 5HCCC1CN
# 9329. C#O1CC(CCCCC#
# 9330. -
# 9331. 1[oFFHcFcc144[5-5+351n11]n3ocH+3-n3[o1c]n(oc+(3c-)c-FH(+nn]Co52O5F4H4=215C15](2][4]3]+
# 9332. <CCCOCC=CCCCC
# 9333. <OC1CCCCOCCO=C111
# 9334. [1C1(C1OCCNCC2
# 9335. <CC1COOC()2=)C
# 9336. C[cCO1#O4ONOO4#N=O2N##O
# 9337. 2=FC#
# 9338. NCC1C()CC=N))N=OC221
# 9339. [O=C211)O)C
# 9340. 1c1CCC1)C11C3N)1
# 9341. <ONCC=1CC1C1C)
# 9342. O1144+o4
# 9343. <C1CCCCCCCCC=C111)-
# 9344. <CN1(2(=O1CNCC2)O1
# 9345. 5][1C1OC1C1CC3
# 9346. =oC#OC)CO11
# 9347. n5-H+NFH([[c-co
# 9348. 3n<OO#2H[1#<<<<<<<<<<<<<<<<<<<<<<5<<<<N<<<<5o<<55<[<<<<<<<<<<<<<<<<[<<<<<<<<<<<<<<<<<+<<4]<<<N<H<<<-
# 9349. Cc-3n#3--#)o-FnF(cc4(c+-[[5(ccoc(H[-o4Hc#o-5=#]H[o<+5)[(5nccH5con#]o]c5c+[5-[]co55]4F([+[+##Ho4n[45c
# 9350. CON1CC1C11C1C
# 9351. FCCCC3CCCCC1##2
# 9352. <CCC1==CC2)C
# 9353. <CC=OCCCO))1OC)2
# 9354. <CC((CC1CC(Cn1O22ONnOC
# 9355. <CCNN=CC1=)CFNON11
# 9356. <CCCCCCCC1ON
# 9357. O+#24+c-=[52c<-+5+<(+45]<<<<<<4]]<<-<5<<<<=F<<<<<<]<<<<n<<<<<<<5<<<o4<<#<[<<<<5<-<oH3<<c5<<=3<<<<<<n
# 9358. <CC=C1CC
# 9359. <OCCCCCO21CCCCO
# 9360. #n#N
# 9361. 4[NC[
# 9362. <CCC(C#O13CC11)2
# 9363. <CC2=CCCC1CC)C
# 9364. <CC11(O1COC=)CC#C2
# 9365. [+2OOOO==N
# 9366. (CCCCCCC11111
# 9367. 3CC1CC
# 9368. C5COC1)O=1
# 9369. <OCCC2CC)COOCO2
# 9370. <NC1CCCC1CCC2CCCO#
# 9371. <CNC=OCCC=CCC1=
# 9372. <COC1CC1=CC=)CO1#O2
# 9373. H#C11C1CCC(1()
# 9374. O<[11F
# 9375. CCCCCC1N1CO=4
# 9376. +On-1111OC1=C=(C
# 9377. Fo54CC(<<F[]<Hn<n4O[<3<C<<OF4<<HccccF<<<<n<<[<c<onN+NH=ccon5<c<<<<H[5][H(52[#5<[o#o11nCON)O1
# 9378. +n)nno]]oc5on55c)+1445F5oo5O5cCo5+[c<)H[HH5(o45[H5onF<c-=<ccC<<+F]+<cF[H5H-3<<-<<H-5<H
# 9379. <CC1CC(=CCC()NN
# 9380. H[+43-NH<55<H<<<<]o(5<<2-H<Nn<<<<<<3<+<<<<<<45<H<n<c<5<o53<-<<<<<<<H5<cc=C<cF<<<[]<<2<<<-<n<<<<c[n<<
# 9381. <CC12C()1oC2C2C
# 9382. 5H43NF1
# 9383. <CCC1C1C)O(O121
# 9384. )n2Nn-4)[55#3c5<3+<H-<<<<<<5-5-cH<o<+[(<<<<(5<45[<<55n<N<<<5(3O<<FF<o=[<o[4<<)<5]<]-N<<<+<(<-[<n5HF)
# 9385. <CCCC=CC1CN(21
# 9386. <CC2CC2CCCO3)21N
# 9387. <NO11O(C)NCO))C
# 9388. O=CC=CC=2#O
# 9389. ]+OO1
# 9390.
# 9391. <CC11CFOCOC+C)O
# 9392. <CC1CCCC)C)CC1(C1
# 9393. <C()(NO4nOC2
# 9394. 2=CO23C1=
# 9395. <CO)1O3OCCCCNO1O
# 9396. 4-#2
# 9397. <CCC12CC(O)=NCC)1
# 9398. =n-c<]<<5<[<<nno(O#11+<<<<Fn<<<<3<[<#NNno2[5n5<H]<c-<<<C=1OH(H4]]5(]<o<c[C1c]#CO=)C[=O2O
# 9399. <CC1OO=(1CC2(2)O
# 9400. H
# 9401.
# 9402. <CCC#CC33C2=ONC))(
# 9403. ==2#12
# 9404. #1O(11
# 9405. 3H5+<55o=cO1(O(122O
# 9406. n5F1(CO2)C2
# 9407. <CCCCC2CCN2C12
# 9408. c41C2OO
# 9409. <OCC#O1CCCCCCCCCCC
# 9410. )n]HC
# 9411. 3o=NC1O111
# 9412. <C1C1C=3C21C23CCC4N)2
# 9413. cCC11())CFCCC21CC
# 9414. CC=(#C
# 9415. ON]
# 9416. 2N=NC)CCOO
# 9417. <#NNCCCCC1CCC1OO
# 9418. <CC1CC=C(=)))=OCCCO
# 9419. )541c142CCo-[o--(-4(((5o5=<c4+1oc5+<o+<<(<<<55<H12o-<H#<)(H5((-<-c3cc+(5<[5<+<(o<(Cc<<<<3]<<-5<<-5(o
# 9420. <C]CHCO
# 9421. <CCC1C#3C=CCNO2O
# 9422. N#1NNOC=OCO
# 9423. (HOC1CC1OOCCN2
# 9424. 3)554=#O#1[31
# 9425. <OCCO)(CCC(N)NC23
# 9426. <CCCCCCC1C=)CNN
# 9427. CN2CC1#CC2
# 9428. =5
# 9429. 2CCCC1=CC
# 9430. -)CCCCOCO)
# 9431. <CC1CCCONC1CCCNN
# 9432. <C#1#CCC(11CN
# 9433. <CN12C=1=O=(OC=2C22NO
# 9434. <CC1C==C)CC2C23
# 9435. <CCCC2N3O11COCOCCC412
# 9436. <CCN1C2C=))N1
# 9437. =1ONCCCNON
# 9438.
# 9439. -OCNOOO1F
# 9440. n#C1C(C1)]=#
# 9441. <CN14)C)CCC1
# 9442. 42CCC(O#CC
# 9443. <CC1C22C1CCCC
# 9444. 5OCCOOCOCO1
# 9445. N4o]5c4-c([c[oFFcc5[o=FNnC14#1
# 9446. 3OC=C(CO1#=
# 9447. )oH-#FON2
# 9448. <==1(2=CCCCCCO2
# 9449. 3OCC1CC221#
# 9450. <CC11C2NCC31=C1
# 9451. <OC2#2OCCC))C3C
# 9452. H(1=
# 9453. <C#C(CCC)1CONCO
# 9454. [CCC=N1CC1C1(123
# 9455. <CCC1CCCN13NCCN)1
# 9456. <CC1COC1CCCNCCO#3
# 9457. <CC1NC2CC(CCCCOCC1
# 9458. <CC1C=CNCC11O=23322
# 9459. <CC(CO)CC#N4N212C
# 9460. <CC11C2#-CCC2C)=OC
# 9461. CN#CC2(C#
# 9462. (5FOC14O
# 9463. #CCCCCCNOC121O
# 9464. <CC1(1OCOC1ON332
# 9465. (25=4
# 9466. (cC1)NOCON
# 9467. =O#3O2
# 9468. <OCCC=C)OC1C#
# 9469. CNC=C2)1=C
# 9470. <CC1C2CO1CC)=C
# 9471. <CCO1CCC23
# 9472. <CCCOC1COCCCC(
# 9473. <CC1CC1CCCC=CC
# 9474. +
# 9475. #3FH3-[(
# 9476. ONC2CC=
# 9477. +On(ncnH-n#3+-+Hc]+35n5Fo(F(n[+15[(n4((nc4(n]F[c5n5F-[n[FHc<4n4]5c4n5o
# 9478.
# 9479. c5NCC1=O##CCNO=
# 9480. [)21113
# 9481. ]#=CCO12
# 9482. <CC1C)C12CCC)
# 9483. <CC1(1CCC2)NC(
# 9484. [NCO1C122N11O
# 9485. +NcC==COO
# 9486. <CC1(2CC3(CC)O=)=
# 9487. +=3#
# 9488. <OC1(2CC(C)CCC(O
# 9489. ]OCC11CNCC1O
# 9490. o4)o-5H=4535c]c1#5c[5FOco35cO)-4-N[[+5<<H+H4-c5554]<--+4n-55[cH<c<5cF[]F5F+<-55+Foc(oc5<c5[+[54o[][=
# 9491. o3CNCCOCCN=1O
# 9492. <N(N1CNCC1O=CCCCO
# 9493. NnCCOC)))O1=C
# 9494. Ncc1O2CN-CO1CC
# 9495. C2111OOC
# 9496. OCCCCCC2NN)C
# 9497. <CC1CNCCCNC1CCNCOC22
# 9498. C-
# 9499. CCCCC(3CC)N=2
# 9500. <O=1#CCCC()OC1C2
# 9501. [FH55o]
# 9502. <CCCCCC=C)=#C1C1
# 9503. <CC1C(23C=CCC))C1
# 9504. <C1c11OCCOC=
# 9505. <O1CCH#)NCNC)O2
# 9506. <CCCC(2)=C1)OC1
# 9507. 1-O4-=F#
# 9508. <CN21CC)C)C#CO=N)=3O
# 9509. <CCC(OCCC)CC33OC
# 9510. ON1OC#O
# 9511. <CC1CC(3C))CCC33
# 9512. <NCC=ONC311C=12
# 9513. <N##222OCC11=
# 9514. <H4C1=CC3N2OCO+#N
# 9515. 51CCCCC
# 9516. CFnOCCO1OO[21)NOC#2
# 9517. <CC1(13CC1COC21)
# 9518. )C
# 9519. Co(3-(=COc+114]+5<+<+c(255CO5c<-)1FO]+O<+<5nCF53<((<[<=N(5<F4]<On)4o(F(<H5<n2-4(O4-#[<<c-4<o=[FOcc1(
# 9520. <CCCCCCC=32CC1O
# 9521. cn+-4c]5H]]H3o5o1n]4ccHH[[n2+43<Hno]32nnc+<3c<3(]54<4o=cn]5nF[Hoo<<c5nHFocon3cn<<[32o3+<n]<+N3o]-nHn
# 9522. #2OC1N)
# 9523. O53=11NCCO
# 9524. <CC1CCCOC1=C)21C
# 9525. CF411=1C1
# 9526. 5C1(#1=
# 9527. +1OCOO#
# 9528. <CC11C[)CC2C=
# 9529. 3n5o[54#(NnF2o#O11=CCC
# 9530. 4(CC11CC=OCCNCCOC
# 9531. <CCCCCCOC1)=CC2O
# 9532. FOCCC==C(221
# 9533. <C=1CCCOOCC)C
# 9534. HCC=(CC1CCCCC2C3
# 9535. <CC1CCCC(CN1CCO
# 9536. <CC111()OCC1(OC
# 9537. <NCCC2CNO(CC2ON
# 9538. <CC#C2=CCCCCNO(OC
# 9539. c4C1OO=22O
# 9540. )OCNCC#1CC2
# 9541. 5[O1
# 9542. <CC1CCC1OCCCC1())=21
# 9543. +NC1C2C)=()1
# 9544. <C1CC(CCCCO=3#N
# 9545. <CC1O#CCCC)CCO
# 9546. (
# 9547. <<#=CCC1CC11)1#N
# 9548. <CC1CC(NCC1211
# 9549. +NCC2COCCCCN1
# 9550. H1=O1CCCC12H
# 9551. oc(C1(O))C(C(OCN
# 9552. OCC(CCC)C12C==12
# 9553. <CCC1CCCC2CC1C1#
# 9554.
# 9555. N]CCCC(CCOC)C
# 9556. <CC112C()C(1OC
# 9557.
# 9558. <CC1C2==CCCCC=CO
# 9559. (CC1C)N32C)=3
# 9560. c)F#441O1O4
# 9561. <CC1CCCNOCCC(C(O
# 9562. <CC1O1CC)C=(=)
# 9563.
# 9564. <OCC11CCCC
# 9565. )-#=H]
# 9566. <CCC)CC1CCC2C
# 9567. <CC1CC1N)CCC2N1
# 9568. OCNCOC1C3
# 9569. <CC1C=C13CC)C3N2=
# 9570. 1C-1O#C=
# 9571. FOC1C=CC=1O)2
# 9572. (OC#C)N11C1#3
# 9573. <C#CC2CN)CC121C)=1
# 9574. <CCC=CCC(()1)CC3
# 9575. -OCCCCCC)O3
# 9576. <CC1CCNONCC=CNCC
# 9577. #NO1C131
# 9578. )C#4OON
# 9579. 4-F5[+F=1#12COC1)=2
# 9580. <CCO1=C22O21
# 9581. nCNC1C=CCC(OOOO
# 9582. <cCC1C11C2NC=2CNC
# 9583. <CN1(3OCCCCCOO1
# 9584. 4#
# 9585. <C=(+C=C=12C)3CN
# 9586. <CC1CCC)=222[2
# 9587. (CC[OC)1#C=O1O1N
# 9588. OCCCC1C1C12CCCO1C
# 9589. c=C1C(211=N
# 9590. <CC)CC21CO(
# 9591. OCC1C11CC2
# 9592. <OC(22CCCCCN[112
# 9593. <CC1CCC2CCCCO2OC
# 9594. (CNCCCC121CN
# 9595. <CC1O2N(CCCNN1#CON11
# 9596. <CCC#C1CC3C
# 9597. NCCCOCoC1CCCCC)222
# 9598. 3=O##<2<+<5N<O3<<<<<<<-<<<<<<=<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<o<<<<<<<<<<<<<<<<<<<<<<<<<<<<<[<<<<
# 9599. -NO1CCCCNOC=)C1
# 9600. --Ho](Fco-<-#<<1<<<<c<<2<<<<<<5<c+o[4c#1CC(2CO2C(NCC)O
# 9601. <CCCCC3CC=C3CCC1
# 9602. n]]13]3FHNn]+HF]n5o5O5cc+NHcc14
# 9603. <CC1CCCC)C1C1)(
# 9604. <CCCC2N1CCCN
# 9605. #CCCCN1C=)C)#C)
# 9606. F[NN1(##1#
# 9607. <CCCC)C=C1NCC)OC2
# 9608. 5##1CCC#
# 9609. <CC11+CCC(O#1
# 9610.
# 9611. FCC-2=c[+33
# 9612. NN
# 9613. <]O#C=1
# 9614. 45nF15[nFo5on-+Hn(]Fco
# 9615. <CC#13CCC2CCC1
# 9616. n)cc5-2OO#42OC
# 9617. <[F=[CC11)1
# 9618. H(Cco
# 9619. <OO1OCCCCOCCCCC
# 9620. <C11121CC(11)O21
# 9621. NNF-15
# 9622. 3(n-4ncFo4cnCccn-Ho]ccoFcn[F+nnHHnHHcnF5-coon+co]-cNHcon[<nHccc-oc45c-oon-nO#C=(
# 9623. <CC12CC(=(CCOHCOC)N
# 9624. <CCN11CC)CC)#(C=C112
# 9625. 2OC1CCC#CCOCC31)C3
# 9626. <c=11CC21CO#11N
# 9627. 3
# 9628. (5OOOC=1
# 9629. <CC3)C)(CCCC(C)CC
# 9630. 4CNC=
# 9631. F
# 9632. 5-ONC
# 9633. <CC1N11OCCON)
# 9634. <C111CCCOC)2=O1C2
# 9635. 1cOO](
# 9636. Co]]-+(O12]
# 9637. 44)FN
# 9638. 2N##NC1O4C
# 9639. <)cCCC1CCNCNC
# 9640. [#F=ON
# 9641. <NC1OC5C1==#NCC2
# 9642. <ON1Cn2]On2O1cN
# 9643. <OCC(C()12)1OC
# 9644. <CC#COC=)CC1CCN2
# 9645. nH(F#C2C
# 9646. C-cccn+)2
# 9647. #2+((1cH1nO115F<1o5(+[o5OH[3+(4<(<<5-<-[(<(<<
# 9648. <CC111CO1CCC2CNO2
# 9649. <NC=CCCC=CO
# 9650. 1+c11NF#[#5C5n++[4-43c[4c3c[<c5Cccc<<4c-[(-<-5o-[o=-+c-<+o5<5<[-<-<<3c<555+[F+oH[<Ooo5[(c(5[-[<[on]-
# 9651. <CN1C1=CC#N2N
# 9652. =CC2C
# 9653. 2CCC1CC
# 9654. <CC12C1O)CC11CCOC
# 9655. OCCC=C1CCC
# 9656. (()H<-4+c5<<<H+[<-Hn<+<5<<n5<<54<H<co<<<4n<<<[CnN5<n+o<<cH5c[H<<<5<n<5<<o<5<2c<<<<n<c<<3<<<<<5<<<<<<
# 9657. ]nnn1]#OH4NC
# 9658. =cc(C#C(OCNC
# 9659. <CC1CCC))(CO2OO
# 9660. ]ONC1CC1=11)2C
# 9661. n[]N=C
# 9662. <CC1ONCCC])CCC1C=2
# 9663. FCC1CC=122O
# 9664. F)#o
# 9665. oO[3O2[oOO==
# 9666. o=OCCC21=O
# 9667. O#1CO1COOCC#C
# 9668. <CC1CCcC(]C(C=CC2
# 9669. C3n5o4C=
# 9670. <CC12C1N(())CCCCC
# 9671. <CCCC2CCC1=2N1C13C=
# 9672. <]CF2)CCC1)NNCCO
# 9673. <CCCO3=C)=O24)CO2N2
# 9674. oo]o-N4(No#]--c]([]H--F=4F=5+#45<NnHnH+<c[55o+]-<+<c55(c-5+n[5O<2+cHc-FFC<+o(<NC)3c<5<+355-(on+nHcHc
# 9675. =OC1#=#C#
# 9676. <CC)C(CCC=C1
# 9677. [+=Co5HH<n#<<oF-<<(5c<<<[<<<<5<<<-<<5<<<C<+2<<<<+<<<]<<<<)<1+5n]<<<<-(<<2]<<3-No<<<<<<<<<)<<<<[<<<<c
# 9678. 12
# 9679. C#CCC(2CCCO
# 9680. <CC(OHCCC2CC(OO=
# 9681. -OC1O1(C)=(2C3=N
# 9682. NOOCC1nC
# 9683. N[FO
# 9684. <CC1OCnNC(O==C1)1C1
# 9685. <CCCCCCC()C3(=CC#CN
# 9686. <()111C1C
# 9687. n[C(1CC
# 9688. <CCCC1CCOC1C1O=
# 9689. 5=+1
# 9690. +CCC1C=2CCC=1)1O
# 9691. <CCCCCCCCCOCC)C
# 9692. <C#=1)C2CC1C1))
# 9693. CO#=
# 9694. H=oc<n(C1CCC+CC1CCOCOC2
# 9695. <CCCOCCC1N#C
# 9696. 2)-2cH-4(H)F
# 9697. <CN1CCC2)CCC)OC
# 9698. OCC12C1C()C(OO)21=1C
# 9699. )#-C12O
# 9700. 2+CCCC2OCCOCCCCO
# 9701. <CC12COOOCCC)CN112
# 9702. N
# 9703. <C=1223CC1O(O=3NNC2
# 9704. -2nCC21=
# 9705. <C#11(2CC1C1C2)
# 9706. <CCC((C#=11CC3
# 9707. +CC1C2NCCC1CCC21N
# 9708. ([cC11C2)
# 9709. 3C(CC=CN#CC
# 9710. <CN1=OCO2N#23=)N
# 9711. <CC#1CCC(CC2CO1
# 9712. -COC(=CCCC(C)C2C
# 9713. <OC11CCCC3C1C2)CN
# 9714. <NC12CCC(13CNCCC
# 9715. <OCNC=CO)CCN2
# 9716. <CC1(2NCC)CCCC23
# 9717. <CC=C1NCCCC2CC
# 9718. F+)2]-)o3OO
# 9719. c[]1Fn3(n1[-
# 9720. <CC(1OCOC=C#O3
# 9721. <#1CC2C1CCOC)4C1
# 9722. <CC1CC412)2CNN
# 9723. <CC1=C2)CCCCCOC((3O
# 9724. <CC1CC(C=C3)C=2C
# 9725. 3C1OOC=CC)O
# 9726. [+<<<-<<<<<5<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<O<4<<<<<<<<<+<<<<<<c<<<F<<<<<<<<<o<<<<<(<<[<<<N<<
# 9727. <CC1COCC=O()CC12)32N
# 9728. <CC1)CCnCC)CCC2)#1O
# 9729. NCCCCCCCOCO3CN
# 9730. <OC1CCCCCC)CCCCON
# 9731. <C111CC2C=C((3NO1
# 9732. 4[C1C2COC(O)
# 9733. <CC1CC2[CC)O3
# 9734. <CC#23OO1(C=CO12212
# 9735. <C1=N(C1NO1NO]=NC)
# 9736. <CCCC1CCCC1CC
# 9737. <CCC=2C(3)C)=1CN
# 9738. nC1
# 9739. [CC=C3CN=CC2
# 9740. <CCO123=C1)C#O
# 9741.
# 9742. <CCF=11N11ON1=CC
# 9743. FO)n2
# 9744. CNc444-]
# 9745. <c1122)O2C3C2)#ON
# 9746.
# 9747. <CCCCN1)CCCOC1==
# 9748.
# 9749. <C4CNNCC12=C)11
# 9750. <CCCCCC)NCC(CCCC
# 9751. <NC=OC(CCCOCCC2C
# 9752. COCCC2CC))C)CC2
# 9753. nCC1CCCC(22C)OCNO
# 9754. <CC11CCCCC)C1
# 9755. 4o31[]3(N+<+<<=<<<<C<<o<Cc25c1<#F
# 9756. 2CC1O(C)3#C=C2CC2)
# 9757. <C1CC=CCCCC1CNC
# 9758. <CC1C=CNOOONOO(C
# 9759. 11NCCO1)-
# 9760. c-N1=CCC=CC#1
# 9761. <CC1C1(CC1CNCCCO1O
# 9762. 3(-<FOC
# 9763. <C1C=C(CCCCC2212
# 9764. 4<C1OC1=OCCO=1
# 9765. <CCC1=C(O=C1#C1C1)23
# 9766. <CC1(CCCC3N#21N
# 9767. <CCC1CCC1O1CC(()N3O
# 9768. 4NCCNCCC1O(#=3
# 9769. ])cCCCCCCCC1COCN
# 9770. onon(oo[
# 9771. <[C#22C21OC12
# 9772. <
# 9773. 5OCCC1CCCCO3CCCC
# 9774. =5]<)cF<n<<]<[<n<<<<<<<<<<<<<<<<<H<<<<<<<<<<5<<<<<<<]o<<<<<5[<<<<<<<<<O<o<<<<<<c<<<<n<<<<<<<<<FN<<n=
# 9775. HO#1H==211
# 9776. <CCCC1NC(CC
# 9777. HOC[11CC1#O
# 9778. [cO=O
# 9779. o=#4FOC[nHHH<5O+2cH-+[[555-55N5cc(5)+5oco]+3on5cn2coo++c55+n-5c[[Oc-coH-F43]H-5c+=4H-55oooc<-5-[52cn
# 9780. NOCCOC)=C11NC2
# 9781. <OC1N#CCC=11)C3
# 9782. =]4O#=O
# 9783. <CC1CC(32)C(NCCN
# 9784. 5C1C(OC(C212C=)1
# 9785. +4#C1C1COCOOC#CCCCC#
# 9786. 5N)CC12CCCCCNN
# 9787. oN(1C))33C2
# 9788. <CC)#C1C2C(=)CC1=
# 9789. <#CC12((NCC)CC22#
# 9790. <CC(1CN=3CCCC)N)#2
# 9791. <CCCCC212CC=2OCO
# 9792. <CC1C11CC=)CCCN=
# 9793. 54=NC==
# 9794. (#CNC=C#CCOO1
# 9795. <CO2O12CNC)C1C=2(OO
# 9796. +CC(1OOC1C3(1N
# 9797. F-C2CCCC=CN1O)N
# 9798. 2OC1CO212C=[O
# 9799. <CC1CCCCN2C#C
# 9800. cCCCC)CC2C=1NCCCO)OO
# 9801. )=[#1O2Oc
# 9802. <C]1CC1O=CC1N)1NO
# 9803. 5[FN=22
# 9804.
# 9805. N#[N]-]H-]+Hcc[n-4c5+n5+]nH[Hn5H[[Foc+n5-c5<c5c5+c<n<cn<FC#4[cc5-5Fncc4nFo-c+<n[cHcoo+[+n3cc<<n<[o+#
# 9806. cC1=NC21222
# 9807. <C#N2CCCC)2CCCO12
# 9808. ##OCOCC=CO)NC=
# 9809. <CC1=OCCC)(CON=CO)
# 9810. <cN1c(COO=)CO[C)OCH)3NO)
# 9811. #[)2O()O2N
# 9812. [CC(11CC)CC
# 9813. <#CCOCCCCCNC2
# 9814. <4COCOOCC3CC12=O21
# 9815. 1c[13n1n5]44H1oo]cc][-c4N5o(#c5[nc]o-4nnc5n5[55=co--[3-+1#(c]o[5n+oHc[[Ho(co]C-5oo+51nH]N5--no4-H-n[
# 9816.
# 9817. CON1C1CC)O1O
# 9818. <OCCCC3O2=N3C1
# 9819. <C=#1O1=(C2NCC
# 9820. COCOOC(FC332
# 9821. #FCOC(CC#CC2
# 9822. cC5n([5[HnooC3Hccn[cn)OHoHco4)(=c1[n+H[
# 9823. <OCC(NCC1(1)OC3C
# 9824. <O=1C1COCNOO
# 9825. <FC1C2OO=CCOCC3N
# 9826. o31OOO
# 9827. <CCC1CCC(CC2C)
# 9828. <CCCNONC1#C)CCCN
# 9829. 2NNO1C=C
# 9830. -+O(CCC))C
# 9831. <CC(=CCNCC11)C2O
# 9832. <CCC2CCC2CC2)=12OO[
# 9833. <c#1CN112O
# 9834. n[434N(CCN
# 9835. c3+)1CC##N2=1=2
# 9836. nn+5]4<<+]
# 9837. <CC=C1OCCCC#CC2
# 9838. <CCCC1CCCC12CC
# 9839. <C#21OCCOCCCCC=1
# 9840. <CC1NCCC)(CCCCCCOO=
# 9841.
# 9842. FCCC=1CCC)C4=1
# 9843. 5+-11-F5FCOC#=1
# 9844. c)[nc2c-coc(oC54-H<o55<-+-<<+F-<5<<<<<<<<[oHO<(<<<o-<<n<n<<5(O4](Nc
# 9845. <CC(C22121C)3COC
# 9846. nFNC#CC1=
# 9847. C[(CC==2O33N#O
# 9848. <Cc11O1C#C=O2N)3)2
# 9849. -Ho=
# 9850. <C1C(NO))C1CNCO
# 9851. O+]cn)#]5Hc])[2(-c+F
# 9852. CNFCC==ON
# 9853. n1)=OOCCC2
# 9854. -=cC(1=1##
# 9855. 1++OC2COON11COC#1
# 9856. <OC1CCCC1C213)122
# 9857. <=C111=1CCC#CC
# 9858. <CC1CON)(2)3)1CCN)NC1
# 9859. FCc1NC(1NNC#N2
# 9860. 4CNC1C2(NNCCON3
# 9861.
# 9862. <CCCCC)COC13CC
# 9863. (#oN=CC1N
# 9864. <CCCCCCCO3CC1N2
# 9865. <OCCCN1CCC1CO))2
# 9866. <CCCC1))NCC1CC1
# 9867. )CC11CN1CNN)114
# 9868. =+CCCCCCN)2)C
# 9869. +n
# 9870. <NCO1OO)CCC))2
# 9871. oOOO1
# 9872. [3=1
# 9873. <C#1C1C)CCNCC=CN
# 9874.
# 9875. <CC1CC(1C)=2)O
# 9876. F=cF1)N11
# 9877. <CCC=C=C2OC1)3
# 9878. <CCC1CCCC)1C2COO2#1
# 9879. <CCC(OCCCO)=2CCC(N22
# 9880. 1OCOCC2(21O1
# 9881. <CC1CCOOCCC)3C)N2O
# 9882. O[#]HFCCO
# 9883. =#NOC
# 9884.
# 9885. <CCC2CC3))1CN(CC13
# 9886. 5F]N)2#OF=
# 9887. <OC12C2CCC4=N11CCO
# 9888. <O=CCC21C3CC
# 9889. <CC1C=NC)=CCCC11
# 9890. <CO)N3CC=1N)
# 9891. <CCC1CCC(NCC1CN
# 9892. <C1(CCOCC1CC
# 9893. C+=1=1NCCCO(=1
# 9894. <C11CCCOC2C)NCCN
# 9895. )-NCO=2C#1O1N
# 9896. c#CC2
# 9897. <OC11CCC()CN1=
# 9898. 1COCCCCCC11
# 9899. <OCCCCCCCCC)OC12C
# 9900. oF)-4O#C=1
# 9901. <CC212C1)1(1CO)4
# 9902. <OCC11=CCCCC
# 9903. <NC=11)CCCCOC
# 9904. <CC1CC1C2C)CCC2
# 9905. ++[1+C2)=
# 9906. <CC#CCCCCOC)12
# 9907. <###OCCC1O11O
# 9908. 3]c+<15#C2CCN1C=CC
# 9909. nOCC(1CCCC)C
# 9910. +=CCCNC2CCN2N
# 9911. <CNCC(1C1C))=O1
# 9912.
# 9913. <CC=O(=OC(C(1C11C
# 9914. <CCCCOCC=1#O2=
# 9915. ]CCCCCCC1C1C
# 9916. Ho#1OCCCCCN2
# 9917. <ON1CC1CO(CCNN1
# 9918. 1COCCCCC1COO2C#
# 9919. <CCCC1C)1=C#CNN
# 9920. <CCC1C22C)#)=23#
# 9921. 3C12O1=OCN
# 9922. N+=5=H4#15(o[(<5c54O#<n-#5N<4o4H5)<<#55cc+<H544c(2+<55+<+3##5<F4<+<4<o+5<([F<oc25<2o-5-<5[5Fn55<55+5
# 9923. nCNCCCNCC1=O
# 9924. <CCNC(CC1#C=(CN
# 9925. oOOC#==ONCCOF
# 9926. (CC1NCC
# 9927. <CO1C2C11CO)#
# 9928. <c111CN(C))1]11OC2
# 9929. <CCCCC2C121CCO1
# 9930. (##=2=
# 9931. <CC1CCNCC)C1CCCCC
# 9932. <COC1))CC32)1N1213
# 9933. 4OOCC2=2CC)O2
# 9934. FcCC11C(CCOCNCCN
# 9935. <+C1CCCC1==)3C1)O
# 9936. ]O-FOo11=CO)N
# 9937. <-CC(=)OCC)1N11
# 9938. NONCONC31CC12
# 9939. ]=OC1CC
# 9940. n-CO1C332C[1N
# 9941. #+]
# 9942. <C=CCCCCC1CNCO21#
# 9943. N1Fo]5<c<<<<<[<<<#<<<<<<+<c<5<<<<<<<<<<<<<<<<#]O<<2<<<<<]<o<<4-<<<<<<<F2+5-<C<<<<<<<<++(-<<(<<<-<<<2
# 9944. 2N41=NO
# 9945. <C(1CCOC)2CC)N1O12
# 9946. <C#CCCN4C3CC=C2C
# 9947. <OO1NCC3C)CNCC1O
# 9948. <O#1#OCC)OCCCN=O
# 9949. <CCCCO1CC1CCC==
# 9950. <CCCCC1(OCCOCC2
# 9951. #[N+cH5542Fo]co-
# 9952. <CO1CCCNCCOCCC
# 9953. N(CHC1CNO
# 9954. 3O1CC=COCCCNC
# 9955. <OC1CC1CC1=CC#123
# 9956. FNN=NCCCC)C(=N
# 9957. HOCO1N3C)C)CN
# 9958. <CCCCCCC1C111
# 9959. ]C=c=21CC112=NC
# 9960. (H
# 9961. H+)CC2NC1CC)
# 9962. <CCCCOCC(=#C=C
# 9963. <CCCCCCOOCC)COCO12
# 9964. HNNCCC=CC#OCCN)O
# 9965. nNC(CCCC(#C)O)1
# 9966. -[O
# 9967. [4F4OC=OCO#1O
# 9968. 1()
# 9969. <CC1CCCCCC2C11111
# 9970. <CC1=1O(CNCCC1CN
# 9971. <CC(C12(C=C]1C=)2=
# 9972. +1NCCN
# 9973. <OO1CNCN)CO)#1
# 9974. n)C(CC=2=))1)O2
# 9975. <CCCC(CCCOC#C==1C
# 9976. N2CCNO1#CN
# 9977. <=CC(CC#1C22C#)3
# 9978. 3+1#1N=1#
# 9979. <+4CNO##221N
# 9980. <CN(C2O)1)OCCC
# 9981. cn[]C]#N
# 9982. )43OCC#]
# 9983. <5NC1=CCC13CC1NO#
# 9984. 4O2#OC=2
# 9985. =oCCCCC2=C1)C(
# 9986. <CCCCCCCN)C3CN1
# 9987. #2<F)n#1CCCCN#1=
# 9988. [+11=N
# 9989. <CC121C)CCC(C2)OC2N
# 9990. cON1C1
# 9991. #H1)OO2]1O=CCC)C)N
# 9992. O32n
# 9993. +o1[cFO5NH[cH<4-o5]+[<+<[-5<<2o<[o<[[-<-<o5<<F<4o<5<<c]<5<<4<<<5c[c5+<F<+c+co<<[4[o<<]-[<<<<5c+[<ccn
# 9994. <CNC(CCC=((ONOC
# 9995. <CC11C(NCC1+C11
# 9996. <CCC2CCCCOCC2CCHN
# 9997. C4CCCCCC)CCCCN
# 9998. cc-F5C11ON)C1
# 9999. <CC1C=C(C=#CCC)C3
# 10000. <CC1CCC#OCNN1O1C

# %% [markdown]
# 7. Analyzing Generated Molecules: After generating new molecules, we analyze them for validity, novelty, and potential usefulness. Here are some common analyses and insights we can derive:
#
#   7.1 Validity Check: First, we'll check how many of our generated SMILES strings represent valid molecules:

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from typing import Tuple, List, Dict

def validate_and_correct_smiles(smiles: str) -> Tuple[bool, str]:
    """
    Validate and attempt to correct a SMILES string.

    Args:
        smiles (str): The SMILES string to validate and correct.

    Returns:
        Tuple[bool, str]: A tuple containing a boolean indicating validity
                          and the corrected SMILES string (or original if invalid).
    """
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        try:
            Chem.SanitizeMol(mol)
            return True, Chem.MolToSmiles(mol, isomericSmiles=True)
        except:
            pass
    return False, smiles

def enhanced_post_process_smiles(smiles: str) -> str:
    """
    Post-process a SMILES string to correct common issues.

    Args:
        smiles (str): The SMILES string to process.

    Returns:
        str: The processed SMILES string.
    """
    smiles = smiles.replace('<', '').replace('>', '')
    allowed_chars = set('CNOPSFIBrClcnops()[]=@+-#0123456789')
    smiles = ''.join(c for c in smiles if c in allowed_chars)

    # Balance parentheses
    open_count = smiles.count('(')
    close_count = smiles.count(')')
    if open_count > close_count:
        smiles += ')' * (open_count - close_count)
    elif close_count > open_count:
        smiles = '(' * (close_count - open_count) + smiles

    # Replace invalid double bonds
    smiles = smiles.replace('==', '=')

    # Attempt to close unclosed rings
    for i in range(1, 10):
        if smiles.count(str(i)) % 2 != 0:
            smiles += str(i)

    return smiles

def analyze_molecules(smiles_list: List[str]) -> Dict:
    """
    Analyze a list of SMILES strings and provide detailed statistics.

    Args:
        smiles_list (List[str]): A list of SMILES strings to analyze.

    Returns:
        Dict: A dictionary containing various statistics and analyses.
    """
    results = {
        'total': len(smiles_list),
        'valid': 0,
        'invalid': 0,
        'unique': 0,
        'corrected': 0,
        'properties': [],
        'invalid_smiles': []
    }

    unique_smiles = set()

    for smiles in smiles_list:
        processed_smiles = enhanced_post_process_smiles(smiles)
        is_valid, corrected_smiles = validate_and_correct_smiles(processed_smiles)

        if is_valid:
            results['valid'] += 1
            unique_smiles.add(corrected_smiles)
            if corrected_smiles != processed_smiles:
                results['corrected'] += 1

            mol = Chem.MolFromSmiles(corrected_smiles)
            results['properties'].append({
                'smiles': corrected_smiles,
                'molecular_weight': Descriptors.ExactMolWt(mol),
                'logp': Descriptors.MolLogP(mol),
                'num_atoms': mol.GetNumAtoms(),
                'num_rings': Descriptors.RingCount(mol)
            })
        else:
            results['invalid'] += 1
            results['invalid_smiles'].append(smiles)

    results['unique'] = len(unique_smiles)
    return results

# Assume generated_smiles is your list of generated SMILES strings
analysis = analyze_molecules(generated_smiles)

# Print summary
print(f"Total SMILES: {analysis['total']}")
print(f"Valid SMILES: {analysis['valid']} ({analysis['valid']/analysis['total']:.2%})")
print(f"Invalid SMILES: {analysis['invalid']} ({analysis['invalid']/analysis['total']:.2%})")
print(f"Unique SMILES: {analysis['unique']} ({analysis['unique']/analysis['total']:.2%})")
print(f"Corrected SMILES: {analysis['corrected']} ({analysis['corrected']/analysis['total']:.2%})")

# Print property statistics
df = pd.DataFrame(analysis['properties'])
print("\nProperty Statistics:")
print(df.describe())

# Print some invalid SMILES
print("\nSample of Invalid SMILES:")
for smiles in analysis['invalid_smiles'][:5]:  # Print first 5 invalid SMILES
    print(smiles)

# Optionally, save the full analysis to a CSV file
df.to_csv('molecule_properties.csv', index=False)
print("\nFull property analysis saved to 'molecule_properties.csv'")
# Out:
# Streaming output truncated to the last 5000 lines.
# [03:10:17] SMILES Parse Error: check for mistakes around position 11:
# [03:10:17] FCC1=1CCC()2CC112
# [03:10:17] ~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'FCC1=1CCC()2CC112' for input: 'FCC1=1CCC()2CC112'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCC(CC=3(C(+131=O21)))12
# [03:10:17] SMILES Parse Error: check for mistakes around position 12:
# [03:10:17] CCC(CC=3(C(+131=O21)))12
# [03:10:17] ~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: extra open parentheses while parsing: CCC(CC=3(C(+131=O21)))12
# [03:10:17] SMILES Parse Error: check for mistakes around position 4:
# [03:10:17] CCC(CC=3(C(+131=O21)))12
# [03:10:17] ~~~^
# [03:10:17] SMILES Parse Error: extra open parentheses while parsing: CCC(CC=3(C(+131=O21)))12
# [03:10:17] SMILES Parse Error: check for mistakes around position 9:
# [03:10:17] CCC(CC=3(C(+131=O21)))12
# [03:10:17] ~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCC(CC=3(C(+131=O21)))12' for input: 'CCC(CC=3(C(+131=O21)))12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((NC(COC=)=CC=)C)C
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((NC(COC=)=CC=)C)C
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((NC(COC=)=CC=)C)C' for input: '((NC(COC=)=CC=)C)C'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCCCNC(=31C1OCN)3
# [03:10:17] SMILES Parse Error: check for mistakes around position 9:
# [03:10:17] CCCCNC(=31C1OCN)3
# [03:10:17] ~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCCCNC(=31C1OCN)3' for input: 'CCCCNC(=31C1OCN)3'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (5=CCCCCOOCCC)5
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (5=CCCCCOOCCC)5
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(5=CCCCCOOCCC)5' for input: '(5=CCCCCOOCCC)5'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 3CC##CCCC3
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 3CC##CCCC3
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '3CC##CCCC3' for input: '3CC##CCCC3'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (([c=13))=C13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (([c=13))=C13
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(([c=13))=C13' for input: '(([c=13))=C13'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 7 to itself for input: 'CnCCCC(C=C11CCO=OC#1O)1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (5CCOO11CC)O225
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (5CCOO11CC)O225
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(5CCOO11CC)O225' for input: '(5CCOO11CC)O225'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (C)=OOO11O#
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (C)=OOO11O#
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(C)=OOO11O#' for input: '(C)=OOO11O#'
# [03:10:17] SMILES Parse Error: ring closure 1 duplicates bond between atom 1 and atom 2 for input: 'NC1C1'
# [03:10:17] Explicit valence for atom # 8 O, 3, is greater than permitted
# [03:10:17] SMILES Parse Error: syntax error while parsing: (OCCC(C2N112))
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (OCCC(C2N112))
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(OCCC(C2N112))' for input: '(OCCC(C2N112))'
# [03:10:17] SMILES Parse Error: ring closure 3 duplicates bond between atom 10 and atom 11 for input: 'FCNCCCOOCOC3O3'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =)[32##+2((+]5o)35
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =)[32##+2((+]5o)35
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=)[32##+2((+]5o)35' for input: '=)[32##+2((+]5o)35'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 1 to itself for input: 'CC112C(C#O21CCC)1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((#CCC2CC))C112
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((#CCC2CC))C112
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((#CCC2CC))C112' for input: '((#CCC2CC))C112'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (-C1C(C22C=)1)C2OC2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (-C1C(C22C=)1)C2OC2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(-C1C(C22C=)1)C2OC2' for input: '(-C1C(C22C=)1)C2OC2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (+1)CO#NOO#CO1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (+1)CO#NOO#CO1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(+1)CO#NOO#CO1' for input: '(+1)CO#NOO#CO1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: O=c+4CCOCC#=C1O=#14
# [03:10:17] SMILES Parse Error: check for mistakes around position 4:
# [03:10:17] O=c+4CCOCC#=C1O=#14
# [03:10:17] ~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'O=c+4CCOCC#=C1O=#14' for input: 'O=c+4CCOCC#=C1O=#14'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CC1C)CCCC1CC2)2ON
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CC1C)CCCC1CC2)2ON
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CC1C)CCCC1CC2)2ON' for input: '((CC1C)CCCC1CC2)2ON'
# [03:10:17] SMILES Parse Error: syntax error while parsing: +#n1n1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] +#n1n1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '+#n1n1' for input: '+#n1n1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((225[)C1C1=C)O2N1215
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((225[)C1C1=C)O2N1215
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((225[)C1C1=C)O2N1215' for input: '((225[)C1C1=C)O2N1215'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CN=(COC)N)ONC
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CN=(COC)N)ONC
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CN=(COC)N)ONC' for input: '(CN=(COC)N)ONC'
# [03:10:17] SMILES Parse Error: syntax error while parsing: n[o4O4
# [03:10:17] SMILES Parse Error: check for mistakes around position 4:
# [03:10:17] n[o4O4
# [03:10:17] ~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'n[o4O4' for input: 'n[o4O4'
# [03:10:17] SMILES Parse Error: syntax error while parsing: +No125#5N-#+n53[c#](#-(5[C2+5=)#(5Fc-F+=c()5-[5=)5F55c-cc=-[545n5[-cFc-]5c4-4F5[45(]5o5]C555[))13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] +No125#5N-#+n53[c#](#-(5[C2+5=)#(5Fc-F+=c
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '+No125#5N-#+n53[c#](#-(5[C2+5=)#(5Fc-F+=c()5-[5=)5F55c-cc=-[545n5[-cFc-]5c4-4F5[45(]5o5]C555[))13' for input: '+No125#5N-#+n53[c#](#-(5[C2+5=)#(5Fc-F+=c()5-[5=)5F55c-cc=-[545n5[-cFc-]5c4-4F5[45(]5o5]C555[))13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 4CCC(N1=N)14
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 4CCC(N1=N)14
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '4CCC(N1=N)14' for input: '4CCC(N1=N)14'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCC(1(CC2=))12
# [03:10:17] SMILES Parse Error: check for mistakes around position 5:
# [03:10:17] CCC(1(CC2=))12
# [03:10:17] ~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCC(1(CC2=))12' for input: 'CCC(1(CC2=))12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (F-NOC)
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (F-NOC)
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(F-NOC)' for input: '(F-NOC)'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CC(1(C(CCCC)3C=NC))13
# [03:10:17] SMILES Parse Error: check for mistakes around position 4:
# [03:10:17] CC(1(C(CCCC)3C=NC))13
# [03:10:17] ~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CC(1(C(CCCC)3C=NC))13' for input: 'CC(1(C(CCCC)3C=NC))13'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 7 to itself for input: 'CCC(CCC)NC11'
# [03:10:17] SMILES Parse Error: syntax error while parsing: -4OC4
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] -4OC4
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '-4OC4' for input: '-4OC4'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [n=C=(1=N2)12
# [03:10:17] SMILES Parse Error: check for mistakes around position 3:
# [03:10:17] [n=C=(1=N2)12
# [03:10:17] ~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[n=C=(1=N2)12' for input: '[n=C=(1=N2)12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 5CCoC(NCn)5
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 5CCoC(NCn)5
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '5CCoC(NCn)5' for input: '5CCoC(NCn)5'
# [03:10:17] SMILES Parse Error: syntax error while parsing: OCCN1(CC)3O+2213
# [03:10:17] SMILES Parse Error: check for mistakes around position 12:
# [03:10:17] OCCN1(CC)3O+2213
# [03:10:17] ~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'OCCN1(CC)3O+2213' for input: 'OCCN1(CC)3O+2213'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CN]24O3C=)234
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CN]24O3C=)234
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CN]24O3C=)234' for input: '(CN]24O3C=)234'
# [03:10:17] SMILES Parse Error: ring closure 1 duplicates bond between atom 4 and atom 5 for input: 'F5O(OCO1C1O)5'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (OCC#2)CC=21O1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (OCC#2)CC=21O1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(OCC#2)CC=21O1' for input: '(OCC#2)CC=21O1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CC1CCC)=CCCCCCN3N13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CC1CCC)=CCCCCCN3N13
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CC1CCC)=CCCCCCN3N13' for input: '(CC1CCC)=CCCCCCN3N13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (([c11]Oc=)OO)]O
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (([c11]Oc=)OO)]O
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(([c11]Oc=)OO)]O' for input: '(([c11]Oc=)OO)]O'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 4CC(CCC1C1O#CCOCC)4
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 4CC(CCC1C1O#CCOCC)4
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '4CC(CCC1C1O#CCOCC)4' for input: '4CC(CCC1C1O#CCOCC)4'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ()N=CCC
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ()N=CCC
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '()N=CCC' for input: '()N=CCC'
# [03:10:17] Explicit valence for atom # 1 C, 5, is greater than permitted
# [03:10:17] SMILES Parse Error: syntax error while parsing: [OC=CC=(CC)
# [03:10:17] SMILES Parse Error: check for mistakes around position 3:
# [03:10:17] [OC=CC=(CC)
# [03:10:17] ~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[OC=CC=(CC)' for input: '[OC=CC=(CC)'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 2n2+F5O#CCCC)(C1C(O1)5
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 2n2+F5O#CCCC)(C1C(O1)5
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '2n2+F5O#CCCC)(C1C(O1)5' for input: '2n2+F5O#CCCC)(C1C(O1)5'
# [03:10:17] SMILES Parse Error: ring closure 1 duplicates bond between atom 1 and atom 2 for input: 'CC1C1CCCCC11'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CC11CC()CN=CO11
# [03:10:17] SMILES Parse Error: check for mistakes around position 8:
# [03:10:17] CC11CC()CN=CO11
# [03:10:17] ~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CC11CC()CN=CO11' for input: 'CC11CC()CN=CO11'
# [03:10:17] SMILES Parse Error: syntax error while parsing: NCC1C1CCCO12(1O)2
# [03:10:17] SMILES Parse Error: check for mistakes around position 14:
# [03:10:17] NCC1C1CCCO12(1O)2
# [03:10:17] ~~~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'NCC1C1CCCO12(1O)2' for input: 'NCC1C1CCCO12(1O)2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =#((C3))3
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =#((C3))3
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=#((C3))3' for input: '=#((C3))3'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 0 to itself for input: 'n511OCC1C#C3CFOC135'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CC11C1CC()1
# [03:10:17] SMILES Parse Error: check for mistakes around position 10:
# [03:10:17] CC11C1CC()1
# [03:10:17] ~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CC11C1CC()1' for input: 'CC11C1CC()1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (()#--OOO1CO)2ONOF#12
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (()#--OOO1CO)2ONOF#12
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(()#--OOO1CO)2ONOF#12' for input: '(()#--OOO1CO)2ONOF#12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 5CC=C(12NC2C=CC#22)15
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 5CC=C(12NC2C=CC#22)15
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '5CC=C(12NC2C=CC#22)15' for input: '5CC=C(12NC2C=CC#22)15'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CN112C(C[CC(C3=C))23
# [03:10:17] SMILES Parse Error: check for mistakes around position 11:
# [03:10:17] CN112C(C[CC(C3=C))23
# [03:10:17] ~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: extra open parentheses while parsing: CN112C(C[CC(C3=C))23
# [03:10:17] SMILES Parse Error: check for mistakes around position 7:
# [03:10:17] CN112C(C[CC(C3=C))23
# [03:10:17] ~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CN112C(C[CC(C3=C))23' for input: 'CN112C(C[CC(C3=C))23'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((#2C=C1OCCC))OC1O2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((#2C=C1OCCC))OC1O2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((#2C=C1OCCC))OC1O2' for input: '((#2C=C1OCCC))OC1O2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =(24FN3#)234
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =(24FN3#)234
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=(24FN3#)234' for input: '=(24FN3#)234'
# [03:10:17] SMILES Parse Error: syntax error while parsing: #2#=+OOC2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] #2#=+OOC2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '#2#=+OOC2' for input: '#2#=+OOC2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCC1CCCCOC)C=1#11
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCC1CCCCOC)C=1#11
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCC1CCCCOC)C=1#11' for input: '(CCC1CCCCOC)C=1#11'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 9 to itself for input: 'COCCCCCCCC=1212'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (c3)3
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (c3)3
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(c3)3' for input: '(c3)3'
# [03:10:17] Explicit valence for atom # 2 O, 4, is greater than permitted
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((OC1C)C)O()11#1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((OC1C)C)O()11#1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((OC1C)C)O()11#1' for input: '((OC1C)C)O()11#1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ()C=N=11
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ()C=N=11
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '()C=N=11' for input: '()C=N=11'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCC(1C(CCC2CC)C)12
# [03:10:17] SMILES Parse Error: check for mistakes around position 5:
# [03:10:17] CCC(1C(CCC2CC)C)12
# [03:10:17] ~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCC(1C(CCC2CC)C)12' for input: 'CCC(1C(CCC2CC)C)12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 4C41313
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 4C41313
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '4C41313' for input: '4C41313'
# [03:10:17] SMILES Parse Error: syntax error while parsing: #C1OCCCC1=1#O3O13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] #C1OCCCC1=1#O3O13
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '#C1OCCCC1=1#O3O13' for input: '#C1OCCCC1=1#O3O13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CC1(OC)2C))12
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CC1(OC)2C))12
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CC1(OC)2C))12' for input: '((CC1(OC)2C))12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [(25c5c[5(11CC2N=ON))5
# [03:10:17] SMILES Parse Error: check for mistakes around position 2:
# [03:10:17] [(25c5c[5(11CC2N=ON))5
# [03:10:17] ~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[(25c5c[5(11CC2N=ON))5' for input: '[(25c5c[5(11CC2N=ON))5'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 2c#O1]N12
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 2c#O1]N12
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '2c#O1]N12' for input: '2c#O1]N12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CCNN=1OC#C))oC1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CCNN=1OC#C))oC1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CCNN=1OC#C))oC1' for input: '((CCNN=1OC#C))oC1'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 2 to itself for input: 'cO=C132221C23'
# [03:10:17] SMILES Parse Error: syntax error while parsing: -oCC24=11C1214
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] -oCC24=11C1214
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '-oCC24=11C1214' for input: '-oCC24=11C1214'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =2C#CO2C=1O1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =2C#CO2C=1O1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=2C#CO2C=1O1' for input: '=2C#CO2C=1O1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: F2=3#4+NcoFF#(]o]+(#n1c[5))12345
# [03:10:17] SMILES Parse Error: check for mistakes around position 7:
# [03:10:17] F2=3#4+NcoFF#(]o]+(#n1c[5))12345
# [03:10:17] ~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'F2=3#4+NcoFF#(]o]+(#n1c[5))12345' for input: 'F2=3#4+NcoFF#(]o]+(#n1c[5))12345'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (OC=O)=1O2CC12
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (OC=O)=1O2CC12
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(OC=O)=1O2CC12' for input: '(OC=O)=1O2CC12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (((CC(12))1CNC))=2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (((CC(12))1CNC))=2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(((CC(12))1CNC))=2' for input: '(((CC(12))1CNC))=2'
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'o44]OO+21#14C#24' for input: 'o44]OO+21#14C#24'
# [03:10:17] Explicit valence for atom # 10 C, 5, is greater than permitted
# [03:10:17] SMILES Parse Error: syntax error while parsing: CC1=CCC+1C=C
# [03:10:17] SMILES Parse Error: check for mistakes around position 8:
# [03:10:17] CC1=CCC+1C=C
# [03:10:17] ~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CC1=CCC+1C=C' for input: 'CC1=CCC+1C=C'
# [03:10:17] SMILES Parse Error: ring closure 1 duplicates bond between atom 2 and atom 4 for input: 'CCC2(O=2)1C1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((cCC1CC[))1C33
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((cCC1CC[))1C33
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((cCC1CC[))1C33' for input: '((cCC1CC[))1C33'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CC111CNOCOC=#3)13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CC111CNOCOC=#3)13
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CC111CNOCOC=#3)13' for input: '(CC111CNOCOC=#3)13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: c#5[-c-[n4(n][5cn=[)4
# [03:10:17] SMILES Parse Error: check for mistakes around position 5:
# [03:10:17] c#5[-c-[n4(n][5cn=[)4
# [03:10:17] ~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'c#5[-c-[n4(n][5cn=[)4' for input: 'c#5[-c-[n4(n][5cn=[)4'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 2 to itself for input: 'O#NN11'
# [03:10:17] SMILES Parse Error: duplicated ring closure 2 bonds atom 9 to itself for input: 'CC1CCCCC=N1CN22'
# [03:10:17] SMILES Parse Error: syntax error while parsing: -CC12#CC1((C=#CC122))12
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] -CC12#CC1((C=#CC122))12
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '-CC12#CC1((C=#CC122))12' for input: '-CC12#CC1((C=#CC122))12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CC2()C1OC=O12
# [03:10:17] SMILES Parse Error: check for mistakes around position 5:
# [03:10:17] CC2()C1OC=O12
# [03:10:17] ~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CC2()C1OC=O12' for input: 'CC2()C1OC=O12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (1=2)NC21CO
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (1=2)NC21CO
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(1=2)NC21CO' for input: '(1=2)NC21CO'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =334]C[O+4
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =334]C[O+4
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=334]C[O+4' for input: '=334]C[O+4'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (3-oC1OO=])13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (3-oC1OO=])13
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(3-oC1OO=])13' for input: '(3-oC1OO=])13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [CCC11CCCO3CCO1CO13
# [03:10:17] SMILES Parse Error: check for mistakes around position 3:
# [03:10:17] [CCC11CCCO3CCO1CO13
# [03:10:17] ~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[CCC11CCCO3CCO1CO13' for input: '[CCC11CCCO3CCO1CO13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCC1COC1C2C2C)(1)1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCC1COC1C2C2C)(1)1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCC1COC1C2C2C)(1)1' for input: '(CCC1COC1C2C2C)(1)1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [N[[2(o4[c[+cc+=3]+5Fn+n=]oc)2FcFc[345
# [03:10:17] SMILES Parse Error: check for mistakes around position 3:
# [03:10:17] [N[[2(o4[c[+cc+=3]+5Fn+n=]oc)2FcFc[345
# [03:10:17] ~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[N[[2(o4[c[+cc+=3]+5Fn+n=]oc)2FcFc[345' for input: '[N[[2(o4[c[+cc+=3]+5Fn+n=]oc)2FcFc[345'
# [03:10:17] SMILES Parse Error: syntax error while parsing: +CC1CC(C=)N=1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] +CC1CC(C=)N=1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '+CC1CC(C=)N=1' for input: '+CC1CC(C=)N=1'
# [03:10:17] SMILES Parse Error: duplicated ring closure 2 bonds atom 2 to itself for input: 'CC1N(C#CC1C)2=2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((=NCC)O()CO1)3OC#2N]NOOO2COO#O2N#123
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((=NCC)O()CO1)3OC#2N]NOOO2COO#O2N#123
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((=NCC)O()CO1)3OC#2N]NOOO2COO#O2N#123' for input: '((=NCC)O()CO1)3OC#2N]NOOO2COO#O2N#123'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCCO(C)CCC3N)1CO13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCCO(C)CCC3N)1CO13
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCCO(C)CCC3N)1CO13' for input: '(CCCO(C)CCC3N)1CO13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: #C(1=)=14C#114
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] #C(1=)=14C#114
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '#C(1=)=14C#114' for input: '#C(1=)=14C#114'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 345F=O1OOC1345
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 345F=O1OOC1345
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '345F=O1OOC1345' for input: '345F=O1OOC1345'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CCCCCCCCOC)CCC)11
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CCCCCCCCOC)CCC)11
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CCCCCCCCOC)CCC)11' for input: '((CCCCCCCCOC)CCC)11'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCCCNC#=CCCCN1CO2O12
# [03:10:17] SMILES Parse Error: check for mistakes around position 8:
# [03:10:17] CCCCNC#=CCCCN1CO2O12
# [03:10:17] ~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCCCNC#=CCCCN1CO2O12' for input: 'CCCCNC#=CCCCN1CO2O12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 5335
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 5335
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '5335' for input: '5335'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CC1CC3NC))N22C1113
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CC1CC3NC))N22C1113
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CC1CC3NC))N22C1113' for input: '((CC1CC3NC))N22C1113'
# [03:10:17] SMILES Parse Error: syntax error while parsing: cN#=O
# [03:10:17] SMILES Parse Error: check for mistakes around position 4:
# [03:10:17] cN#=O
# [03:10:17] ~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'cN#=O' for input: 'cN#=O'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CC2C)CCCCCCOCC2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CC2C)CCCCCCOCC2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CC2C)CCCCCCOCC2' for input: '(CC2C)CCCCCCOCC2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 4=((#NCC1(N#)))14
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 4=((#NCC1(N#)))14
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '4=((#NCC1(N#)))14' for input: '4=((#NCC1(N#)))14'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 4NFF]-n[-(=+4NFC[F+F5-#on])5
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 4NFF]-n[-(=+4NFC[F+F5-#on])5
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '4NFF]-n[-(=+4NFC[F+F5-#on])5' for input: '4NFF]-n[-(=+4NFC[F+F5-#on])5'
# [03:10:17] SMILES Parse Error: extra close parentheses while parsing: CCCC1N3CC1C2)CCC(23
# [03:10:17] SMILES Parse Error: check for mistakes around position 13:
# [03:10:17] CCCC1N3CC1C2)CCC(23
# [03:10:17] ~~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCCC1N3CC1C2)CCC(23' for input: 'CCCC1N3CC1C2)CCC(23'
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'c]+[+' for input: 'c]+[+'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (((CC=CCC)C)CCN#C)#
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (((CC=CCC)C)CCN#C)#
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(((CC=CCC)C)CCN#C)#' for input: '(((CC=CCC)C)CCN#C)#'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((((CCCCC)2)C#C)CC11)2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((((CCCCC)2)C#C)CC11)2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((((CCCCC)2)C#C)CC11)2' for input: '((((CCCCC)2)C#C)CC11)2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (C1OC1=C=C1)1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (C1OC1=C=C1)1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(C1OC1=C=C1)1' for input: '(C1OC1=C=C1)1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =N+O1C11C1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =N+O1C11C1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=N+O1C11C1' for input: '=N+O1C11C1'
# [03:10:17] SMILES Parse Error: ring closure 3 duplicates bond between atom 6 and atom 3 for input: 'CCC1C(ONN231)23'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((]1]3-c+3-o5On+cC1NCC)C1O2C)2O15
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((]1]3-c+3-o5On+cC1NCC)C1O2C)2O15
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((]1]3-c+3-o5On+cC1NCC)C1O2C)2O15' for input: '((]1]3-c+3-o5On+cC1NCC)C1O2C)2O15'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCC(NCC1C)C)2N12
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCC(NCC1C)C)2N12
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCC(NCC1C)C)2N12' for input: '(CCC(NCC1C)C)2N12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CC#CCCO1)CO1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CC#CCCO1)CO1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CC#CCCO1)CO1' for input: '(CC#CCCO1)CO1'
# [03:10:17] Explicit valence for atom # 4 O, 3, is greater than permitted
# [03:10:17] SMILES Parse Error: syntax error while parsing: +#-13OO1113
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] +#-13OO1113
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '+#-13OO1113' for input: '+#-13OO1113'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 5[(N+c-([-o5]]2(2o)))
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 5[(N+c-([-o5]]2(2o)))
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '5[(N+c-([-o5]]2(2o)))' for input: '5[(N+c-([-o5]]2(2o)))'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (c5)=OCOOO4#1145
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (c5)=OCOOO4#1145
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(c5)=OCOOO4#1145' for input: '(c5)=OCOOO4#1145'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ++5]5cocnn[o=ccnc]n+o2cno+n5c[=coF+-25
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ++5]5cocnn[o=ccnc]n+o2cno+n5c[=coF+-25
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '++5]5cocnn[o=ccnc]n+o2cno+n5c[=coF+-25' for input: '++5]5cocnn[o=ccnc]n+o2cno+n5c[=coF+-25'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (=CCCC#)1=CNCC3O13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (=CCCC#)1=CNCC3O13
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(=CCCC#)1=CNCC3O13' for input: '(=CCCC#)1=CNCC3O13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCCC1CCCCC()C=1O
# [03:10:17] SMILES Parse Error: check for mistakes around position 12:
# [03:10:17] CCCC1CCCCC()C=1O
# [03:10:17] ~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCCC1CCCCC()C=1O' for input: 'CCCC1CCCCC()C=1O'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (o#1C1NC1)1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (o#1C1NC1)1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(o#1C1NC1)1' for input: '(o#1C1NC1)1'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 1 to itself for input: 'CC11C2CO123CCC=13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: c-
# [03:10:17] SMILES Parse Error: check for mistakes around position 2:
# [03:10:17] c-
# [03:10:17] ~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'c-' for input: 'c-'
# [03:10:17] Explicit valence for atom # 4 C, 7, is greater than permitted
# [03:10:17] SMILES Parse Error: syntax error while parsing: (((NC=C)CCCC1))CCNNN1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (((NC=C)CCCC1))CCNNN1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(((NC=C)CCCC1))CCNNN1' for input: '(((NC=C)CCCC1))CCNNN1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCCNCCO)()CON11
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCCNCCO)()CON11
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCCNCCO)()CON11' for input: '(CCCNCCO)()CON11'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=' for input: '='
# [03:10:17] SMILES Parse Error: ring closure 3 duplicates bond between atom 4 and atom 3 for input: 'CCOC(C=3=C1CO)13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CCCCOC3N)CO)CCC2=2O3
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CCCCOC3N)CO)CCC2=2O3
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CCCCOC3N)CO)CCC2=2O3' for input: '((CCCCOC3N)CO)CCC2=2O3'
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'n]4n52-[55on(On45155-1-+15+5]o)12' for input: 'n]4n52-[55on(On45155-1-+15+5]o)12'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ([NN)
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ([NN)
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '([NN)' for input: '([NN)'
# [03:10:17] SMILES Parse Error: syntax error while parsing: o#14-5Oo5o(F-3)4-+3#51c(-ooCF2[noc(n(o[5n554#15-+44=]]o([5oc-55+[[n))))124
# [03:10:17] SMILES Parse Error: check for mistakes around position 18:
# [03:10:17] o#14-5Oo5o(F-3)4-+3#51c(-ooCF2[noc(n(o[5n
# [03:10:17] ~~~~~~~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'o#14-5Oo5o(F-3)4-+3#51c(-ooCF2[noc(n(o[5n554#15-+44=]]o([5oc-55+[[n))))124' for input: 'o#14-5Oo5o(F-3)4-+3#51c(-ooCF2[noc(n(o[5n554#15-+44=]]o([5oc-55+[[n))))124'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (((C#CC131)))3
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (((C#CC131)))3
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(((C#CC131)))3' for input: '(((C#CC131)))3'
# [03:10:17] SMILES Parse Error: syntax error while parsing: +N1(C1ONCC)
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] +N1(C1ONCC)
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '+N1(C1ONCC)' for input: '+N1(C1ONCC)'
# [03:10:17] SMILES Parse Error: ring closure 2 duplicates bond between atom 2 and atom 3 for input: 'N3C1C2C132'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (NO1C1C#CCO)N
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (NO1C1C#CCO)N
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(NO1C1C#CCO)N' for input: '(NO1C1C#CCO)N'
# [03:10:17] SMILES Parse Error: ring closure 1 duplicates bond between atom 8 and atom 9 for input: 'C=CCCC=CCCC1(O1)'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =+=1=#N=N=4OO14
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =+=1=#N=N=4OO14
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=+=1=#N=N=4OO14' for input: '=+=1=#N=N=4OO14'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((OCCCCCO)NO)1N1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((OCCCCCO)NO)1N1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((OCCCCCO)NO)1N1' for input: '((OCCCCCO)NO)1N1'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 0 to itself for input: 'O=11=C2OC2CCOOO'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCC1N)CO2CCOCCNN21
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCC1N)CO2CCOCCNN21
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCC1N)CO2CCOCCNN21' for input: '(CCC1N)CO2CCOCCNN21'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCCCNCC=CC12)12
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCCCNCC=CC12)12
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCCCNCC=CC12)12' for input: '(CCCCNCC=CC12)12'
# [03:10:17] SMILES Parse Error: ring closure 2 duplicates bond between atom 2 and atom 3 for input: 'oCC2O2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [CCCC2#CC1N=CC=2C212
# [03:10:17] SMILES Parse Error: check for mistakes around position 3:
# [03:10:17] [CCCC2#CC1N=CC=2C212
# [03:10:17] ~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[CCCC2#CC1N=CC=2C212' for input: '[CCCC2#CC1N=CC=2C212'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CC=1C(C()N)1CCCO
# [03:10:17] SMILES Parse Error: check for mistakes around position 9:
# [03:10:17] CC=1C(C()N)1CCCO
# [03:10:17] ~~~~~~~~^
# [03:10:17] SMILES Parse Error: extra open parentheses while parsing: CC=1C(C()N)1CCCO
# [03:10:17] SMILES Parse Error: check for mistakes around position 6:
# [03:10:17] CC=1C(C()N)1CCCO
# [03:10:17] ~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CC=1C(C()N)1CCCO' for input: 'CC=1C(C()N)1CCCO'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 0 to itself for input: 'N11O1#CCO1O'
# [03:10:17] SMILES Parse Error: syntax error while parsing: -
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] -
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '-' for input: '-'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (((CC1CC1CC1)NCCC1N)2)N2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (((CC1CC1CC1)NCCC1N)2)N2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(((CC1CC1CC1)NCCC1N)2)N2' for input: '(((CC1CC1CC1)NCCC1N)2)N2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [[#1C=1CCC=1N1
# [03:10:17] SMILES Parse Error: check for mistakes around position 2:
# [03:10:17] [[#1C=1CCC=1N1
# [03:10:17] ~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[[#1C=1CCC=1N1' for input: '[[#1C=1CCC=1N1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [14F1C1ON14
# [03:10:17] SMILES Parse Error: check for mistakes around position 5:
# [03:10:17] [14F1C1ON14
# [03:10:17] ~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[14F1C1ON14' for input: '[14F1C1ON14'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (+3)CN12N1C1123
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (+3)CN12N1C1123
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(+3)CN12N1C1123' for input: '(+3)CN12N1C1123'
# [03:10:17] SMILES Parse Error: syntax error while parsing: OC13C(1C1#C)C2123
# [03:10:17] SMILES Parse Error: check for mistakes around position 7:
# [03:10:17] OC13C(1C1#C)C2123
# [03:10:17] ~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'OC13C(1C1#C)C2123' for input: 'OC13C(1C1#C)C2123'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((([CC1NCC2)OC1)CN)N2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((([CC1NCC2)OC1)CN)N2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((([CC1NCC2)OC1)CN)N2' for input: '((([CC1NCC2)OC1)CN)N2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 5n5
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 5n5
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '5n5' for input: '5n5'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CCC1C13N)OC2C)23
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CCC1C13N)OC2C)23
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CCC1C13N)OC2C)23' for input: '((CCC1C13N)OC2C)23'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CC1=C3C2CCCCC1=(CC12)13
# [03:10:17] SMILES Parse Error: check for mistakes around position 16:
# [03:10:17] CC1=C3C2CCCCC1=(CC12)13
# [03:10:17] ~~~~~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CC1=C3C2CCCCC1=(CC12)13' for input: 'CC1=C3C2CCCCC1=(CC12)13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CNCON(C2C1)C12O=
# [03:10:17] SMILES Parse Error: check for mistakes around position 16:
# [03:10:17] CNCON(C2C1)C12O=
# [03:10:17] ~~~~~~~~~~~~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CNCON(C2C1)C12O=' for input: 'CNCON(C2C1)C12O='
# [03:10:17] SMILES Parse Error: syntax error while parsing: +2N5OC1(NC1O)25
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] +2N5OC1(NC1O)25
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '+2N5OC1(NC1O)25' for input: '+2N5OC1(NC1O)25'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 5##C11C11=115
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 5##C11C11=115
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '5##C11C11=115' for input: '5##C11C11=115'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((3#C=C)C11)3
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((3#C=C)C11)3
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((3#C=C)C11)3' for input: '((3#C=C)C11)3'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 55
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 55
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '55' for input: '55'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 2FNoC1CCO1ONOO2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 2FNoC1CCO1ONOO2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '2FNoC1CCO1ONOO2' for input: '2FNoC1CCO1ONOO2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (F)OCO#=NN22
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (F)OCO#=NN22
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(F)OCO#=NN22' for input: '(F)OCO#=NN22'
# [03:10:17] SMILES Parse Error: syntax error while parsing: =c=C+4+1=F]+o523-c+-5o124-]4o=C)-(4(#o)(F+O[1oc+C#[)13
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] =c=C+4+1=F]+o523-c+-5o124-]4o=C)-(4(#o)(F
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '=c=C+4+1=F]+o523-c+-5o124-]4o=C)-(4(#o)(F+O[1oc+C#[)13' for input: '=c=C+4+1=F]+o523-c+-5o124-]4o=C)-(4(#o)(F+O[1oc+C#[)13'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (=O4)O+C4
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (=O4)O+C4
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(=O4)O+C4' for input: '(=O4)O+C4'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (#2()1N1C)2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (#2()1N1C)2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(#2()1N1C)2' for input: '(#2()1N1C)2'
# [03:10:17] SMILES Parse Error: syntax error while parsing: 5+#[C11CO5
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] 5+#[C11CO5
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '5+#[C11CO5' for input: '5+#[C11CO5'
# [03:10:17] SMILES Parse Error: syntax error while parsing: (CCC=1C)O12O323
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] (CCC=1C)O12O323
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '(CCC=1C)O12O323' for input: '(CCC=1C)O12O323'
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'N][no5Cc]+]][ncn5Cn5n]oCF3[35' for input: 'N][no5Cc]+]][ncn5Cn5n]oCF3[35'
# [03:10:17] SMILES Parse Error: syntax error while parsing: ((CCCC)CCCC=)CC1OC1
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] ((CCCC)CCCC=)CC1OC1
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '((CCCC)CCCC=)CC1OC1' for input: '((CCCC)CCCC=)CC1OC1'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 3 to itself for input: 'C3O=NC1#2#123'
# [03:10:17] SMILES Parse Error: syntax error while parsing: #[#n2]oc=2
# [03:10:17] SMILES Parse Error: check for mistakes around position 1:
# [03:10:17] #[#n2]oc=2
# [03:10:17] ^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '#[#n2]oc=2' for input: '#[#n2]oc=2'
# [03:10:17] SMILES Parse Error: ring closure 2 duplicates bond between atom 2 and atom 9 for input: 'oCC12NNOCOON12'
# [03:10:17] SMILES Parse Error: duplicated ring closure 2 bonds atom 2 to itself for input: 'CCN22(CC2(CCC2)1)1'
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCC(2=CCCCC23=CN)3
# [03:10:17] SMILES Parse Error: check for mistakes around position 5:
# [03:10:17] CCC(2=CCCCC23=CN)3
# [03:10:17] ~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCC(2=CCCCC23=CN)3' for input: 'CCC(2=CCCCC23=CN)3'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [O5CO1C(O)1=C11C5
# [03:10:17] SMILES Parse Error: check for mistakes around position 3:
# [03:10:17] [O5CO1C(O)1=C11C5
# [03:10:17] ~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[O5CO1C(O)1=C11C5' for input: '[O5CO1C(O)1=C11C5'
# [03:10:17] SMILES Parse Error: syntax error while parsing: NC=(C11#CC)
# [03:10:17] SMILES Parse Error: check for mistakes around position 4:
# [03:10:17] NC=(C11#CC)
# [03:10:17] ~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'NC=(C11#CC)' for input: 'NC=(C11#CC)'
# [03:10:17] Explicit valence for atom # 0 F, 2, is greater than permitted
# [03:10:17] SMILES Parse Error: syntax error while parsing: CCC((C1CCN1CCCC))
# [03:10:17] SMILES Parse Error: check for mistakes around position 5:
# [03:10:17] CCC((C1CCN1CCCC))
# [03:10:17] ~~~~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES 'CCC((C1CCN1CCCC))' for input: 'CCC((C1CCN1CCCC))'
# [03:10:17] SMILES Parse Error: syntax error while parsing: [[n=#OO
# [03:10:17] SMILES Parse Error: check for mistakes around position 2:
# [03:10:17] [[n=#OO
# [03:10:17] ~^
# [03:10:17] SMILES Parse Error: Failed parsing SMILES '[[n=#OO' for input: '[[n=#OO'
# [03:10:17] SMILES Parse Error: duplicated ring closure 1 bonds atom 1 to itself for input: 'cc11C1CCCO1'
# [03:10:17] SMILES Parse Error: extra close parentheses while parsing: C112CC)C(C2C(=2)2
# [03:10:17] SMILES Parse Error: check for mistakes around position 7:
# [03:10:17] C112CC)C(C2C(=2)2
# [03:10:17] ~~~~~~^
# ...
# [03:10:18] ]=OC1CC1
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES ']=OC1CC1' for input: ']=OC1CC1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: n-CO1C332C[1N2
# [03:10:18] SMILES Parse Error: check for mistakes around position 14:
# [03:10:18] n-CO1C332C[1N2
# [03:10:18] ~~~~~~~~~~~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'n-CO1C332C[1N2' for input: 'n-CO1C332C[1N2'
# [03:10:18] SMILES Parse Error: syntax error while parsing: #+]
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] #+]
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '#+]' for input: '#+]'
# [03:10:18] SMILES Parse Error: duplicated ring closure 2 bonds atom 10 to itself for input: 'C=CCCCCC1CNCO21#2'
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'N1Fo]5c[#+c5#]O2]o4-F2+5-C++(-(-2))1245' for input: 'N1Fo]5c[#+c5#]O2]o4-F2+5-C++(-(-2))1245'
# [03:10:18] SMILES Parse Error: syntax error while parsing: 2N41=NO124
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] 2N41=NO124
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '2N41=NO124' for input: '2N41=NO124'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (C(1CCOC)2CC)N1O121
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (C(1CCOC)2CC)N1O121
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(C(1CCOC)2CC)N1O121' for input: '(C(1CCOC)2CC)N1O121'
# [03:10:18] SMILES Parse Error: ring closure 2 duplicates bond between atom 8 and atom 9 for input: 'C#CCCN4C3CC=C2C234'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (OO1NCC3C)CNCC1O3
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (OO1NCC3C)CNCC1O3
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(OO1NCC3C)CNCC1O3' for input: '(OO1NCC3C)CNCC1O3'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (O#1#OCC)OCCCN=O1
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (O#1#OCC)OCCCN=O1
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(O#1#OCC)OCCCN=O1' for input: '(O#1#OCC)OCCCN=O1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: CCCCO1CC1CCC=
# [03:10:18] SMILES Parse Error: check for mistakes around position 13:
# [03:10:18] CCCCO1CC1CCC=
# [03:10:18] ~~~~~~~~~~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'CCCCO1CC1CCC=' for input: 'CCCCO1CC1CCC='
# [03:10:18] SMILES Parse Error: duplicated ring closure 1 bonds atom 4 to itself for input: 'CCCCC1(OCCOCC2)12'
# [03:10:18] SMILES Parse Error: syntax error while parsing: #[N+c5542Fo]co-24
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] #[N+c5542Fo]co-24
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '#[N+c5542Fo]co-24' for input: '#[N+c5542Fo]co-24'
# [03:10:18] Explicit valence for atom # 1 O, 3, is greater than permitted
# [03:10:18] SMILES Parse Error: syntax error while parsing: 3O1CC=COCCCNC13
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] 3O1CC=COCCCNC13
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '3O1CC=COCCCNC13' for input: '3O1CC=COCCCNC13'
# [03:10:18] SMILES Parse Error: duplicated ring closure 2 bonds atom 7 to itself for input: 'OC1CC1CC1=CC#12323'
# [03:10:18] SMILES Parse Error: extra close parentheses while parsing: FNN=NCCCC)C(=N
# [03:10:18] SMILES Parse Error: check for mistakes around position 10:
# [03:10:18] FNN=NCCCC)C(=N
# [03:10:18] ~~~~~~~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'FNN=NCCCC)C(=N' for input: 'FNN=NCCCC)C(=N'
# [03:10:18] SMILES Parse Error: syntax error while parsing: ((OCO1N3C)C)CN13
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] ((OCO1N3C)C)CN13
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '((OCO1N3C)C)CN13' for input: '((OCO1N3C)C)CN13'
# [03:10:18] SMILES Parse Error: ring closure 1 duplicates bond between atom 6 and atom 7 for input: 'CCCCCCC1C111'
# [03:10:18] SMILES Parse Error: syntax error while parsing: ]C=c=21CC112=NC1
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] ]C=c=21CC112=NC1
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES ']C=c=21CC112=NC1' for input: ']C=c=21CC112=NC1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: ()
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] ()
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '()' for input: '()'
# [03:10:18] SMILES Parse Error: syntax error while parsing: ((+)CC2NC1CC)12
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] ((+)CC2NC1CC)12
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '((+)CC2NC1CC)12' for input: '((+)CC2NC1CC)12'
# [03:10:18] SMILES Parse Error: syntax error while parsing: CCCCOCC(=#C=C)
# [03:10:18] SMILES Parse Error: check for mistakes around position 10:
# [03:10:18] CCCCOCC(=#C=C)
# [03:10:18] ~~~~~~~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'CCCCOCC(=#C=C)' for input: 'CCCCOCC(=#C=C)'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (CCCCCCOOCC)COCO1212
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (CCCCCCOOCC)COCO1212
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(CCCCCCOOCC)COCO1212' for input: '(CCCCCCOOCC)COCO1212'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (NNCCC=CC#OCCN)O
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (NNCCC=CC#OCCN)O
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(NNCCC=CC#OCCN)O' for input: '(NNCCC=CC#OCCN)O'
# [03:10:18] SMILES Parse Error: duplicated ring closure 1 bonds atom 2 to itself for input: 'nNC(CCCC(#C)O)11'
# [03:10:18] SMILES Parse Error: syntax error while parsing: -[O
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] -[O
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '-[O' for input: '-[O'
# [03:10:18] SMILES Parse Error: syntax error while parsing: [4F4OC=OCO#1O1
# [03:10:18] SMILES Parse Error: check for mistakes around position 4:
# [03:10:18] [4F4OC=OCO#1O1
# [03:10:18] ~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '[4F4OC=OCO#1O1' for input: '[4F4OC=OCO#1O1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: 1()1
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] 1()1
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '1()1' for input: '1()1'
# [03:10:18] SMILES Parse Error: duplicated ring closure 1 bonds atom 8 to itself for input: 'CC1CCCCCC2C111112'
# [03:10:18] SMILES Parse Error: duplicated ring closure 1 bonds atom 1 to itself for input: 'CC1=1O(CNCCC1CN)1'
# [03:10:18] SMILES Parse Error: extra open parentheses while parsing: CC(C12(C=C]1C=)2=)
# [03:10:18] SMILES Parse Error: check for mistakes around position 3:
# [03:10:18] CC(C12(C=C]1C=)2=)
# [03:10:18] ~~^
# [03:10:18] SMILES Parse Error: extra open parentheses while parsing: CC(C12(C=C]1C=)2=)
# [03:10:18] SMILES Parse Error: check for mistakes around position 7:
# [03:10:18] CC(C12(C=C]1C=)2=)
# [03:10:18] ~~~~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'CC(C12(C=C]1C=)2=)' for input: 'CC(C12(C=C]1C=)2=)'
# [03:10:18] SMILES Parse Error: syntax error while parsing: +1NCCN1
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] +1NCCN1
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '+1NCCN1' for input: '+1NCCN1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: ((OO1CNCN)CO)#1
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] ((OO1CNCN)CO)#1
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '((OO1CNCN)CO)#1' for input: '((OO1CNCN)CO)#1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (((n)C(CC=2=))1)O21
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (((n)C(CC=2=))1)O21
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(((n)C(CC=2=))1)O21' for input: '(((n)C(CC=2=))1)O21'
# [03:10:18] Explicit valence for atom # 9 C, 6, is greater than permitted
# [03:10:18] Explicit valence for atom # 4 O, 5, is greater than permitted
# [03:10:18] SMILES Parse Error: syntax error while parsing: =CC(CC#1C22C#)313
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] =CC(CC#1C22C#)313
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '=CC(CC#1C22C#)313' for input: '=CC(CC#1C22C#)313'
# [03:10:18] SMILES Parse Error: syntax error while parsing: 3+1#1N=1#13
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] 3+1#1N=1#13
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '3+1#1N=1#13' for input: '3+1#1N=1#13'
# [03:10:18] SMILES Parse Error: syntax error while parsing: +4CNO##221N14
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] +4CNO##221N14
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '+4CNO##221N14' for input: '+4CNO##221N14'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (CN(C2O)1)OCCC12
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (CN(C2O)1)OCCC12
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(CN(C2O)1)OCCC12' for input: '(CN(C2O)1)OCCC12'
# [03:10:18] SMILES Parse Error: syntax error while parsing: cn[]C]#N
# [03:10:18] SMILES Parse Error: check for mistakes around position 4:
# [03:10:18] cn[]C]#N
# [03:10:18] ~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'cn[]C]#N' for input: 'cn[]C]#N'
# [03:10:18] SMILES Parse Error: syntax error while parsing: ()43OCC#]34
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] ()43OCC#]34
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '()43OCC#]34' for input: '()43OCC#]34'
# [03:10:18] SMILES Parse Error: syntax error while parsing: 5NC1=CCC13CC1NO#135
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] 5NC1=CCC13CC1NO#135
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '5NC1=CCC13CC1NO#135' for input: '5NC1=CCC13CC1NO#135'
# [03:10:18] SMILES Parse Error: syntax error while parsing: 4O2#OC=24
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] 4O2#OC=24
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '4O2#OC=24' for input: '4O2#OC=24'
# [03:10:18] SMILES Parse Error: syntax error while parsing: =oCCCCC2=C1)C(12
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] =oCCCCC2=C1)C(12
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '=oCCCCC2=C1)C(12' for input: '=oCCCCC2=C1)C(12'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (CCCCCCCN)C3CN113
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (CCCCCCCN)C3CN113
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(CCCCCCCN)C3CN113' for input: '(CCCCCCCN)C3CN113'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (#2F)n#1CCCCN#1=2
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (#2F)n#1CCCCN#1=2
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(#2F)n#1CCCCN#1=2' for input: '(#2F)n#1CCCCN#1=2'
# [03:10:18] SMILES Parse Error: syntax error while parsing: [+11=N
# [03:10:18] SMILES Parse Error: check for mistakes around position 2:
# [03:10:18] [+11=N
# [03:10:18] ~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '[+11=N' for input: '[+11=N'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (CC121C)CCC(C2)OC2N2
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (CC121C)CCC(C2)OC2N2
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(CC121C)CCC(C2)OC2N2' for input: '(CC121C)CCC(C2)OC2N2'
# [03:10:18] SMILES Parse Error: ring closure 1 duplicates bond between atom 2 and atom 3 for input: 'cON1C1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (((#1)OO2]1O=CCC)C)N2
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (((#1)OO2]1O=CCC)C)N2
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(((#1)OO2]1O=CCC)C)N2' for input: '(((#1)OO2]1O=CCC)C)N2'
# [03:10:18] SMILES Parse Error: ring closure 2 duplicates bond between atom 0 and atom 1 for input: 'O32n23'
# [03:10:18] SMILES Parse Error: syntax error while parsing: +o1[cFO5N[c4-o5]+[+[-52o[o[[--o5F4o5c]545c[c5+F+c+co[4[o]-[5c+[ccn125
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] +o1[cFO5N[c4-o5]+[+[-52o[o[[--o5F4o5c]545
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '+o1[cFO5N[c4-o5]+[+[-52o[o[[--o5F4o5c]545c[c5+F+c+co[4[o]-[5c+[ccn125' for input: '+o1[cFO5N[c4-o5]+[+[-52o[o[[--o5F4o5c]545c[c5+F+c+co[4[o]-[5c+[ccn125'
# [03:10:18] SMILES Parse Error: syntax error while parsing: CNC(CCC=((ONOC)))
# [03:10:18] SMILES Parse Error: check for mistakes around position 9:
# [03:10:18] CNC(CCC=((ONOC)))
# [03:10:18] ~~~~~~~~^
# [03:10:18] SMILES Parse Error: extra open parentheses while parsing: CNC(CCC=((ONOC)))
# [03:10:18] SMILES Parse Error: check for mistakes around position 4:
# [03:10:18] CNC(CCC=((ONOC)))
# [03:10:18] ~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'CNC(CCC=((ONOC)))' for input: 'CNC(CCC=((ONOC)))'
# [03:10:18] SMILES Parse Error: syntax error while parsing: CC11C(NCC1+C11)1
# [03:10:18] SMILES Parse Error: check for mistakes around position 11:
# [03:10:18] CC11C(NCC1+C11)1
# [03:10:18] ~~~~~~~~~~^
# [03:10:18] SMILES Parse Error: extra open parentheses while parsing: CC11C(NCC1+C11)1
# [03:10:18] SMILES Parse Error: check for mistakes around position 6:
# [03:10:18] CC11C(NCC1+C11)1
# [03:10:18] ~~~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'CC11C(NCC1+C11)1' for input: 'CC11C(NCC1+C11)1'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (C4CCCCCC)CCCCN4
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (C4CCCCCC)CCCCN4
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(C4CCCCCC)CCCCN4' for input: '(C4CCCCCC)CCCCN4'
# [03:10:18] SMILES Parse Error: syntax error while parsing: (cc-F5C11ON)C115
# [03:10:18] SMILES Parse Error: check for mistakes around position 1:
# [03:10:18] (cc-F5C11ON)C115
# [03:10:18] ^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES '(cc-F5C11ON)C115' for input: '(cc-F5C11ON)C115'
# [03:10:18] SMILES Parse Error: syntax error while parsing: CC1C=C(C=#CCC)C313
# [03:10:18] SMILES Parse Error: check for mistakes around position 10:
# [03:10:18] CC1C=C(C=#CCC)C313
# [03:10:18] ~~~~~~~~~^
# [03:10:18] SMILES Parse Error: extra open parentheses while parsing: CC1C=C(C=#CCC)C313
# [03:10:18] SMILES Parse Error: check for mistakes around position 7:
# [03:10:18] CC1C=C(C=#CCC)C313
# [03:10:18] ~~~~~~^
# [03:10:18] SMILES Parse Error: Failed parsing SMILES 'CC1C=C(C=#CCC)C313' for input: 'CC1C=C(C=#CCC)C313'
# [03:10:18] SMILES Parse Error: ring closure 1 duplicates bond between atom 9 and atom 10 for input: 'CC1CCC#OCNN1O1C1'
# Total SMILES: 10000
# Valid SMILES: 685 (6.85%)
# Invalid SMILES: 9315 (93.15%)
# Unique SMILES: 372 (3.72%)
# Corrected SMILES: 285 (2.85%)
#
# Property Statistics:
#        molecular_weight        logp   num_atoms   num_rings
# count        685.000000  685.000000  685.000000  685.000000
# mean          76.401487    0.724509    5.356204    0.633577
# std           73.570762    1.151959    5.190393    0.812033
# min            0.000000   -1.541600    0.000000    0.000000
# 25%            0.000000    0.000000    0.000000    0.000000
# 50%           72.093900    0.152500    5.000000    0.000000
# 75%          145.110279    1.503700   10.000000    1.000000
# max          220.178693    5.317300   15.000000    4.000000
#
# Sample of Invalid SMILES:
# ]
# H##4n=2]111
# NNCCCCCCC2C
# CC#CCC1CNO2O1=
# c)H(]
#
# Full property analysis saved to 'molecule_properties.csv'

# %%
analysis['valid']
# Out:
# 685

# %% [markdown]
# 7.2 Novelty Assessment
# We can check if our generated molecules are novel (not present in the training set):

# %%
from typing import List, Set

def check_novelty(generated_smiles: List[str], training_smiles: Set[str]) -> tuple[List[str], float]:
    """
    Check the novelty of generated SMILES strings against a training set.

    This function determines which of the generated SMILES strings are not present
    in the training set, and calculates the novelty rate.

    Args:
        generated_smiles (List[str]): A list of SMILES strings generated by the model.
        training_smiles (Set[str]): A set of SMILES strings used for training the model.

    Returns:
        tuple[List[str], float]: A tuple containing:
            - A list of novel SMILES strings (those not in the training set).
            - The novelty rate as a float (proportion of novel SMILES).

    Example:
        >>> training_set = {"CC", "CCO", "CCCC"}
        >>> generated_smiles = ["CC", "CCC", "CCCO", "CCO"]
        >>> novel, rate = check_novelty(generated_smiles, training_set)
        >>> print(novel)
        ['CCC', 'CCCO']
        >>> print(f"Novelty rate: {rate:.2%}")
        Novelty rate: 50.00%
    """
    novel_molecules = [s for s in generated_smiles if s not in training_smiles]
    novelty_rate = len(novel_molecules) / len(generated_smiles)
    return novel_molecules, novelty_rate

training_set = set(smiles_list)  # Convert training list to a set for faster lookup
novel_molecules, novelty_rate = check_novelty(generated_smiles, training_set)

print(f"Novelty rate: {novelty_rate:.2%}")
print(f"Number of novel molecules: {len(novel_molecules)}")
print("\nSample of novel molecules:")
for smiles in novel_molecules[:5]:  # Print first 5 novel SMILES
    print(smiles)
# Out:
# Novelty rate: 99.55%
# Number of novel molecules: 9955
#
# Sample of novel molecules:
# ]
# H##4n=2]111
# NNCCCCCCC2C
# CC#CCC1CNO2O1=
# c)H(]

# %% [markdown]
# 7.3 Basic Property Calculation: We can calculate some basic molecular properties for valid molecules:

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
from typing import List, Dict, Optional

def calculate_properties(smiles: str) -> Optional[Dict[str, float]]:
    """
    Calculate molecular properties for a given SMILES string.

    This function computes several key molecular properties using RDKit's Descriptors module.
    If the SMILES string is invalid or cannot be converted to a molecule, the function returns None.

    Args:
        smiles (str): A SMILES string representing a molecule.

    Returns:
        Optional[Dict[str, float]]: A dictionary containing the calculated properties, or None if the SMILES is invalid.
        The dictionary includes the following properties:
            - 'MolWt': Exact molecular weight
            - 'LogP': Octanol-water partition coefficient
            - 'NumHDonors': Number of hydrogen bond donors
            - 'NumHAcceptors': Number of hydrogen bond acceptors

    Example:
        >>> props = calculate_properties("CCO")
        >>> print(props)
        {'MolWt': 46.06844, 'LogP': -0.0014, 'NumHDonors': 1, 'NumHAcceptors': 1}
    """
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        return {
            'MolWt': Descriptors.ExactMolWt(mol),
            'LogP': Descriptors.MolLogP(mol),
            'NumHDonors': Descriptors.NumHDonors(mol),
            'NumHAcceptors': Descriptors.NumHAcceptors(mol)
        }
    return None

def calculate_properties_for_valid_mols(generated_smiles: List[str]) -> List[Optional[Dict[str, float]]]:
    """
    Calculate properties for a list of generated SMILES strings, considering only valid molecules.

    This function iterates through the list of generated SMILES strings, calculates properties
    for valid molecules, and returns a list of property dictionaries.

    Args:
        generated_smiles (List[str]): A list of SMILES strings generated by the model.

    Returns:
        List[Optional[Dict[str, float]]]: A list of dictionaries containing calculated properties
        for valid molecules. Invalid SMILES strings are excluded from the result.

    Example:
        >>> smiles_list = ["CCO", "InvalidSMILES", "C1=CC=CC=C1"]
        >>> properties_list = calculate_properties_for_valid_mols(smiles_list)
        >>> print(len(properties_list))
        2
    """
    return [calculate_properties(s) for s in generated_smiles if Chem.MolFromSmiles(s)]

valid_mols_properties = calculate_properties_for_valid_mols(novel_molecules)

print(f"Number of valid molecules: {len(valid_mols_properties)}")
for i, props in enumerate(valid_mols_properties, 1):
    if props:
        print(f"Molecule {i}:")
        for key, value in props.items():
            print(f"  {key}: {value}")
        print()
# Out:
# Streaming output truncated to the last 5000 lines.
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+' for input: '+'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C#=((CCC3CC1NC=112
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C#=((CCC3CC1NC=112
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C#=((CCC3CC1NC=112' for input: '<C#=((CCC3CC1NC=112'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C=11C2)CCCCC)N1OO2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C=11C2)CCCCC)N1OO2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C=11C2)CCCCC)N1OO2' for input: '<C=11C2)CCCCC)N1OO2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCC(CCCCC21C11
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCC(CCCCC21C11
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCC(CCCCC21C11' for input: '<CCCC(CCCCC21C11'
# [03:38:10] SMILES Parse Error: syntax error while parsing: N(5n(
# [03:38:10] SMILES Parse Error: check for mistakes around position 3:
# [03:38:10] N(5n(
# [03:38:10] ~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'N(5n(' for input: 'N(5n('
# [03:38:10] SMILES Parse Error: syntax error while parsing: 4C3=#=###C=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 4C3=#=###C=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '4C3=#=###C=' for input: '4C3=#=###C='
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OCC1=O(c=C==ON#NC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OCC1=O(c=C==ON#NC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OCC1=O(c=C==ON#NC' for input: '<OCC1=O(c=C==ON#NC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC11=1)C2)1NO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC11=1)C2)1NO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC11=1)C2)1NO' for input: '<CC11=1)C2)1NO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: -NCO1=)CN=C#O(12
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] -NCO1=)CN=C#O(12
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '-NCO1=)CN=C#O(12' for input: '-NCO1=)CN=C#O(12'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCO1C2CC=CC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCO1C2CC=CC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCO1C2CC=CC' for input: '<CCO1C2CC=CC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCOOCCCC1)C()2C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCOOCCCC1)C()2C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCOOCCCC1)C()2C' for input: '<CCCOOCCCC1)C()2C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC112(CC)OC)C2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC112(CC)OC)C2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC112(CC)OC)C2' for input: '<CC112(CC)OC)C2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: +CC12CCO-C1O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] +CC12CCO-C1O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+CC12CCO-C1O' for input: '+CC12CCO-C1O'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: nc1)]CNON(=)CNC2C[N
# [03:38:10] SMILES Parse Error: check for mistakes around position 4:
# [03:38:10] nc1)]CNON(=)CNC2C[N
# [03:38:10] ~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'nc1)]CNON(=)CNC2C[N' for input: 'nc1)]CNON(=)CNC2C[N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC12CO(CCCC(O)2C21
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC12CO(CCCC(O)2C21
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC12CO(CCCC(O)2C21' for input: '<CC12CO(CCCC(O)2C21'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCC((C()C1OO2=23O)1#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCC((C()C1OO2=23O)1#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCC((C()C1OO2=23O)1#' for input: '<CCCCCC((C()C1OO2=23O)1#'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C)CC1CCONC=1C2=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C)CC1CCONC=1C2=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C)CC1CCONC=1C2=' for input: '<C)CC1CCONC=1C2='
# [03:38:10] SMILES Parse Error: syntax error while parsing: 4o#OCC2(
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 4o#OCC2(
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '4o#OCC2(' for input: '4o#OCC2('
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CC)2C12OCCC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CC)2C12OCCC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CC)2C12OCCC' for input: '<CC1CC)2C12OCCC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C##1(3CC1O1=O31)
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C##1(3CC1O1=O31)
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C##1(3CC1O1=O31)' for input: '<C##1(3CC1O1=O31)'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 4]C(()11CC=OO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 4]C(()11CC=OO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '4]C(()11CC=OO' for input: '4]C(()11CC=OO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CNCCCCC)C11CC22)1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CNCCCCC)C11CC22)1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CNCCCCC)C11CC22)1' for input: '<CNCCCCC)C11CC22)1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: cOH
# [03:38:10] SMILES Parse Error: check for mistakes around position 3:
# [03:38:10] cOH
# [03:38:10] ~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cOH' for input: 'cOH'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCC3111C1C2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCC3111C1C2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCC3111C1C2' for input: '<CCCCCC3111C1C2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: =H3#COON##
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] =H3#COON##
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '=H3#COON##' for input: '=H3#COON##'
# [03:38:10] SMILES Parse Error: syntax error while parsing: (OC1=111CCC)O11
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] (OC1=111CCC)O11
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '(OC1=111CCC)O11' for input: '(OC1=111CCC)O11'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C(1CCCCCCCC)2=3
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C(1CCCCCCCC)2=3
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C(1CCCCCCCC)2=3' for input: '<C(1CCCCCCCC)2=3'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1COCCCCCOCCO=CC=1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1COCCCCCOCCO=CC=1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1COCCCCCOCCO=CC=1' for input: '1COCCCCCOCCO=CC=1'
# [03:38:10] SMILES Parse Error: unclosed ring for input: 'o5#C1C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OCC1C2C=1CC)
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OCC1C2C=1CC)
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OCC1C2C=1CC)' for input: '<OCC1C2C=1CC)'
# [03:38:10] SMILES Parse Error: syntax error while parsing: oH1CN1CO=213
# [03:38:10] SMILES Parse Error: check for mistakes around position 2:
# [03:38:10] oH1CN1CO=213
# [03:38:10] ~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'oH1CN1CO=213' for input: 'oH1CN1CO=213'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 2=+=1=)C3(1c--+F<H<<O<o<c)<<<<[5<=<<=H<5<<<<<(5O<5<<<<o<<]<<<<<<<<<=cc4<<<<<=<<<5<<=(<35--<<<<5<5<-(
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 2=+=1=)C3(1c--+F<H<<O<o<c)<<<<[5<=<<=H<5<
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '2=+=1=)C3(1c--+F<H<<O<o<c)<<<<[5<=<<=H<5<<<<<(5O<5<<<<o<<]<<<<<<<<<=cc4<<<<<=<<<5<<=(<35--<<<<5<5<-(' for input: '2=+=1=)C3(1c--+F<H<<O<o<c)<<<<[5<=<<=H<5<<<<<(5O<5<<<<o<<]<<<<<<<<<=cc4<<<<<=<<<5<<=(<35--<<<<5<5<-('
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCC2C1CCC2OOO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCC2C1CCC2OOO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCC2C1CCC2OOO' for input: '<CC1CCC2C1CCC2OOO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OCCC1C)1CCC3#C1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OCCC1C)1CCC3#C1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OCCC1C)1CCC3#C1' for input: '<OCCC1C)1CCC3#C1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <COCC11C1CCOCCNC#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <COCC11C1CCOCCNC#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<COCC11C1CCOCCNC#' for input: '<COCC11C1CCOCCNC#'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: cc=12)2CCCNCO]
# [03:38:10] SMILES Parse Error: check for mistakes around position 6:
# [03:38:10] cc=12)2CCCNCO]
# [03:38:10] ~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cc=12)2CCCNCO]' for input: 'cc=12)2CCCNCO]'
# [03:38:10] SMILES Parse Error: syntax error while parsing: Hc1=C2NC1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] Hc1=C2NC1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'Hc1=C2NC1' for input: 'Hc1=C2NC1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCC1(1CC(=O111
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCC1(1CC(=O111
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCC1(1CC(=O111' for input: '<CCCC1(1CC(=O111'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ][C=CCC2O1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ][C=CCC2O1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '][C=CCC2O1' for input: '][C=CCC2O1'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: Fc=CC2C)CC122
# [03:38:10] SMILES Parse Error: check for mistakes around position 8:
# [03:38:10] Fc=CC2C)CC122
# [03:38:10] ~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'Fc=CC2C)CC122' for input: 'Fc=CC2C)CC122'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 2=n]+F2#H
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 2=n]+F2#H
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '2=n]+F2#H' for input: '2=n]+F2#H'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 41CC#NC=C=CCCO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 41CC#NC=C=CCCO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '41CC#NC=C=CCCO' for input: '41CC#NC=C=CCCO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1O12CCCOCOON
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1O12CCCOCOON
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1O12CCCOCOON' for input: '<CC1O12CCCOCOON'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1(NC(=C=C=N2=O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1(NC(=C=C=N2=O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1(NC(=C=C=N2=O' for input: '<CC1(NC(=C=C=N2=O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: -cCC]+CCO=)C1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] -cCC]+CCO=)C1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '-cCC]+CCO=)C1' for input: '-cCC]+CCO=)C1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <+CCC)CCC)C)(CO3C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <+CCC)CCC)C)(CO3C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<+CCC)CCC)C)(CO3C' for input: '<+CCC)CCC)C)(CO3C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 4CC=C2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 4CC=C2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '4CC=C2' for input: '4CC=C2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCONCC=))3131
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCONCC=))3131
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCONCC=))3131' for input: '<CCCCONCC=))3131'
# [03:38:10] SMILES Parse Error: syntax error while parsing: -(4C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] -(4C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '-(4C' for input: '-(4C'
# [03:38:10] non-ring atom 0 marked aromatic
# [03:38:10] SMILES Parse Error: syntax error while parsing: =1434#OONOFOC-1#N+=N
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] =1434#OONOFOC-1#N+=N
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '=1434#OONOFOC-1#N+=N' for input: '=1434#OONOFOC-1#N+=N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C#11CCCC=(N11C)O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C#11CCCC=(N11C)O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C#11CCCC=(N11C)O' for input: '<C#11CCCC=(N11C)O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: )O3F##
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] )O3F##
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ')O3F##' for input: ')O3F##'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCC2N(C=1N
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCC2N(C=1N
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCC2N(C=1N' for input: '<CCCCC2N(C=1N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCCCO11CC=N
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCCCO11CC=N
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCCCO11CC=N' for input: '<CC1CCCCO11CC=N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <cO1CCC==
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <cO1CCC==
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<cO1CCC==' for input: '<cO1CCC=='
# [03:38:10] SMILES Parse Error: ring closure 1 duplicates bond between atom 2 and atom 3 for input: 'OO3C1O1OOC#O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: nCC((==COCCONCOO
# [03:38:10] SMILES Parse Error: check for mistakes around position 5:
# [03:38:10] nCC((==COCCONCOO
# [03:38:10] ~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'nCC((==COCCONCOO' for input: 'nCC((==COCCONCOO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: cn3[cONFccoc[<<<4c--1NO4#CC2==N
# [03:38:10] SMILES Parse Error: check for mistakes around position 6:
# [03:38:10] cn3[cONFccoc[<<<4c--1NO4#CC2==N
# [03:38:10] ~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cn3[cONFccoc[<<<4c--1NO4#CC2==N' for input: 'cn3[cONFccoc[<<<4c--1NO4#CC2==N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 2(F5+-[55onc++4n455n5cH5H-cn-5]n45+H5[FoFn[-(4F[-oHO+H[-[N[-5oo5o2c[4[c]
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 2(F5+-[55onc++4n455n5cH5H-cn-5]n45+H5[FoF
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '2(F5+-[55onc++4n455n5cH5H-cn-5]n45+H5[FoFn[-(4F[-oHO+H[-[N[-5oo5o2c[4[c]' for input: '2(F5+-[55onc++4n455n5cH5H-cn-5]n45+H5[FoFn[-(4F[-oHO+H[-[N[-5oo5o2c[4[c]'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCC2O113C)CCC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCC2O113C)CCC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCC2O113C)CCC' for input: '<CC1CCC2O113C)CCC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: [HnHo
# [03:38:10] SMILES Parse Error: check for mistakes around position 3:
# [03:38:10] [HnHo
# [03:38:10] ~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '[HnHo' for input: '[HnHo'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C=C12CCN1)COCC)C1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C=C12CCN1)COCC)C1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C=C12CCN1)COCC)C1' for input: '<C=C12CCN1)COCC)C1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <O1CC)1(C)CNCC]11
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <O1CC)1(C)CNCC]11
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<O1CC)1(C)CNCC]11' for input: '<O1CC)1(C)CNCC]11'
# [03:38:10] SMILES Parse Error: syntax error while parsing: =NC2CCO221
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] =NC2CCO221
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '=NC2CCO221' for input: '=NC2CCO221'
# [03:38:10] SMILES Parse Error: syntax error while parsing: cnNn-([
# [03:38:10] SMILES Parse Error: check for mistakes around position 6:
# [03:38:10] cnNn-([
# [03:38:10] ~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cnNn-([' for input: 'cnNn-(['
# [03:38:10] SMILES Parse Error: syntax error while parsing: 3no=5)o<<<)=<<n5<)+5<<<33(<[+<<<<n<<<42<F2O<<<<<<(<<<[<<<<<<([<5o<<c<<2F<5<<<<1<<<<<<<N4<5<<<<<<<c<5
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 3no=5)o<<<)=<<n5<)+5<<<33(<[+<<<<n<<<42<F
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '3no=5)o<<<)=<<n5<)+5<<<33(<[+<<<<n<<<42<F2O<<<<<<(<<<[<<<<<<([<5o<<c<<2F<5<<<<1<<<<<<<N4<5<<<<<<<c<5' for input: '3no=5)o<<<)=<<n5<)+5<<<33(<[+<<<<n<<<42<F2O<<<<<<(<<<[<<<<<<([<5o<<c<<2F<5<<<<1<<<<<<<N4<5<<<<<<<c<5'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ==C4211
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ==C4211
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '==C4211' for input: '==C4211'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1CCCCCC)CC1=C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1CCCCCC)CC1=C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1CCCCCC)CC1=C' for input: '1CCCCCC)CC1=C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: =n-O-1O]=O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] =n-O-1O]=O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '=n-O-1O]=O' for input: '=n-O-1O]=O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 3O]o#N=#C#1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 3O]o#N=#C#1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '3O]o#N=#C#1' for input: '3O]o#N=#C#1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <N1CCC()=N3NO1)N
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <N1CCC()=N3NO1)N
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<N1CCC()=N3NO1)N' for input: '<N1CCC()=N3NO1)N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 5OC#COCC3NN1OO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 5OC#COCC3NN1OO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '5OC#COCC3NN1OO' for input: '5OC#COCC3NN1OO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: nocnoNco5ncFon44+No4]HncH]-[c[con=#[c[o-nc4523ccHnc
# [03:38:10] SMILES Parse Error: check for mistakes around position 17:
# [03:38:10] nocnoNco5ncFon44+No4]HncH]-[c[con=#[c[o-n
# [03:38:10] ~~~~~~~~~~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'nocnoNco5ncFon44+No4]HncH]-[c[con=#[c[o-nc4523ccHnc' for input: 'nocnoNco5ncFon44+No4]HncH]-[c[con=#[c[o-nc4523ccHnc'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCC13C(C=11C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCC13C(C=11C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCC13C(C=11C' for input: '<CCCCCC13C(C=11C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 31C#1#C=##1CNOO##
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 31C#1#C=##1CNOO##
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '31C#1#C=##1CNOO##' for input: '31C#1#C=##1CNOO##'
# [03:38:10] SMILES Parse Error: syntax error while parsing: -<[CN#CC)(C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] -<[CN#CC)(C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '-<[CN#CC)(C' for input: '-<[CN#CC)(C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1N2(CCN23)C)C1OON
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1N2(CCN23)C)C1OON
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1N2(CCN23)C)C1OON' for input: '<CC1N2(CCN23)C)C1OON'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC(1CNC2C2C1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC(1CNC2C2C1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC(1CNC2C2C1' for input: '<CC(1CNC2C2C1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C=11==(COCC)=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C=11==(COCC)=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C=11==(COCC)=' for input: '<C=11==(COCC)='
# [03:38:10] SMILES Parse Error: syntax error while parsing: (CCCC2CCCCC1C2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] (CCCC2CCCCC1C2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '(CCCC2CCCCC1C2' for input: '(CCCC2CCCCC1C2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1COC2(=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1COC2(=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1COC2(=' for input: '1COC2(='
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C#CC(CCOC1CC2O21
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C#CC(CCOC1CC2O21
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C#CC(CCOC1CC2O21' for input: '<C#CC(CCOC1CC2O21'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ([+=1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ([+=1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '([+=1' for input: '([+=1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <NCC1(O=)CCCO1O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <NCC1(O=)CCCO1O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<NCC1(O=)CCCO1O' for input: '<NCC1(O=)CCCO1O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OC1COC(CCCC31
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OC1COC(CCCC31
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OC1COC(CCCC31' for input: '<OC1COC(CCCC31'
# [03:38:10] SMILES Parse Error: syntax error while parsing: n2o=C1+5C((oFcnF
# [03:38:10] SMILES Parse Error: check for mistakes around position 7:
# [03:38:10] n2o=C1+5C((oFcnF
# [03:38:10] ~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'n2o=C1+5C((oFcnF' for input: 'n2o=C1+5C((oFcnF'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 55NCC=N2#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 55NCC=N2#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '55NCC=N2#' for input: '55NCC=N2#'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CN)1C(CN1)2C=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CN)1C(CN1)2C=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CN)1C(CN1)2C=' for input: '<CN)1C(CN1)2C='
# [03:38:10] SMILES Parse Error: syntax error while parsing: (][c+4)-4c+3]ccnF5=-=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] (][c+4)-4c+3]ccnF5=-=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '(][c+4)-4c+3]ccnF5=-=' for input: '(][c+4)-4c+3]ccnF5=-='
# [03:38:10] SMILES Parse Error: syntax error while parsing: ]-O(CCCCCNCCOC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ]-O(CCCCCNCCOC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ']-O(CCCCCNCCOC' for input: ']-O(CCCCCNCCOC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: )F33c+11O43H+3#5(#NH]n+5=]5--+
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] )F33c+11O43H+3#5(#NH]n+5=]5--+
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ')F33c+11O43H+3#5(#NH]n+5=]5--+' for input: ')F33c+11O43H+3#5(#NH]n+5=]5--+'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OCCC(C(OCCC))C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OCCC(C(OCCC))C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OCCC(C(OCCC))C' for input: '<OCCC(C(OCCC))C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCC21CO)))C2C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCC21CO)))C2C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCC21CO)))C2C' for input: '<CCCC21CO)))C2C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: cFF(4-(((N-H+-+3n(4[+5cHno-4nc(3
# [03:38:10] SMILES Parse Error: check for mistakes around position 5:
# [03:38:10] cFF(4-(((N-H+-+3n(4[+5cHno-4nc(3
# [03:38:10] ~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cFF(4-(((N-H+-+3n(4[+5cHno-4nc(3' for input: 'cFF(4-(((N-H+-+3n(4[+5cHno-4nc(3'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <N-=)CCCCCCCC=1=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <N-=)CCCCCCCC=1=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<N-=)CCCCCCCC=1=' for input: '<N-=)CCCCCCCC=1='
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCHC=(CCC(C)OC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCHC=(CCC(C)OC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCHC=(CCC(C)OC' for input: '<CCHC=(CCC(C)OC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: =4o])n-c+4OOO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] =4o])n-c+4OOO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '=4o])n-c+4OOO' for input: '=4o])n-c+4OOO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C(1)2O1COCC)C=2=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C(1)2O1COCC)C=2=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C(1)2O1COCC)C=2=' for input: '<C(1)2O1COCC)C=2='
# [03:38:10] SMILES Parse Error: syntax error while parsing: (=]c(
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] (=]c(
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '(=]c(' for input: '(=]c('
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C2CCCC(C#OC1=NO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C2CCCC(C#OC1=NO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C2CCCC(C#OC1=NO' for input: '<C2CCCC(C#OC1=NO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCCCC2C2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCCCC2C2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCCCC2C2' for input: '<CC1CCCCC2C2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C1CCOC=CO)2)ONCN=1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C1CCOC=CO)2)ONCN=1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C1CCOC=CO)2)ONCN=1' for input: '<C1CCOC=CO)2)ONCN=1'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: C#O)1C22
# [03:38:10] SMILES Parse Error: check for mistakes around position 4:
# [03:38:10] C#O)1C22
# [03:38:10] ~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'C#O)1C22' for input: 'C#O)1C22'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: N1)1N1)OO
# [03:38:10] SMILES Parse Error: check for mistakes around position 3:
# [03:38:10] N1)1N1)OO
# [03:38:10] ~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'N1)1N1)OO' for input: 'N1)1N1)OO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCCO2C)4NC1N1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCCO2C)4NC1N1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCCO2C)4NC1N1' for input: '<CC1CCCO2C)4NC1N1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCC12OCN)OON=C2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCC12OCN)OON=C2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCC12OCN)OON=C2' for input: '<CCC12OCN)OON=C2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1(O=OCC1C(4=2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1(O=OCC1C(4=2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1(O=OCC1C(4=2' for input: '1(O=OCC1C(4=2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: +4H[][HO=CCNO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] +4H[][HO=CCNO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+4H[][HO=CCNO' for input: '+4H[][HO=CCNO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CNC2CC=)(2NCC#31O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CNC2CC=)(2NCC#31O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CNC2CC=)(2NCC#31O' for input: '<CNC2CC=)(2NCC#31O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: #CCCCCCC(CCCCCC31
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] #CCCCCCC(CCCCCC31
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '#CCCCCCC(CCCCCC31' for input: '#CCCCCCC(CCCCCC31'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <<CCCCCC1CC1=#C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <<CCCCCC1CC1=#C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<<CCCCCC1CC1=#C' for input: '<<CCCCCC1CC1=#C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ]c#(N=ON11
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ]c#(N=ON11
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ']c#(N=ON11' for input: ']c#(N=ON11'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 5(CC1(1112N=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 5(CC1(1112N=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '5(CC1(1112N=' for input: '5(CC1(1112N='
# [03:38:10] SMILES Parse Error: syntax error while parsing: n[#C##CN=)
# [03:38:10] SMILES Parse Error: check for mistakes around position 4:
# [03:38:10] n[#C##CN=)
# [03:38:10] ~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'n[#C##CN=)' for input: 'n[#C##CN=)'
# [03:38:10] SMILES Parse Error: duplicated ring closure 1 bonds atom 4 to itself for input: 'CCOCC1122'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCC#CC1CCCCC)CO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCC#CC1CCCCC)CO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCC#CC1CCCCC)CO' for input: '<CCC#CC1CCCCC)CO'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: o=N1)OC2))3
# [03:38:10] SMILES Parse Error: check for mistakes around position 5:
# [03:38:10] o=N1)OC2))3
# [03:38:10] ~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'o=N1)OC2))3' for input: 'o=N1)OC2))3'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCCC2CCCN=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCCC2CCCN=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCCC2CCCN=' for input: '<CCCCCCC2CCCN='
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC(CC1N3)N)2O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC(CC1N3)N)2O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC(CC1N3)N)2O' for input: '<CC(CC1N3)N)2O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: no[1=
# [03:38:10] SMILES Parse Error: check for mistakes around position 5:
# [03:38:10] no[1=
# [03:38:10] ~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'no[1=' for input: 'no[1='
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCC1CCNCCOO2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCC1CCNCCOO2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCC1CCNCCOO2' for input: '<CCCC1CCNCCOO2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ]4O#C1CNC3#N2C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ]4O#C1CNC3#N2C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ']4O#C1CNC3#N2C' for input: ']4O#C1CNC3#N2C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <NOCN2C(CC=CCC11O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <NOCN2C(CC=CCC11O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<NOCN2C(CC=CCC11O' for input: '<NOCN2C(CC=CCC11O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1CCC1=N2N==
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1CCC1=N2N==
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1CCC1=N2N==' for input: '1CCC1=N2N=='
# [03:38:10] SMILES Parse Error: syntax error while parsing: F+++=<+
# [03:38:10] SMILES Parse Error: check for mistakes around position 2:
# [03:38:10] F+++=<+
# [03:38:10] ~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'F+++=<+' for input: 'F+++=<+'
# [03:38:10] SMILES Parse Error: syntax error while parsing: #N11CC(C1OO1NOO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] #N11CC(C1OO1NOO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '#N11CC(C1OO1NOO' for input: '#N11CC(C1OO1NOO'
# [03:38:10] SMILES Parse Error: duplicated ring closure 2 bonds atom 3 to itself for input: 'cOOn22=OO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: [nC11)1NN
# [03:38:10] SMILES Parse Error: check for mistakes around position 3:
# [03:38:10] [nC11)1NN
# [03:38:10] ~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '[nC11)1NN' for input: '[nC11)1NN'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCCOC1C1C1=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCCOC1C1C1=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCCOC1C1C1=' for input: '<CCCCCCOC1C1C1='
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1NC2((CCCN)C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1NC2((CCCN)C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1NC2((CCCN)C' for input: '1NC2((CCCN)C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OC1CNCO=()C1C(1=3CN
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OC1CNCO=()C1C(1=3CN
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OC1CNCO=()C1C(1=3CN' for input: '<OC1CNCO=()C1C(1=3CN'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCC2(CC21C421C2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCC2(CC21C421C2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCC2(CC21C421C2' for input: '<CCC2(CC21C421C2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC=#C1=CCC1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC=#C1=CCC1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC=#C1=CCC1' for input: '<CC=#C1=CCC1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: cnO1CC=)3)1NO11
# [03:38:10] SMILES Parse Error: check for mistakes around position 8:
# [03:38:10] cnO1CC=)3)1NO11
# [03:38:10] ~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cnO1CC=)3)1NO11' for input: 'cnO1CC=)3)1NO11'
# [03:38:10] SMILES Parse Error: syntax error while parsing: +#-+F+n(O-n5OH[n1oHHHFH[5<ccc<5FncCC<-o-<<nccc4#oO2H<co4+]FH2FC+c+HF-<(<53F[--H55[<F<5n(+c-cFo<c4cc<
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] +#-+F+n(O-n5OH[n1oHHHFH[5<ccc<5FncCC<-o-<
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+#-+F+n(O-n5OH[n1oHHHFH[5<ccc<5FncCC<-o-<<nccc4#oO2H<co4+]FH2FC+c+HF-<(<53F[--H55[<F<5n(+c-cFo<c4cc<' for input: '+#-+F+n(O-n5OH[n1oHHHFH[5<ccc<5FncCC<-o-<<nccc4#oO2H<co4+]FH2FC+c+HF-<(<53F[--H55[<F<5n(+c-cFo<c4cc<'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC11CCCC(#CC=HO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC11CCCC(#CC=HO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC11CCCC(#CC=HO' for input: '<CC11CCCC(#CC=HO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: +CC1N2C122(=O211
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] +CC1N2C122(=O211
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+CC1N2C122(=O211' for input: '+CC1N2C122(=O211'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 2+5#1C(N11CCC3
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 2+5#1C(N11CCC3
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '2+5#1C(N11CCC3' for input: '2+5#1C(N11CCC3'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CC1(2CC(C#ON
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CC1(2CC(C#ON
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CC1(2CC(C#ON' for input: '<CC1CC1(2CC(C#ON'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCC=O2CCCC1CC1C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCC=O2CCCC1CC1C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCC=O2CCCC1CC1C' for input: '<CCCC=O2CCCC1CC1C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCO2CC(C=CCC)
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCO2CC(C=CCC)
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCO2CC(C=CCC)' for input: '<CCCCO2CC(C=CCC)'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C#=O2(CCC(1CO23
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C#=O2(CCC(1CO23
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C#=O2(CCC(1CO23' for input: '<C#=O2(CCC(1CO23'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <1ONC)C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <1ONC)C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<1ONC)C' for input: '<1ONC)C'
# [03:38:10] SMILES Parse Error: ring closure 1 duplicates bond between atom 1 and atom 2 for input: 'CF1O31cOO#O'
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'Cn]' for input: 'Cn]'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1==CC)OC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1==CC)OC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1==CC)OC' for input: '1==CC)OC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCC1C=OC(1)C1C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCC1C=OC(1)C1C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCC1C=OC(1)C1C' for input: '<CCC1C=OC(1)C1C'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: FCC1CCC2C)1N1=2
# [03:38:10] SMILES Parse Error: check for mistakes around position 10:
# [03:38:10] FCC1CCC2C)1N1=2
# [03:38:10] ~~~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'FCC1CCC2C)1N1=2' for input: 'FCC1CCC2C)1N1=2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1==c))1COO3N2FCO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1==c))1COO3N2FCO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1==c))1COO3N2FCO' for input: '<CC1==c))1COO3N2FCO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C#11C2CC)1CC[C)1C=[
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C#11C2CC)1CC[C)1C=[
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C#11C2CC)1CC[C)1C=[' for input: '<C#11C2CC)1CC[C)1C=['
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC(C=2CCCCC#)OC2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC(C=2CCCCC#)OC2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC(C=2CCCCC#)OC2' for input: '<CC(C=2CCCCC#)OC2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCC(CCN()(OCOO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCC(CCN()(OCOO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCC(CCN()(OCOO' for input: '<CCC(CCN()(OCOO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: nF-]NCCCOOO(#CCNOC32
# [03:38:10] SMILES Parse Error: check for mistakes around position 4:
# [03:38:10] nF-]NCCCOOO(#CCNOC32
# [03:38:10] ~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'nF-]NCCCOOO(#CCNOC32' for input: 'nF-]NCCCOOO(#CCNOC32'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1C#2=C(C=C(==)O)
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1C#2=C(C=C(==)O)
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1C#2=C(C=C(==)O)' for input: '<CC1C#2=C(C=C(==)O)'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC#(NCC1C=1C)2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC#(NCC1C=1C)2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC#(NCC1C=1C)2' for input: '<CC#(NCC1C=1C)2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <2#NCC=C1-)CO)22132)=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <2#NCC=C1-)CO)22132)=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<2#NCC=C1-)CO)22132)=' for input: '<2#NCC=C1-)CO)22132)='
# [03:38:10] SMILES Parse Error: syntax error while parsing: +212C)1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] +212C)1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+212C)1' for input: '+212C)1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 4n#OC#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 4n#OC#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '4n#OC#' for input: '4n#OC#'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ]+ONCCC1CC13
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ]+ONCCC1CC13
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ']+ONCCC1CC13' for input: ']+ONCCC1CC13'
# [03:38:10] SMILES Parse Error: syntax error while parsing: HNoN+N#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] HNoN+N#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'HNoN+N#' for input: 'HNoN+N#'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ]
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ]
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ']' for input: ']'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1co11OC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1co11OC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1co11OC' for input: '1co11OC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ]NC11C1OC2OO31
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ]NC11C1OC2OO31
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ']NC11C1OC2OO31' for input: ']NC11C1OC2OO31'
# [03:38:10] SMILES Parse Error: extra open parentheses while parsing: CCCCCC1C(N21O
# [03:38:10] SMILES Parse Error: check for mistakes around position 9:
# [03:38:10] CCCCCC1C(N21O
# [03:38:10] ~~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'CCCCCC1C(N21O' for input: 'CCCCCC1C(N21O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 5
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 5
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '5' for input: '5'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCC1CCC=C=211C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCC1CCC=C=211C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCC1CCC=C=211C' for input: '<CCC1CCC=C=211C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC(C=CCC)CC1CN
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC(C=CCC)CC1CN
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC(C=CCC)CC1CN' for input: '<CC(C=CCC)CC1CN'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C=1CCCCCC#C(C#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C=1CCCCCC#C(C#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C=1CCCCCC#C(C#' for input: '<C=1CCCCCC#C(C#'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <NCNCC2(C=12CCCC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <NCNCC2(C=12CCCC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<NCNCC2(C=12CCCC' for input: '<NCNCC2(C=12CCCC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCCC)C2C#12
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCCC)C2C#12
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCCC)C2C#12' for input: '<CC1CCCC)C2C#12'
# [03:38:10] SMILES Parse Error: syntax error while parsing: [+=C(N=13
# [03:38:10] SMILES Parse Error: check for mistakes around position 2:
# [03:38:10] [+=C(N=13
# [03:38:10] ~^
# ...
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C=CCCCCC1CNCO21#' for input: '<C=CCCCCC1CNCO21#'
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'N1Fo]5<c<<<<<[<<<#<<<<<<+<c<5<<<<<<<<<<<<<<<<#]O<<2<<<<<]<o<<4-<<<<<<<F2+5-<C<<<<<<<<++(-<<(<<<-<<<2' for input: 'N1Fo]5<c<<<<<[<<<#<<<<<<+<c<5<<<<<<<<<<<<<<<<#]O<<2<<<<<]<o<<4-<<<<<<<F2+5-<C<<<<<<<<++(-<<(<<<-<<<2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 2N41=NO
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 2N41=NO
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '2N41=NO' for input: '2N41=NO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C(1CCOC)2CC)N1O12
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C(1CCOC)2CC)N1O12
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C(1CCOC)2CC)N1O12' for input: '<C(1CCOC)2CC)N1O12'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <C#CCCN4C3CC=C2C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <C#CCCN4C3CC=C2C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<C#CCCN4C3CC=C2C' for input: '<C#CCCN4C3CC=C2C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OO1NCC3C)CNCC1O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OO1NCC3C)CNCC1O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OO1NCC3C)CNCC1O' for input: '<OO1NCC3C)CNCC1O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <O#1#OCC)OCCCN=O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <O#1#OCC)OCCCN=O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<O#1#OCC)OCCCN=O' for input: '<O#1#OCC)OCCCN=O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCO1CC1CCC==
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCO1CC1CCC==
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCO1CC1CCC==' for input: '<CCCCO1CC1CCC=='
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCC1(OCCOCC2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCC1(OCCOCC2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCC1(OCCOCC2' for input: '<CCCCC1(OCCOCC2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: #[N+cH5542Fo]co-
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] #[N+cH5542Fo]co-
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '#[N+cH5542Fo]co-' for input: '#[N+cH5542Fo]co-'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CO1CCCNCCOCCC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CO1CCCNCCOCCC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CO1CCCNCCOCCC' for input: '<CO1CCCNCCOCCC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: N(CHC1CNO
# [03:38:10] SMILES Parse Error: check for mistakes around position 4:
# [03:38:10] N(CHC1CNO
# [03:38:10] ~~~^
# [03:38:10] SMILES Parse Error: extra open parentheses while parsing: N(CHC1CNO
# [03:38:10] SMILES Parse Error: check for mistakes around position 2:
# [03:38:10] N(CHC1CNO
# [03:38:10] ~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'N(CHC1CNO' for input: 'N(CHC1CNO'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 3O1CC=COCCCNC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 3O1CC=COCCCNC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '3O1CC=COCCCNC' for input: '3O1CC=COCCCNC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OC1CC1CC1=CC#123
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OC1CC1CC1=CC#123
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OC1CC1CC1=CC#123' for input: '<OC1CC1CC1=CC#123'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: FNN=NCCCC)C(=N
# [03:38:10] SMILES Parse Error: check for mistakes around position 10:
# [03:38:10] FNN=NCCCC)C(=N
# [03:38:10] ~~~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'FNN=NCCCC)C(=N' for input: 'FNN=NCCCC)C(=N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: HOCO1N3C)C)CN
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] HOCO1N3C)C)CN
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'HOCO1N3C)C)CN' for input: 'HOCO1N3C)C)CN'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCCC1C111
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCCC1C111
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCCC1C111' for input: '<CCCCCCC1C111'
# [03:38:10] SMILES Parse Error: syntax error while parsing: ]C=c=21CC112=NC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] ]C=c=21CC112=NC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ']C=c=21CC112=NC' for input: ']C=c=21CC112=NC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: (H
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] (H
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '(H' for input: '(H'
# [03:38:10] SMILES Parse Error: syntax error while parsing: H+)CC2NC1CC)
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] H+)CC2NC1CC)
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'H+)CC2NC1CC)' for input: 'H+)CC2NC1CC)'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCOCC(=#C=C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCOCC(=#C=C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCOCC(=#C=C' for input: '<CCCCOCC(=#C=C'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCCOOCC)COCO12
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCCOOCC)COCO12
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCCOOCC)COCO12' for input: '<CCCCCCOOCC)COCO12'
# [03:38:10] SMILES Parse Error: syntax error while parsing: HNNCCC=CC#OCCN)O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] HNNCCC=CC#OCCN)O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'HNNCCC=CC#OCCN)O' for input: 'HNNCCC=CC#OCCN)O'
# [03:38:10] SMILES Parse Error: unclosed ring for input: 'nNC(CCCC(#C)O)1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: -[O
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] -[O
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '-[O' for input: '-[O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: [4F4OC=OCO#1O
# [03:38:10] SMILES Parse Error: check for mistakes around position 4:
# [03:38:10] [4F4OC=OCO#1O
# [03:38:10] ~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '[4F4OC=OCO#1O' for input: '[4F4OC=OCO#1O'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 1()
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 1()
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '1()' for input: '1()'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCCCCC2C11111
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCCCCC2C11111
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCCCCC2C11111' for input: '<CC1CCCCCC2C11111'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1=1O(CNCCC1CN
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1=1O(CNCCC1CN
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1=1O(CNCCC1CN' for input: '<CC1=1O(CNCCC1CN'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC(C12(C=C]1C=)2=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC(C12(C=C]1C=)2=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC(C12(C=C]1C=)2=' for input: '<CC(C12(C=C]1C=)2='
# [03:38:10] SMILES Parse Error: syntax error while parsing: +1NCCN
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] +1NCCN
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+1NCCN' for input: '+1NCCN'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <OO1CNCN)CO)#1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <OO1CNCN)CO)#1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<OO1CNCN)CO)#1' for input: '<OO1CNCN)CO)#1'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: n)C(CC=2=))1)O2
# [03:38:10] SMILES Parse Error: check for mistakes around position 2:
# [03:38:10] n)C(CC=2=))1)O2
# [03:38:10] ~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'n)C(CC=2=))1)O2' for input: 'n)C(CC=2=))1)O2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCC(CCCOC#C==1C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCC(CCCOC#C==1C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCC(CCCOC#C==1C' for input: '<CCCC(CCCOC#C==1C'
# [03:38:10] SMILES Parse Error: unclosed ring for input: 'N2CCNO1#CN'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <=CC(CC#1C22C#)3
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <=CC(CC#1C22C#)3
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<=CC(CC#1C22C#)3' for input: '<=CC(CC#1C22C#)3'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 3+1#1N=1#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 3+1#1N=1#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '3+1#1N=1#' for input: '3+1#1N=1#'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <+4CNO##221N
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <+4CNO##221N
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<+4CNO##221N' for input: '<+4CNO##221N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CN(C2O)1)OCCC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CN(C2O)1)OCCC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CN(C2O)1)OCCC' for input: '<CN(C2O)1)OCCC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: cn[]C]#N
# [03:38:10] SMILES Parse Error: check for mistakes around position 4:
# [03:38:10] cn[]C]#N
# [03:38:10] ~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cn[]C]#N' for input: 'cn[]C]#N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: )43OCC#]
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] )43OCC#]
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES ')43OCC#]' for input: ')43OCC#]'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <5NC1=CCC13CC1NO#
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <5NC1=CCC13CC1NO#
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<5NC1=CCC13CC1NO#' for input: '<5NC1=CCC13CC1NO#'
# [03:38:10] SMILES Parse Error: syntax error while parsing: 4O2#OC=2
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] 4O2#OC=2
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '4O2#OC=2' for input: '4O2#OC=2'
# [03:38:10] SMILES Parse Error: syntax error while parsing: =oCCCCC2=C1)C(
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] =oCCCCC2=C1)C(
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '=oCCCCC2=C1)C(' for input: '=oCCCCC2=C1)C('
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCCCCCCN)C3CN1
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCCCCCCN)C3CN1
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCCCCCCN)C3CN1' for input: '<CCCCCCCN)C3CN1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: #2<F)n#1CCCCN#1=
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] #2<F)n#1CCCCN#1=
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '#2<F)n#1CCCCN#1=' for input: '#2<F)n#1CCCCN#1='
# [03:38:10] SMILES Parse Error: syntax error while parsing: [+11=N
# [03:38:10] SMILES Parse Error: check for mistakes around position 2:
# [03:38:10] [+11=N
# [03:38:10] ~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '[+11=N' for input: '[+11=N'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC121C)CCC(C2)OC2N
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC121C)CCC(C2)OC2N
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC121C)CCC(C2)OC2N' for input: '<CC121C)CCC(C2)OC2N'
# [03:38:10] SMILES Parse Error: ring closure 1 duplicates bond between atom 2 and atom 3 for input: 'cON1C1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: #H1)OO2]1O=CCC)C)N
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] #H1)OO2]1O=CCC)C)N
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '#H1)OO2]1O=CCC)C)N' for input: '#H1)OO2]1O=CCC)C)N'
# [03:38:10] SMILES Parse Error: unclosed ring for input: 'O32n'
# [03:38:10] SMILES Parse Error: syntax error while parsing: +o1[cFO5NH[cH<4-o5]+[<+<[-5<<2o<[o<[[-<-<o5<<F<4o<5<<c]<5<<4<<<5c[c5+<F<+c+co<<[4[o<<]-[<<<<5c+[<ccn
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] +o1[cFO5NH[cH<4-o5]+[<+<[-5<<2o<[o<[[-<-<
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '+o1[cFO5NH[cH<4-o5]+[<+<[-5<<2o<[o<[[-<-<o5<<F<4o<5<<c]<5<<4<<<5c[c5+<F<+c+co<<[4[o<<]-[<<<<5c+[<ccn' for input: '+o1[cFO5NH[cH<4-o5]+[<+<[-5<<2o<[o<[[-<-<o5<<F<4o<5<<c]<5<<4<<<5c[c5+<F<+c+co<<[4[o<<]-[<<<<5c+[<ccn'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CNC(CCC=((ONOC
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CNC(CCC=((ONOC
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CNC(CCC=((ONOC' for input: '<CNC(CCC=((ONOC'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC11C(NCC1+C11
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC11C(NCC1+C11
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC11C(NCC1+C11' for input: '<CC11C(NCC1+C11'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CCC2CCCCOCC2CCHN
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CCC2CCCCOCC2CCHN
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CCC2CCCCOCC2CCHN' for input: '<CCC2CCCCOCC2CCHN'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: C4CCCCCC)CCCCN
# [03:38:10] SMILES Parse Error: check for mistakes around position 9:
# [03:38:10] C4CCCCCC)CCCCN
# [03:38:10] ~~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'C4CCCCCC)CCCCN' for input: 'C4CCCCCC)CCCCN'
# [03:38:10] SMILES Parse Error: extra close parentheses while parsing: cc-F5C11ON)C1
# [03:38:10] SMILES Parse Error: check for mistakes around position 11:
# [03:38:10] cc-F5C11ON)C1
# [03:38:10] ~~~~~~~~~~^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES 'cc-F5C11ON)C1' for input: 'cc-F5C11ON)C1'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1C=C(C=#CCC)C3
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1C=C(C=#CCC)C3
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1C=C(C=#CCC)C3' for input: '<CC1C=C(C=#CCC)C3'
# [03:38:10] SMILES Parse Error: syntax error while parsing: <CC1CCC#OCNN1O1C
# [03:38:10] SMILES Parse Error: check for mistakes around position 1:
# [03:38:10] <CC1CCC#OCNN1O1C
# [03:38:10] ^
# [03:38:10] SMILES Parse Error: Failed parsing SMILES '<CC1CCC#OCNN1O1C' for input: '<CC1CCC#OCNN1O1C'

# %% [markdown]
# 7.4 Visualizing Generated Molecules: We can visualize some of the valid generated molecules:

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from typing import List, Optional, Tuple
import logging
from PIL import Image
import io
from IPython.display import display

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def visualize_molecules(smiles_list: List[str], n: int = 5, filename: str = "generated_molecules.png") -> Optional[Tuple[str, Image.Image]]:
    """
    Visualize a list of generated molecules from their SMILES strings, save and return the image.

    This function takes the list of generated SMILES strings, converts them to RDKit molecule objects,
    generates a grid image of the molecules, and both saves and returns the image.

    Args:
        smiles_list (List[str]): The list of generated SMILES strings to visualize.
        n (int, optional): Maximum number of molecules to visualize. Defaults to 5.
        filename (str, optional): Name of the file to save the image. Defaults to "generated_molecules.png".

    Returns:
        Optional[Tuple[str, Image.Image]]: A tuple containing the filename of the saved image and the Image object if successful, None otherwise.

    Raises:
        ValueError: If no valid molecules are found in the input list.
    """
    valid_mols = []
    invalid_count = 0
    for i, smiles in enumerate(smiles_list):
        # Remove any start/end tokens and whitespace
        smiles = smiles.strip().strip('<>').strip()
        if not smiles:  # Skip empty strings
            invalid_count += 1
            continue
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is not None:
                valid_mols.append(mol)
                if len(valid_mols) == n:
                    break
            else:
                logger.warning(f"Invalid SMILES at index {i}: {smiles}")
                invalid_count += 1
        except Exception as e:
            logger.error(f"Error processing SMILES at index {i}: {smiles}. Error: {str(e)}")
            invalid_count += 1

    if not valid_mols:
        logger.error("No valid molecules found in the generated SMILES list.")
        return None

    print(f"{invalid_count} molecules not drawn due to invalidity. Drawing {len(valid_mols)} molecules...")

    try:
        img = Draw.MolsToGridImage(
            valid_mols,
            molsPerRow=min(3, len(valid_mols)),
            subImgSize=(200, 200),
            legends=[f"Mol {i+1}" for i in range(len(valid_mols))]
        )
        # Convert the RDKit image to a PIL Image
        img_pil = Image.open(io.BytesIO(img.data))
        img_pil.save(filename)
        logger.info(f"Generated molecule images saved as '{filename}'")
        return filename, img_pil
    except Exception as e:
        logger.error(f"Error saving generated molecule image: {str(e)}")
        return None

# The function call and display code
result = visualize_molecules(novel_molecules)

if result:
    filename, img = result
    print(f"Visualization of generated molecules successful. Image saved as: {filename}")
    display(img)
else:
    print("Visualization of generated molecules failed.")
# Out:
# [03:39:03] SMILES Parse Error: syntax error while parsing: ]
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] ]
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES ']' for input: ']'
# WARNING:__main__:Invalid SMILES at index 0: ]
# [03:39:03] SMILES Parse Error: syntax error while parsing: H##4n=2]111
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] H##4n=2]111
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'H##4n=2]111' for input: 'H##4n=2]111'
# WARNING:__main__:Invalid SMILES at index 1: H##4n=2]111
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'NNCCCCCCC2C'
# WARNING:__main__:Invalid SMILES at index 2: NNCCCCCCC2C
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC#CCC1CNO2O1=
# [03:39:03] SMILES Parse Error: check for mistakes around position 14:
# [03:39:03] CC#CCC1CNO2O1=
# [03:39:03] ~~~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC#CCC1CNO2O1=' for input: 'CC#CCC1CNO2O1='
# WARNING:__main__:Invalid SMILES at index 3: CC#CCC1CNO2O1=
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: c)H(]
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] c)H(]
# [03:39:03] ~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'c)H(]' for input: 'c)H(]'
# WARNING:__main__:Invalid SMILES at index 4: c)H(]
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC==(N#==C1#
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] CC==(N#==C1#
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC==(N#==C1#' for input: 'CC==(N#==C1#'
# WARNING:__main__:Invalid SMILES at index 5: CC==(N#==C1#
# [03:39:03] SMILES Parse Error: duplicated ring closure 1 bonds atom 1 to itself for input: 'CC11CC21O'
# WARNING:__main__:Invalid SMILES at index 6: CC11CC21O
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CCC2CCCC(CCCC3NC
# [03:39:03] SMILES Parse Error: check for mistakes around position 9:
# [03:39:03] CCC2CCCC(CCCC3NC
# [03:39:03] ~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCC2CCCC(CCCC3NC' for input: 'CCC2CCCC(CCCC3NC'
# WARNING:__main__:Invalid SMILES at index 7: CCC2CCCC(CCCC3NC
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CC(CC1CCC1)2CC1C'
# WARNING:__main__:Invalid SMILES at index 8: CC(CC1CCC1)2CC1C
# [03:39:03] SMILES Parse Error: syntax error while parsing: [-
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] [-
# [03:39:03] ~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '[-' for input: '[-'
# WARNING:__main__:Invalid SMILES at index 9: [-
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CC(CCCNCCCCCO1
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] CC(CCCNCCCCCO1
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC(CCCNCCCCCO1' for input: 'CC(CCCNCCCCCO1'
# WARNING:__main__:Invalid SMILES at index 10: CC(CCCNCCCCCO1
# [03:39:03] SMILES Parse Error: syntax error while parsing: )
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] )
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES ')' for input: ')'
# WARNING:__main__:Invalid SMILES at index 11: )
# [03:39:03] SMILES Parse Error: syntax error while parsing: CCOCCC21C12=1121#
# [03:39:03] SMILES Parse Error: check for mistakes around position 17:
# [03:39:03] CCOCCC21C12=1121#
# [03:39:03] ~~~~~~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCOCCC21C12=1121#' for input: 'CCOCCC21C12=1121#'
# WARNING:__main__:Invalid SMILES at index 12: CCOCCC21C12=1121#
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CCC1(CCN=CCCCCN3
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CCC1(CCN=CCCCCN3
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCC1(CCN=CCCCCN3' for input: 'CCC1(CCN=CCCCCN3'
# WARNING:__main__:Invalid SMILES at index 13: CCC1(CCN=CCCCCN3
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'cO5NC'
# WARNING:__main__:Invalid SMILES at index 14: cO5NC
# [03:39:03] SMILES Parse Error: syntax error while parsing: ]4CO=#N1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] ]4CO=#N1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES ']4CO=#N1' for input: ']4CO=#N1'
# WARNING:__main__:Invalid SMILES at index 15: ]4CO=#N1
# [03:39:03] SMILES Parse Error: duplicated ring closure 1 bonds atom 2 to itself for input: 'nCC11NN12'
# WARNING:__main__:Invalid SMILES at index 16: nCC11NN12
# [03:39:03] SMILES Parse Error: syntax error while parsing: 2+C1CC=1C)C)#1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 2+C1CC=1C)C)#1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '2+C1CC=1C)C)#1' for input: '2+C1CC=1C)C)#1'
# WARNING:__main__:Invalid SMILES at index 17: 2+C1CC=1C)C)#1
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CC1CCCC)(==1)#
# [03:39:03] SMILES Parse Error: check for mistakes around position 8:
# [03:39:03] CC1CCCC)(==1)#
# [03:39:03] ~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC1CCCC)(==1)#' for input: 'CC1CCCC)(==1)#'
# WARNING:__main__:Invalid SMILES at index 18: CC1CCCC)(==1)#
# [03:39:03] SMILES Parse Error: syntax error while parsing: =<N1N==N#CO-NN]OO1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] =<N1N==N#CO-NN]OO1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '=<N1N==N#CO-NN]OO1' for input: '=<N1N==N#CO-NN]OO1'
# WARNING:__main__:Invalid SMILES at index 19: =<N1N==N#CO-NN]OO1
# [03:39:03] SMILES Parse Error: syntax error while parsing: []o]-H555c-n]c4-cnc(H[n3HconF[45(5]c+5n4]5-o+)5-H[cnno-]Hnn]4cFo[Hcc4-+-cn4c5][]5[=5oc4n55cHonc[[Fc
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] []o]-H555c-n]c4-cnc(H[n3HconF[45(5]c+5n4]
# [03:39:03] ~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '[]o]-H555c-n]c4-cnc(H[n3HconF[45(5]c+5n4]5-o+)5-H[cnno-]Hnn]4cFo[Hcc4-+-cn4c5][]5[=5oc4n55cHonc[[Fc' for input: '[]o]-H555c-n]c4-cnc(H[n3HconF[45(5]c+5n4]5-o+)5-H[cnno-]Hnn]4cFo[Hcc4-+-cn4c5][]5[=5oc4n55cHonc[[Fc'
# WARNING:__main__:Invalid SMILES at index 20: []o]-H555c-n]c4-cnc(H[n3HconF[45(5]c+5n4]5-o+)5-H[cnno-]Hnn]4cFo[Hcc4-+-cn4c5][]5[=5oc4n55cHonc[[Fc
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: cOO1)
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] cOO1)
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'cOO1)' for input: 'cOO1)'
# WARNING:__main__:Invalid SMILES at index 21: cOO1)
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CCCCCCCCCOC12'
# WARNING:__main__:Invalid SMILES at index 22: CCCCCCCCCOC12
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CC1C2CCNCC)1
# [03:39:03] SMILES Parse Error: check for mistakes around position 11:
# [03:39:03] CC1C2CCNCC)1
# [03:39:03] ~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC1C2CCNCC)1' for input: 'CC1C2CCNCC)1'
# WARNING:__main__:Invalid SMILES at index 23: CC1C2CCNCC)1
# [03:39:03] SMILES Parse Error: syntax error while parsing: (+#C3
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] (+#C3
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '(+#C3' for input: '(+#C3'
# WARNING:__main__:Invalid SMILES at index 24: (+#C3
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC11COC()CCO)C
# [03:39:03] SMILES Parse Error: check for mistakes around position 9:
# [03:39:03] CC11COC()CCO)C
# [03:39:03] ~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC11COC()CCO)C' for input: 'CC11COC()CCO)C'
# WARNING:__main__:Invalid SMILES at index 25: CC11COC()CCO)C
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'NCC1O3=C1'
# WARNING:__main__:Invalid SMILES at index 26: NCC1O3=C1
# [03:39:03] SMILES Parse Error: duplicated ring closure 1 bonds atom 2 to itself for input: 'CCC11ONCCCC2C'
# WARNING:__main__:Invalid SMILES at index 27: CCC11ONCCCC2C
# [03:39:03] SMILES Parse Error: syntax error while parsing: C#=11112
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] C#=11112
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'C#=11112' for input: 'C#=11112'
# WARNING:__main__:Invalid SMILES at index 28: C#=11112
# [03:39:03] SMILES Parse Error: syntax error while parsing: 1-CC#CCC=CCN=C1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 1-CC#CCC=CCN=C1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '1-CC#CCC=CCN=C1' for input: '1-CC#CCC=CCN=C1'
# WARNING:__main__:Invalid SMILES at index 29: 1-CC#CCC=CCN=C1
# [03:39:03] SMILES Parse Error: syntax error while parsing: #OCCCO2=C
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] #OCCCO2=C
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '#OCCCO2=C' for input: '#OCCCO2=C'
# WARNING:__main__:Invalid SMILES at index 30: #OCCCO2=C
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'OCCC1CNCCO#OO34'
# WARNING:__main__:Invalid SMILES at index 31: OCCC1CNCCO#OO34
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CCCCCCC11)2(CC2)3
# [03:39:03] SMILES Parse Error: check for mistakes around position 10:
# [03:39:03] CCCCCCC11)2(CC2)3
# [03:39:03] ~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCCCCCC11)2(CC2)3' for input: 'CCCCCCC11)2(CC2)3'
# WARNING:__main__:Invalid SMILES at index 32: CCCCCCC11)2(CC2)3
# [03:39:03] SMILES Parse Error: syntax error while parsing: 2[-COON2
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 2[-COON2
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '2[-COON2' for input: '2[-COON2'
# WARNING:__main__:Invalid SMILES at index 33: 2[-COON2
# [03:39:03] SMILES Parse Error: syntax error while parsing: CCC121CC#=CCC)C
# [03:39:03] SMILES Parse Error: check for mistakes around position 10:
# [03:39:03] CCC121CC#=CCC)C
# [03:39:03] ~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCC121CC#=CCC)C' for input: 'CCC121CC#=CCC)C'
# WARNING:__main__:Invalid SMILES at index 34: CCC121CC#=CCC)C
# [03:39:03] SMILES Parse Error: syntax error while parsing: -O3CF2=-#O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] -O3CF2=-#O
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '-O3CF2=-#O' for input: '-O3CF2=-#O'
# WARNING:__main__:Invalid SMILES at index 35: -O3CF2=-#O
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC(C=C(CCCCCC#
# [03:39:03] SMILES Parse Error: check for mistakes around position 14:
# [03:39:03] CC(C=C(CCCCCC#
# [03:39:03] ~~~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CC(C=C(CCCCCC#
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] CC(C=C(CCCCCC#
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CC(C=C(CCCCCC#
# [03:39:03] SMILES Parse Error: check for mistakes around position 7:
# [03:39:03] CC(C=C(CCCCCC#
# [03:39:03] ~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC(C=C(CCCCCC#' for input: 'CC(C=C(CCCCCC#'
# WARNING:__main__:Invalid SMILES at index 37: CC(C=C(CCCCCC#
# [03:39:03] SMILES Parse Error: syntax error while parsing: C#1(2C4))=()=
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] C#1(2C4))=()=
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'C#1(2C4))=()=' for input: 'C#1(2C4))=()='
# WARNING:__main__:Invalid SMILES at index 38: C#1(2C4))=()=
# [03:39:03] SMILES Parse Error: syntax error while parsing: 1CN1#CC)=12
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 1CN1#CC)=12
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '1CN1#CC)=12' for input: '1CN1#CC)=12'
# WARNING:__main__:Invalid SMILES at index 39: 1CN1#CC)=12
# [03:39:03] SMILES Parse Error: syntax error while parsing: [CCCCCCCCCNCC1
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] [CCCCCCCCCNCC1
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '[CCCCCCCCCNCC1' for input: '[CCCCCCCCCNCC1'
# WARNING:__main__:Invalid SMILES at index 40: [CCCCCCCCCNCC1
# [03:39:03] SMILES Parse Error: syntax error while parsing: C1C(21=(12no=)1)CO
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] C1C(21=(12no=)1)CO
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'C1C(21=(12no=)1)CO' for input: 'C1C(21=(12no=)1)CO'
# WARNING:__main__:Invalid SMILES at index 41: C1C(21=(12no=)1)CO
# [03:39:03] SMILES Parse Error: syntax error while parsing: HnN]O#
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] HnN]O#
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'HnN]O#' for input: 'HnN]O#'
# WARNING:__main__:Invalid SMILES at index 42: HnN]O#
# [03:39:03] SMILES Parse Error: syntax error while parsing: 2
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 2
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '2' for input: '2'
# WARNING:__main__:Invalid SMILES at index 43: 2
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: cNC)=2CCOC
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] cNC)=2CCOC
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'cNC)=2CCOC' for input: 'cNC)=2CCOC'
# WARNING:__main__:Invalid SMILES at index 44: cNC)=2CCOC
# [03:39:03] SMILES Parse Error: syntax error while parsing: NH](
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] NH](
# [03:39:03] ~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'NH](' for input: 'NH]('
# WARNING:__main__:Invalid SMILES at index 45: NH](
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: cCC=CC1C1)#OCOCO
# [03:39:03] SMILES Parse Error: check for mistakes around position 10:
# [03:39:03] cCC=CC1C1)#OCOCO
# [03:39:03] ~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'cCC=CC1C1)#OCOCO' for input: 'cCC=CC1C1)#OCOCO'
# WARNING:__main__:Invalid SMILES at index 46: cCC=CC1C1)#OCOCO
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC(1C(C)((CC)O
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] CC(1C(C)((CC)O
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC(1C(C)((CC)O' for input: 'CC(1C(C)((CC)O'
# WARNING:__main__:Invalid SMILES at index 47: CC(1C(C)((CC)O
# [03:39:03] SMILES Parse Error: syntax error while parsing: =4o+###O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] =4o+###O
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '=4o+###O' for input: '=4o+###O'
# WARNING:__main__:Invalid SMILES at index 48: =4o+###O
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CC11On)1221)N=1N
# [03:39:03] SMILES Parse Error: check for mistakes around position 7:
# [03:39:03] CC11On)1221)N=1N
# [03:39:03] ~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC11On)1221)N=1N' for input: 'CC11On)1221)N=1N'
# WARNING:__main__:Invalid SMILES at index 49: CC11On)1221)N=1N
# [03:39:03] SMILES Parse Error: duplicated ring closure 1 bonds atom 9 to itself for input: 'CC2CCC22CCCC=C1#1CN'
# WARNING:__main__:Invalid SMILES at index 50: CC2CCC22CCCC=C1#1CN
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC21CC4C1C1]1' for input: 'CC21CC4C1C1]1'
# WARNING:__main__:Invalid SMILES at index 51: CC21CC4C1C1]1
# [03:39:03] SMILES Parse Error: duplicated ring closure 1 bonds atom 1 to itself for input: 'CN11C1O=NC2'
# WARNING:__main__:Invalid SMILES at index 52: CN11C1O=NC2
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: O=12CCONC))C2=N
# [03:39:03] SMILES Parse Error: check for mistakes around position 10:
# [03:39:03] O=12CCONC))C2=N
# [03:39:03] ~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'O=12CCONC))C2=N' for input: 'O=12CCONC))C2=N'
# WARNING:__main__:Invalid SMILES at index 53: O=12CCONC))C2=N
# [03:39:03] SMILES Parse Error: syntax error while parsing: CCC(()O1C)N1
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CCC(()O1C)N1
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCC(()O1C)N1' for input: 'CCC(()O1C)N1'
# WARNING:__main__:Invalid SMILES at index 54: CCC(()O1C)N1
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CC1O1=2C1111C1)
# [03:39:03] SMILES Parse Error: check for mistakes around position 15:
# [03:39:03] CC1O1=2C1111C1)
# [03:39:03] ~~~~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC1O1=2C1111C1)' for input: 'CC1O1=2C1111C1)'
# WARNING:__main__:Invalid SMILES at index 55: CC1O1=2C1111C1)
# [03:39:03] SMILES Parse Error: syntax error while parsing: O3((NO#CC#
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] O3((NO#CC#
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'O3((NO#CC#' for input: 'O3((NO#CC#'
# WARNING:__main__:Invalid SMILES at index 56: O3((NO#CC#
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC1CC(#CC(1NCCC
# [03:39:03] SMILES Parse Error: check for mistakes around position 11:
# [03:39:03] CC1CC(#CC(1NCCC
# [03:39:03] ~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CC1CC(#CC(1NCCC
# [03:39:03] SMILES Parse Error: check for mistakes around position 6:
# [03:39:03] CC1CC(#CC(1NCCC
# [03:39:03] ~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC1CC(#CC(1NCCC' for input: 'CC1CC(#CC(1NCCC'
# WARNING:__main__:Invalid SMILES at index 57: CC1CC(#CC(1NCCC
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CCCCCNCC(OC1CC3C
# [03:39:03] SMILES Parse Error: check for mistakes around position 9:
# [03:39:03] CCCCCNCC(OC1CC3C
# [03:39:03] ~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCCCCNCC(OC1CC3C' for input: 'CCCCCNCC(OC1CC3C'
# WARNING:__main__:Invalid SMILES at index 58: CCCCCNCC(OC1CC3C
# [03:39:03] SMILES Parse Error: syntax error while parsing: 5CC3O(C
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 5CC3O(C
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '5CC3O(C' for input: '5CC3O(C'
# WARNING:__main__:Invalid SMILES at index 60: 5CC3O(C
# [03:39:03] SMILES Parse Error: syntax error while parsing: 1#F]+(ocon5=<)(5cc-[[[5oc+---5n[<<o[n]ccoH42<<5)55o[]<O2[<45<<-]o5H[[<45F-oH<5<<n<-n5]o<F[c4<5H5<<]5
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 1#F]+(ocon5=<)(5cc-[[[5oc+---5n[<<o[n]cco
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '1#F]+(ocon5=<)(5cc-[[[5oc+---5n[<<o[n]ccoH42<<5)55o[]<O2[<45<<-]o5H[[<45F-oH<5<<n<-n5]o<F[c4<5H5<<]5' for input: '1#F]+(ocon5=<)(5cc-[[[5oc+---5n[<<o[n]ccoH42<<5)55o[]<O2[<45<<-]o5H[[<45F-oH<5<<n<-n5]o<F[c4<5H5<<]5'
# WARNING:__main__:Invalid SMILES at index 61: 1#F]+(ocon5=<)(5cc-[[[5oc+---5n[<<o[n]ccoH42<<5)55o[]<O2[<45<<-]o5H[[<45F-oH<5<<n<-n5]o<F[c4<5H5<<]5
# [03:39:03] SMILES Parse Error: syntax error while parsing: 3HC1C2)CC)CO1)1#1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 3HC1C2)CC)CO1)1#1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '3HC1C2)CC)CO1)1#1' for input: '3HC1C2)CC)CO1)1#1'
# WARNING:__main__:Invalid SMILES at index 62: 3HC1C2)CC)CO1)1#1
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CC1C)2CCCCCC(
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CC1C)2CCCCCC(
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC1C)2CCCCCC(' for input: 'CC1C)2CCCCCC('
# WARNING:__main__:Invalid SMILES at index 63: CC1C)2CCCCCC(
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CCC=CCC)C1CCO22
# [03:39:03] SMILES Parse Error: check for mistakes around position 8:
# [03:39:03] CCC=CCC)C1CCO22
# [03:39:03] ~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCC=CCC)C1CCO22' for input: 'CCC=CCC)C1CCO22'
# WARNING:__main__:Invalid SMILES at index 64: CCC=CCC)C1CCO22
# [03:39:03] SMILES Parse Error: syntax error while parsing: #C4)=o21
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] #C4)=o21
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '#C4)=o21' for input: '#C4)=o21'
# WARNING:__main__:Invalid SMILES at index 65: #C4)=o21
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CC1CCC1(CCC2C)'
# WARNING:__main__:Invalid SMILES at index 66: CC1CCC1(CCC2C)
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC(1)CC=C=1)O)C=O
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] CC(1)CC=C=1)O)C=O
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC(1)CC=C=1)O)C=O' for input: 'CC(1)CC=C=1)O)C=O'
# WARNING:__main__:Invalid SMILES at index 67: CC(1)CC=C=1)O)C=O
# [03:39:03] SMILES Parse Error: syntax error while parsing: CCC=(CC(CC=CNC3
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CCC=(CC(CC=CNC3
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCC=(CC(CC=CNC3' for input: 'CCC=(CC(CC=CNC3'
# WARNING:__main__:Invalid SMILES at index 68: CCC=(CC(CC=CNC3
# [03:39:03] SMILES Parse Error: syntax error while parsing: =CC(O22CCN#C#C11
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] =CC(O22CCN#C#C11
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '=CC(O22CCN#C#C11' for input: '=CC(O22CCN#C#C11'
# WARNING:__main__:Invalid SMILES at index 69: =CC(O22CCN#C#C11
# [03:39:03] SMILES Parse Error: syntax error while parsing: -OC=1CCN1#
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] -OC=1CCN1#
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '-OC=1CCN1#' for input: '-OC=1CCN1#'
# WARNING:__main__:Invalid SMILES at index 70: -OC=1CCN1#
# [03:39:03] SMILES Parse Error: syntax error while parsing: --[
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] --[
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '--[' for input: '--['
# WARNING:__main__:Invalid SMILES at index 71: --[
# [03:39:03] SMILES Parse Error: syntax error while parsing: 113o#1#
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 113o#1#
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '113o#1#' for input: '113o#1#'
# WARNING:__main__:Invalid SMILES at index 72: 113o#1#
# [03:39:03] SMILES Parse Error: syntax error while parsing: =N111C#)12
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] =N111C#)12
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '=N111C#)12' for input: '=N111C#)12'
# WARNING:__main__:Invalid SMILES at index 73: =N111C#)12
# [03:39:03] SMILES Parse Error: syntax error while parsing: 2(-3]cn#++#-<3<O+<#=<]3#[NN1#12O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 2(-3]cn#++#-<3<O+<#=<]3#[NN1#12O
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '2(-3]cn#++#-<3<O+<#=<]3#[NN1#12O' for input: '2(-3]cn#++#-<3<O+<#=<]3#[NN1#12O'
# WARNING:__main__:Invalid SMILES at index 74: 2(-3]cn#++#-<3<O+<#=<]3#[NN1#12O
# [03:39:03] SMILES Parse Error: syntax error while parsing: -25)CC(+o4CC25o(-c(<(<--(Fo]NN5=15+5<-H]H<<4<<5<<H<<(5-<n5<5<(3<+c<5<<(<+o-5)+<<+(<<F5<<<<<<<o[<F(O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] -25)CC(+o4CC25o(-c(<(<--(Fo]NN5=15+5<-H]H
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '-25)CC(+o4CC25o(-c(<(<--(Fo]NN5=15+5<-H]H<<4<<5<<H<<(5-<n5<5<(3<+c<5<<(<+o-5)+<<+(<<F5<<<<<<<o[<F(O' for input: '-25)CC(+o4CC25o(-c(<(<--(Fo]NN5=15+5<-H]H<<4<<5<<H<<(5-<n5<5<(3<+c<5<<(<+o-5)+<<+(<<F5<<<<<<<o[<F(O'
# WARNING:__main__:Invalid SMILES at index 75: -25)CC(+o4CC25o(-c(<(<--(Fo]NN5=15+5<-H]H<<4<<5<<H<<(5-<n5<5<(3<+c<5<<(<+o-5)+<<+(<<F5<<<<<<<o[<F(O
# [03:39:03] SMILES Parse Error: syntax error while parsing: 5CC11O(22
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 5CC11O(22
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '5CC11O(22' for input: '5CC11O(22'
# WARNING:__main__:Invalid SMILES at index 76: 5CC11O(22
# [03:39:03] SMILES Parse Error: syntax error while parsing: 1<F=#O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 1<F=#O
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '1<F=#O' for input: '1<F=#O'
# WARNING:__main__:Invalid SMILES at index 77: 1<F=#O
# [03:39:03] SMILES Parse Error: syntax error while parsing: oO+NC#=1O11
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] oO+NC#=1O11
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'oO+NC#=1O11' for input: 'oO+NC#=1O11'
# WARNING:__main__:Invalid SMILES at index 78: oO+NC#=1O11
# [03:39:03] SMILES Parse Error: syntax error while parsing: N1(1(C
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] N1(1(C
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'N1(1(C' for input: 'N1(1(C'
# WARNING:__main__:Invalid SMILES at index 79: N1(1(C
# [03:39:03] SMILES Parse Error: syntax error while parsing: )CCC#CC1OO(N
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] )CCC#CC1OO(N
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES ')CCC#CC1OO(N' for input: ')CCC#CC1OO(N'
# WARNING:__main__:Invalid SMILES at index 80: )CCC#CC1OO(N
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CCCCCCC)1COC1C2
# [03:39:03] SMILES Parse Error: check for mistakes around position 8:
# [03:39:03] CCCCCCC)1COC1C2
# [03:39:03] ~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCCCCCC)1COC1C2' for input: 'CCCCCCC)1COC1C2'
# WARNING:__main__:Invalid SMILES at index 82: CCCCCCC)1COC1C2
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC(3CCO1CC12C)#=
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] CC(3CCO1CC12C)#=
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC(3CCO1CC12C)#=' for input: 'CC(3CCO1CC12C)#='
# WARNING:__main__:Invalid SMILES at index 83: CC(3CCO1CC12C)#=
# [03:39:03] SMILES Parse Error: syntax error while parsing: c[11N12O==1
# [03:39:03] SMILES Parse Error: check for mistakes around position 6:
# [03:39:03] c[11N12O==1
# [03:39:03] ~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'c[11N12O==1' for input: 'c[11N12O==1'
# WARNING:__main__:Invalid SMILES at index 84: c[11N12O==1
# [03:39:03] SMILES Parse Error: syntax error while parsing: -CCNOCC2C1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] -CCNOCC2C1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '-CCNOCC2C1' for input: '-CCNOCC2C1'
# WARNING:__main__:Invalid SMILES at index 85: -CCNOCC2C1
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CCO(CCN2CC1N3)2'
# WARNING:__main__:Invalid SMILES at index 86: CCO(CCN2CC1N3)2
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: OCCN1CCCO)CCC)
# [03:39:03] SMILES Parse Error: check for mistakes around position 10:
# [03:39:03] OCCN1CCCO)CCC)
# [03:39:03] ~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'OCCN1CCCO)CCC)' for input: 'OCCN1CCCO)CCC)'
# WARNING:__main__:Invalid SMILES at index 87: OCCN1CCCO)CCC)
# [03:39:03] SMILES Parse Error: duplicated ring closure 1 bonds atom 1 to itself for input: 'CC11CCOOCO'
# WARNING:__main__:Invalid SMILES at index 88: CC11CCOOCO
# [03:39:03] SMILES Parse Error: syntax error while parsing: 3FCCC12C1OOC)#1C
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 3FCCC12C1OOC)#1C
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '3FCCC12C1OOC)#1C' for input: '3FCCC12C1OOC)#1C'
# WARNING:__main__:Invalid SMILES at index 89: 3FCCC12C1OOC)#1C
# [03:39:03] SMILES Parse Error: syntax error while parsing: +2((OCC1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] +2((OCC1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '+2((OCC1' for input: '+2((OCC1'
# WARNING:__main__:Invalid SMILES at index 90: +2((OCC1
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'nN]]c[[-4cH##[NON32' for input: 'nN]]c[[-4cH##[NON32'
# WARNING:__main__:Invalid SMILES at index 91: nN]]c[[-4cH##[NON32
# [03:39:03] SMILES Parse Error: syntax error while parsing: HFn[3#OO)3O4
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] HFn[3#OO)3O4
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'HFn[3#OO)3O4' for input: 'HFn[3#OO)3O4'
# WARNING:__main__:Invalid SMILES at index 92: HFn[3#OO)3O4
# [03:39:03] SMILES Parse Error: syntax error while parsing: =C)CCC1C)(CCCC21=1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] =C)CCC1C)(CCCC21=1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '=C)CCC1C)(CCCC21=1' for input: '=C)CCC1C)(CCCC21=1'
# WARNING:__main__:Invalid SMILES at index 93: =C)CCC1C)(CCCC21=1
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: oCC#N2(CN=11C
# [03:39:03] SMILES Parse Error: check for mistakes around position 7:
# [03:39:03] oCC#N2(CN=11C
# [03:39:03] ~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'oCC#N2(CN=11C' for input: 'oCC#N2(CN=11C'
# WARNING:__main__:Invalid SMILES at index 95: oCC#N2(CN=11C
# [03:39:03] SMILES Parse Error: syntax error while parsing: +]O]CO)C+O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] +]O]CO)C+O
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '+]O]CO)C+O' for input: '+]O]CO)C+O'
# WARNING:__main__:Invalid SMILES at index 96: +]O]CO)C+O
# [03:39:03] SMILES Parse Error: syntax error while parsing: 4F5H-
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 4F5H-
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '4F5H-' for input: '4F5H-'
# WARNING:__main__:Invalid SMILES at index 97: 4F5H-
# [03:39:03] SMILES Parse Error: syntax error while parsing: #CC(OC)CC)((C1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] #CC(OC)CC)((C1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '#CC(OC)CC)((C1' for input: '#CC(OC)CC)((C1'
# WARNING:__main__:Invalid SMILES at index 98: #CC(OC)CC)((C1
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: C11C1C)(N=32C)#
# [03:39:03] SMILES Parse Error: check for mistakes around position 7:
# [03:39:03] C11C1C)(N=32C)#
# [03:39:03] ~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'C11C1C)(N=32C)#' for input: 'C11C1C)(N=32C)#'
# WARNING:__main__:Invalid SMILES at index 99: C11C1C)(N=32C)#
# [03:39:03] SMILES Parse Error: syntax error while parsing: 5CC1O==CN
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 5CC1O==CN
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '5CC1O==CN' for input: '5CC1O==CN'
# WARNING:__main__:Invalid SMILES at index 100: 5CC1O==CN
# [03:39:03] SMILES Parse Error: syntax error while parsing: 3C1CCCCCC(2
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 3C1CCCCCC(2
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '3C1CCCCCC(2' for input: '3C1CCCCCC(2'
# WARNING:__main__:Invalid SMILES at index 101: 3C1CCCCCC(2
# [03:39:03] SMILES Parse Error: ring closure 2 duplicates bond between atom 3 and atom 4 for input: 'CCCC2F2CNO'
# WARNING:__main__:Invalid SMILES at index 102: CCCC2F2CNO
# [03:39:03] SMILES Parse Error: syntax error while parsing: C#1=(C1CCC#1
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] C#1=(C1CCC#1
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'C#1=(C1CCC#1' for input: 'C#1=(C1CCC#1'
# WARNING:__main__:Invalid SMILES at index 103: C#1=(C1CCC#1
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CCCCOC)1CCCCC#2
# [03:39:03] SMILES Parse Error: check for mistakes around position 7:
# [03:39:03] CCCCOC)1CCCCC#2
# [03:39:03] ~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCCCOC)1CCCCC#2' for input: 'CCCCOC)1CCCCC#2'
# WARNING:__main__:Invalid SMILES at index 104: CCCCOC)1CCCCC#2
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: OC1CCCNCN#1)C1O
# [03:39:03] SMILES Parse Error: check for mistakes around position 12:
# [03:39:03] OC1CCCNCN#1)C1O
# [03:39:03] ~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'OC1CCCNCN#1)C1O' for input: 'OC1CCCNCN#1)C1O'
# WARNING:__main__:Invalid SMILES at index 105: OC1CCCNCN#1)C1O
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CC1C1(CC2C1)))
# [03:39:03] SMILES Parse Error: check for mistakes around position 13:
# [03:39:03] CC1C1(CC2C1)))
# [03:39:03] ~~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC1C1(CC2C1)))' for input: 'CC1C1(CC2C1)))'
# WARNING:__main__:Invalid SMILES at index 106: CC1C1(CC2C1)))
# [03:39:03] SMILES Parse Error: syntax error while parsing: =-4
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] =-4
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '=-4' for input: '=-4'
# WARNING:__main__:Invalid SMILES at index 107: =-4
# [03:39:03] SMILES Parse Error: syntax error while parsing: 5
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 5
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '5' for input: '5'
# WARNING:__main__:Invalid SMILES at index 108: 5
# [03:39:03] SMILES Parse Error: syntax error while parsing: 2OOCCCCC1#12
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 2OOCCCCC1#12
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '2OOCCCCC1#12' for input: '2OOCCCCC1#12'
# WARNING:__main__:Invalid SMILES at index 109: 2OOCCCCC1#12
# [03:39:03] SMILES Parse Error: syntax error while parsing: n5F2[-o]#+F+5o(<-+54
# [03:39:03] SMILES Parse Error: check for mistakes around position 6:
# [03:39:03] n5F2[-o]#+F+5o(<-+54
# [03:39:03] ~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'n5F2[-o]#+F+5o(<-+54' for input: 'n5F2[-o]#+F+5o(<-+54'
# WARNING:__main__:Invalid SMILES at index 110: n5F2[-o]#+F+5o(<-+54
# [03:39:03] SMILES Parse Error: syntax error while parsing: 2
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 2
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '2' for input: '2'
# WARNING:__main__:Invalid SMILES at index 111: 2
# [03:39:03] SMILES Parse Error: syntax error while parsing: [<CC1C=NCN2
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] [<CC1C=NCN2
# [03:39:03] ~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '[<CC1C=NCN2' for input: '[<CC1C=NCN2'
# WARNING:__main__:Invalid SMILES at index 112: [<CC1C=NCN2
# [03:39:03] SMILES Parse Error: syntax error while parsing: CNCCCCC==(CNOC2
# [03:39:03] SMILES Parse Error: check for mistakes around position 9:
# [03:39:03] CNCCCCC==(CNOC2
# [03:39:03] ~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CNCCCCC==(CNOC2' for input: 'CNCCCCC==(CNOC2'
# WARNING:__main__:Invalid SMILES at index 113: CNCCCCC==(CNOC2
# [03:39:03] SMILES Parse Error: syntax error while parsing: cCHnH((-o(+o-(n55(#on
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] cCHnH((-o(+o-(n55(#on
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'cCHnH((-o(+o-(n55(#on' for input: 'cCHnH((-o(+o-(n55(#on'
# WARNING:__main__:Invalid SMILES at index 114: cCHnH((-o(+o-(n55(#on
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'C=O1C2CO'
# WARNING:__main__:Invalid SMILES at index 115: C=O1C2CO
# [03:39:03] SMILES Parse Error: syntax error while parsing: +
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] +
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '+' for input: '+'
# WARNING:__main__:Invalid SMILES at index 116: +
# [03:39:03] SMILES Parse Error: syntax error while parsing: CCN==2
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CCN==2
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCN==2' for input: 'CCN==2'
# WARNING:__main__:Invalid SMILES at index 117: CCN==2
# [03:39:03] SMILES Parse Error: syntax error while parsing: 5FF1N3C
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 5FF1N3C
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '5FF1N3C' for input: '5FF1N3C'
# WARNING:__main__:Invalid SMILES at index 118: 5FF1N3C
# [03:39:03] SMILES Parse Error: syntax error while parsing: )H[n#O1
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] )H[n#O1
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES ')H[n#O1' for input: ')H[n#O1'
# WARNING:__main__:Invalid SMILES at index 119: )H[n#O1
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'O=C1C'
# WARNING:__main__:Invalid SMILES at index 120: O=C1C
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: CCC=22)C2C2=C)3
# [03:39:03] SMILES Parse Error: check for mistakes around position 7:
# [03:39:03] CCC=22)C2C2=C)3
# [03:39:03] ~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCC=22)C2C2=C)3' for input: 'CCC=22)C2C2=C)3'
# WARNING:__main__:Invalid SMILES at index 121: CCC=22)C2C2=C)3
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CO11(C1(CO112C
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CO11(C1(CO112C
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CO11(C1(CO112C
# [03:39:03] SMILES Parse Error: check for mistakes around position 8:
# [03:39:03] CO11(C1(CO112C
# [03:39:03] ~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CO11(C1(CO112C' for input: 'CO11(C1(CO112C'
# WARNING:__main__:Invalid SMILES at index 122: CO11(C1(CO112C
# [03:39:03] SMILES Parse Error: duplicated ring closure 2 bonds atom 8 to itself for input: 'CCC1NCCCCO22132'
# WARNING:__main__:Invalid SMILES at index 123: CCC1NCCCCO22132
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CCCC2CC(CCCC1C)O'
# WARNING:__main__:Invalid SMILES at index 124: CCCC2CC(CCCC1C)O
# [03:39:03] SMILES Parse Error: syntax error while parsing: OH=[+CO
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] OH=[+CO
# [03:39:03] ~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'OH=[+CO' for input: 'OH=[+CO'
# WARNING:__main__:Invalid SMILES at index 125: OH=[+CO
# [03:39:03] Explicit valence for atom # 2 O, 5, is greater than permitted
# WARNING:__main__:Invalid SMILES at index 126: CCO2=1OO=CC2CC1
# [03:39:03] SMILES Parse Error: syntax error while parsing: o3O+C1C1NN#
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] o3O+C1C1NN#
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'o3O+C1C1NN#' for input: 'o3O+C1C1NN#'
# WARNING:__main__:Invalid SMILES at index 127: o3O+C1C1NN#
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: CNCO(CC2NCC1C12
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CNCO(CC2NCC1C12
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CNCO(CC2NCC1C12' for input: 'CNCO(CC2NCC1C12'
# WARNING:__main__:Invalid SMILES at index 128: CNCO(CC2NCC1C12
# [03:39:03] SMILES Parse Error: syntax error while parsing: 4]3-
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 4]3-
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '4]3-' for input: '4]3-'
# WARNING:__main__:Invalid SMILES at index 129: 4]3-
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'OCCCCCCC1COCC'
# WARNING:__main__:Invalid SMILES at index 130: OCCCCCCC1COCC
# [03:39:03] SMILES Parse Error: syntax error while parsing: HN(C21C1C5C==C=O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] HN(C21C1C5C==C=O
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'HN(C21C1C5C==C=O' for input: 'HN(C21C1C5C==C=O'
# WARNING:__main__:Invalid SMILES at index 131: HN(C21C1C5C==C=O
# [03:39:03] SMILES Parse Error: syntax error while parsing: 1<C4O=12NOHO=
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 1<C4O=12NOHO=
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '1<C4O=12NOHO=' for input: '1<C4O=12NOHO='
# WARNING:__main__:Invalid SMILES at index 132: 1<C4O=12NOHO=
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC2((COCC1#)=C1N
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CC2((COCC1#)=C1N
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC2((COCC1#)=C1N' for input: 'CC2((COCC1#)=C1N'
# WARNING:__main__:Invalid SMILES at index 133: CC2((COCC1#)=C1N
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'ON]1N3)OC2C)=22' for input: 'ON]1N3)OC2C)=22'
# WARNING:__main__:Invalid SMILES at index 134: ON]1N3)OC2C)=22
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: O)2+N[]
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] O)2+N[]
# [03:39:03] ~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'O)2+N[]' for input: 'O)2+N[]'
# WARNING:__main__:Invalid SMILES at index 135: O)2+N[]
# [03:39:03] SMILES Parse Error: syntax error while parsing: NNN+CC()C1CCCC
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] NNN+CC()C1CCCC
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'NNN+CC()C1CCCC' for input: 'NNN+CC()C1CCCC'
# WARNING:__main__:Invalid SMILES at index 136: NNN+CC()C1CCCC
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'nFOF<(HH+F4[(+C(<C<<<+)+(+5<<<5' for input: 'nFOF<(HH+F4[(+C(<C<<<+)+(+5<<<5'
# WARNING:__main__:Invalid SMILES at index 137: nFOF<(HH+F4[(+C(<C<<<+)+(+5<<<5
# [03:39:03] SMILES Parse Error: syntax error while parsing: CCCC22CCC1(2OCCO
# [03:39:03] SMILES Parse Error: check for mistakes around position 12:
# [03:39:03] CCCC22CCC1(2OCCO
# [03:39:03] ~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCCC22CCC1(2OCCO' for input: 'CCCC22CCC1(2OCCO'
# WARNING:__main__:Invalid SMILES at index 138: CCCC22CCC1(2OCCO
# [03:39:03] SMILES Parse Error: syntax error while parsing: 2]HO#
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 2]HO#
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '2]HO#' for input: '2]HO#'
# WARNING:__main__:Invalid SMILES at index 139: 2]HO#
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC2(2CO=C1CC)31=
# [03:39:03] SMILES Parse Error: check for mistakes around position 5:
# [03:39:03] CC2(2CO=C1CC)31=
# [03:39:03] ~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC2(2CO=C1CC)31=' for input: 'CC2(2CO=C1CC)31='
# WARNING:__main__:Invalid SMILES at index 140: CC2(2CO=C1CC)31=
# [03:39:03] SMILES Parse Error: extra open parentheses while parsing: OCCCO1(CNC=CN
# [03:39:03] SMILES Parse Error: check for mistakes around position 7:
# [03:39:03] OCCCO1(CNC=CN
# [03:39:03] ~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'OCCCO1(CNC=CN' for input: 'OCCCO1(CNC=CN'
# WARNING:__main__:Invalid SMILES at index 141: OCCCO1(CNC=CN
# [03:39:03] SMILES Parse Error: syntax error while parsing: +N112OCC#1=
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] +N112OCC#1=
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '+N112OCC#1=' for input: '+N112OCC#1='
# WARNING:__main__:Invalid SMILES at index 142: +N112OCC#1=
# [03:39:03] SMILES Parse Error: syntax error while parsing: 4CCCCCC=C
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 4CCCCCC=C
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '4CCCCCC=C' for input: '4CCCCCC=C'
# WARNING:__main__:Invalid SMILES at index 143: 4CCCCCC=C
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CCCC2O21CCCC'
# WARNING:__main__:Invalid SMILES at index 144: CCCC2O21CCCC
# [03:39:03] SMILES Parse Error: syntax error while parsing: ]#C1-O1=
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] ]#C1-O1=
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES ']#C1-O1=' for input: ']#C1-O1='
# WARNING:__main__:Invalid SMILES at index 145: ]#C1-O1=
# [03:39:03] SMILES Parse Error: syntax error while parsing: CCCCCCOOO=1CCC12#
# [03:39:03] SMILES Parse Error: check for mistakes around position 17:
# [03:39:03] CCCCCCOOO=1CCC12#
# [03:39:03] ~~~~~~~~~~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CCCCCCOOO=1CCC12#' for input: 'CCCCCCOOO=1CCC12#'
# WARNING:__main__:Invalid SMILES at index 146: CCCCCCOOO=1CCC12#
# [03:39:03] SMILES Parse Error: syntax error while parsing: 1(COOC)2=1#=)
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 1(COOC)2=1#=)
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '1(COOC)2=1#=)' for input: '1(COOC)2=1#=)'
# WARNING:__main__:Invalid SMILES at index 147: 1(COOC)2=1#=)
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'F1-1FFO55o]+)<3=+c-nC4+<<<#3nc1<-<3=<<<<O<[c4+<]n-4)<(c<51<#5<c3<<<][<(#Coc5-+o-oH<+55)+[<<)C<(++]2c' for input: 'F1-1FFO55o]+)<3=+c-nC4+<<<#3nc1<-<3=<<<<O<[c4+<]n-4)<(c<51<#5<c3<<<][<(#Coc5-+o-oH<+55)+[<<)C<(++]2c'
# WARNING:__main__:Invalid SMILES at index 148: F1-1FFO55o]+)<3=+c-nC4+<<<#3nc1<-<3=<<<<O<[c4+<]n-4)<(c<51<#5<c3<<<][<(#Coc5-+o-oH<+55)+[<<)C<(++]2c
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CC1CCCOOC11C2O'
# WARNING:__main__:Invalid SMILES at index 149: CC1CCCOOC11C2O
# [03:39:03] SMILES Parse Error: unclosed ring for input: 'CCCC1CCCNCOC1CCC2'
# WARNING:__main__:Invalid SMILES at index 150: CCCC1CCCNCOC1CCC2
# [03:39:03] SMILES Parse Error: syntax error while parsing: 4N(C(CCCC)1O
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] 4N(C(CCCC)1O
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '4N(C(CCCC)1O' for input: '4N(C(CCCC)1O'
# WARNING:__main__:Invalid SMILES at index 151: 4N(C(CCCC)1O
# [03:39:03] SMILES Parse Error: syntax error while parsing: [OCC12OC(OCC2)1C
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] [OCC12OC(OCC2)1C
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES '[OCC12OC(OCC2)1C' for input: '[OCC12OC(OCC2)1C'
# WARNING:__main__:Invalid SMILES at index 152: [OCC12OC(OCC2)1C
# [03:39:03] SMILES Parse Error: syntax error while parsing: c((2#H
# [03:39:03] SMILES Parse Error: check for mistakes around position 3:
# [03:39:03] c((2#H
# [03:39:03] ~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'c((2#H' for input: 'c((2#H'
# WARNING:__main__:Invalid SMILES at index 153: c((2#H
# [03:39:03] SMILES Parse Error: syntax error while parsing: CC(12CCCCN)C222C
# [03:39:03] SMILES Parse Error: check for mistakes around position 4:
# [03:39:03] CC(12CCCCN)C222C
# [03:39:03] ~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'CC(12CCCCN)C222C' for input: 'CC(12CCCCN)C222C'
# WARNING:__main__:Invalid SMILES at index 155: CC(12CCCCN)C222C
# [03:39:03] SMILES Parse Error: syntax error while parsing: oo1CCC1+C122
# [03:39:03] SMILES Parse Error: check for mistakes around position 8:
# [03:39:03] oo1CCC1+C122
# [03:39:03] ~~~~~~~^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES 'oo1CCC1+C122' for input: 'oo1CCC1+C122'
# WARNING:__main__:Invalid SMILES at index 156: oo1CCC1+C122
# [03:39:03] SMILES Parse Error: syntax error while parsing: )##3OO#OOO
# [03:39:03] SMILES Parse Error: check for mistakes around position 1:
# [03:39:03] )##3OO#OOO
# [03:39:03] ^
# [03:39:03] SMILES Parse Error: Failed parsing SMILES ')##3OO#OOO' for input: ')##3OO#OOO'
# WARNING:__main__:Invalid SMILES at index 157: )##3OO#OOO
# [03:39:03] SMILES Parse Error: extra close parentheses while parsing: c)-
# [03:39:03] SMILES Parse Error: check for mistakes around position 2:
# [03:39:03] c)-
# [03:39:03] ~^
# ...
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '1C#1CCCCCC2' for input: '1C#1CCCCCC2'
# WARNING:__main__:Invalid SMILES at index 693: 1C#1CCCCCC2
# [03:39:04] SMILES Parse Error: syntax error while parsing: -+=53#OONOOOOCC1O
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] -+=53#OONOOOOCC1O
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '-+=53#OONOOOOCC1O' for input: '-+=53#OONOOOOCC1O'
# WARNING:__main__:Invalid SMILES at index 694: -+=53#OONOOOOCC1O
# [03:39:04] SMILES Parse Error: syntax error while parsing: ]53#c-]NCO311=C=1)O2ON
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] ]53#c-]NCO311=C=1)O2ON
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES ']53#c-]NCO311=C=1)O2ON' for input: ']53#c-]NCO311=C=1)O2ON'
# WARNING:__main__:Invalid SMILES at index 695: ]53#c-]NCO311=C=1)O2ON
# [03:39:04] SMILES Parse Error: syntax error while parsing: CCCOC==1))O12C1
# [03:39:04] SMILES Parse Error: check for mistakes around position 7:
# [03:39:04] CCCOC==1))O12C1
# [03:39:04] ~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CCCOC==1))O12C1' for input: 'CCCOC==1))O12C1'
# WARNING:__main__:Invalid SMILES at index 696: CCCOC==1))O12C1
# [03:39:04] SMILES Parse Error: unclosed ring for input: 'CC1=2CN1CNOCC12'
# WARNING:__main__:Invalid SMILES at index 697: CC1=2CN1CNOCC12
# [03:39:04] SMILES Parse Error: extra open parentheses while parsing: CC(COOC=1#NC
# [03:39:04] SMILES Parse Error: check for mistakes around position 3:
# [03:39:04] CC(COOC=1#NC
# [03:39:04] ~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC(COOC=1#NC' for input: 'CC(COOC=1#NC'
# WARNING:__main__:Invalid SMILES at index 698: CC(COOC=1#NC
# [03:39:04] SMILES Parse Error: syntax error while parsing: nNC[C4NOO2
# [03:39:04] SMILES Parse Error: check for mistakes around position 6:
# [03:39:04] nNC[C4NOO2
# [03:39:04] ~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'nNC[C4NOO2' for input: 'nNC[C4NOO2'
# WARNING:__main__:Invalid SMILES at index 699: nNC[C4NOO2
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: CC=2CO)=CC3CCC
# [03:39:04] SMILES Parse Error: check for mistakes around position 7:
# [03:39:04] CC=2CO)=CC3CCC
# [03:39:04] ~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC=2CO)=CC3CCC' for input: 'CC=2CO)=CC3CCC'
# WARNING:__main__:Invalid SMILES at index 700: CC=2CO)=CC3CCC
# [03:39:04] non-ring atom 0 marked aromatic
# WARNING:__main__:Invalid SMILES at index 701: ccn
# [03:39:04] SMILES Parse Error: syntax error while parsing: (NC(C(C#22CC
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] (NC(C(C#22CC
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '(NC(C(C#22CC' for input: '(NC(C(C#22CC'
# WARNING:__main__:Invalid SMILES at index 702: (NC(C(C#22CC
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: cF5-4)]]cCH#C
# [03:39:04] SMILES Parse Error: check for mistakes around position 6:
# [03:39:04] cF5-4)]]cCH#C
# [03:39:04] ~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'cF5-4)]]cCH#C' for input: 'cF5-4)]]cCH#C'
# WARNING:__main__:Invalid SMILES at index 703: cF5-4)]]cCH#C
# [03:39:04] SMILES Parse Error: syntax error while parsing: O==1CCCCCO))OCC=
# [03:39:04] SMILES Parse Error: check for mistakes around position 3:
# [03:39:04] O==1CCCCCO))OCC=
# [03:39:04] ~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'O==1CCCCCO))OCC=' for input: 'O==1CCCCCO))OCC='
# WARNING:__main__:Invalid SMILES at index 704: O==1CCCCCO))OCC=
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: cO#COC)O2OCCN=
# [03:39:04] SMILES Parse Error: check for mistakes around position 7:
# [03:39:04] cO#COC)O2OCCN=
# [03:39:04] ~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'cO#COC)O2OCCN=' for input: 'cO#COC)O2OCCN='
# WARNING:__main__:Invalid SMILES at index 705: cO#COC)O2OCCN=
# [03:39:04] SMILES Parse Error: syntax error while parsing: #3o1CCNCO#CNO#C
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] #3o1CCNCO#CNO#C
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '#3o1CCNCO#CNO#C' for input: '#3o1CCNCO#CNO#C'
# WARNING:__main__:Invalid SMILES at index 706: #3o1CCNCO#CNO#C
# [03:39:04] SMILES Parse Error: extra open parentheses while parsing: CCCCCC32(C11121
# [03:39:04] SMILES Parse Error: check for mistakes around position 9:
# [03:39:04] CCCCCC32(C11121
# [03:39:04] ~~~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CCCCCC32(C11121' for input: 'CCCCCC32(C11121'
# WARNING:__main__:Invalid SMILES at index 707: CCCCCC32(C11121
# [03:39:04] SMILES Parse Error: ring closure 1 duplicates bond between atom 0 and atom 1 for input: 'C1C1(O=CN(CO=3))'
# WARNING:__main__:Invalid SMILES at index 708: C1C1(O=CN(CO=3))
# [03:39:04] SMILES Parse Error: ring closure 1 duplicates bond between atom 10 and atom 11 for input: 'CC2CCCOCCCCC1C12N'
# WARNING:__main__:Invalid SMILES at index 709: CC2CCCOCCCCC1C12N
# [03:39:04] SMILES Parse Error: ring closure 1 duplicates bond between atom 1 and atom 2 for input: 'CC1C1CCO=CC2'
# WARNING:__main__:Invalid SMILES at index 710: CC1C1CCO=CC2
# [03:39:04] SMILES Parse Error: syntax error while parsing: [1C1)O)C)1)CCC1#
# [03:39:04] SMILES Parse Error: check for mistakes around position 4:
# [03:39:04] [1C1)O)C)1)CCC1#
# [03:39:04] ~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '[1C1)O)C)1)CCC1#' for input: '[1C1)O)C)1)CCC1#'
# WARNING:__main__:Invalid SMILES at index 711: [1C1)O)C)1)CCC1#
# [03:39:04] SMILES Parse Error: syntax error while parsing: -3HCC=C1##]
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] -3HCC=C1##]
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '-3HCC=C1##]' for input: '-3HCC=C1##]'
# WARNING:__main__:Invalid SMILES at index 712: -3HCC=C1##]
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: OCC)CCC((ON(
# [03:39:04] SMILES Parse Error: check for mistakes around position 4:
# [03:39:04] OCC)CCC((ON(
# [03:39:04] ~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'OCC)CCC((ON(' for input: 'OCC)CCC((ON('
# WARNING:__main__:Invalid SMILES at index 713: OCC)CCC((ON(
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: OCCCC2CC)#O1NCO1O
# [03:39:04] SMILES Parse Error: check for mistakes around position 9:
# [03:39:04] OCCCC2CC)#O1NCO1O
# [03:39:04] ~~~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'OCCCC2CC)#O1NCO1O' for input: 'OCCCC2CC)#O1NCO1O'
# WARNING:__main__:Invalid SMILES at index 714: OCCCC2CC)#O1NCO1O
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: CC1CCCOC1)C)=2N2C
# [03:39:04] SMILES Parse Error: check for mistakes around position 10:
# [03:39:04] CC1CCCOC1)C)=2N2C
# [03:39:04] ~~~~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC1CCCOC1)C)=2N2C' for input: 'CC1CCCOC1)C)=2N2C'
# WARNING:__main__:Invalid SMILES at index 715: CC1CCCOC1)C)=2N2C
# [03:39:04] SMILES Parse Error: syntax error while parsing: +1o+o
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] +1o+o
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '+1o+o' for input: '+1o+o'
# WARNING:__main__:Invalid SMILES at index 716: +1o+o
# [03:39:04] SMILES Parse Error: syntax error while parsing: H1#N25===oF
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] H1#N25===oF
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'H1#N25===oF' for input: 'H1#N25===oF'
# WARNING:__main__:Invalid SMILES at index 717: H1#N25===oF
# [03:39:04] SMILES Parse Error: syntax error while parsing: 2c5n[N]1Oc+555H[1c
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] 2c5n[N]1Oc+555H[1c
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '2c5n[N]1Oc+555H[1c' for input: '2c5n[N]1Oc+555H[1c'
# WARNING:__main__:Invalid SMILES at index 718: 2c5n[N]1Oc+555H[1c
# [03:39:04] SMILES Parse Error: syntax error while parsing: NH]
# [03:39:04] SMILES Parse Error: check for mistakes around position 2:
# [03:39:04] NH]
# [03:39:04] ~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'NH]' for input: 'NH]'
# WARNING:__main__:Invalid SMILES at index 719: NH]
# [03:39:04] SMILES Parse Error: syntax error while parsing: C(1)(CCOCCC1C))2C
# [03:39:04] SMILES Parse Error: check for mistakes around position 3:
# [03:39:04] C(1)(CCOCCC1C))2C
# [03:39:04] ~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'C(1)(CCOCCC1C))2C' for input: 'C(1)(CCOCCC1C))2C'
# WARNING:__main__:Invalid SMILES at index 720: C(1)(CCOCCC1C))2C
# [03:39:04] SMILES Parse Error: unclosed ring for input: 'CONOCCCNC1CO2=N'
# WARNING:__main__:Invalid SMILES at index 721: CONOCCCNC1CO2=N
# [03:39:04] SMILES Parse Error: unclosed ring for input: 'on3O2O21'
# WARNING:__main__:Invalid SMILES at index 722: on3O2O21
# [03:39:04] SMILES Parse Error: syntax error while parsing: N2#
# [03:39:04] SMILES Parse Error: check for mistakes around position 3:
# [03:39:04] N2#
# [03:39:04] ~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'N2#' for input: 'N2#'
# WARNING:__main__:Invalid SMILES at index 723: N2#
# [03:39:04] SMILES Parse Error: syntax error while parsing: +C-12COON
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] +C-12COON
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '+C-12COON' for input: '+C-12COON'
# WARNING:__main__:Invalid SMILES at index 724: +C-12COON
# [03:39:04] SMILES Parse Error: syntax error while parsing: 4O=C11)CCC
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] 4O=C11)CCC
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '4O=C11)CCC' for input: '4O=C11)CCC'
# WARNING:__main__:Invalid SMILES at index 725: 4O=C11)CCC
# [03:39:04] SMILES Parse Error: extra open parentheses while parsing: OOCC(CCCC12
# [03:39:04] SMILES Parse Error: check for mistakes around position 5:
# [03:39:04] OOCC(CCCC12
# [03:39:04] ~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'OOCC(CCCC12' for input: 'OOCC(CCCC12'
# WARNING:__main__:Invalid SMILES at index 726: OOCC(CCCC12
# [03:39:04] SMILES Parse Error: syntax error while parsing: CCCCC2OCC(1
# [03:39:04] SMILES Parse Error: check for mistakes around position 11:
# [03:39:04] CCCCC2OCC(1
# [03:39:04] ~~~~~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CCCCC2OCC(1' for input: 'CCCCC2OCC(1'
# WARNING:__main__:Invalid SMILES at index 727: CCCCC2OCC(1
# [03:39:04] SMILES Parse Error: syntax error while parsing: n[4#FnO]+N[5[O)4HFnn5-cH+o3+o4o4cc++-]nc]nH[oHn-[n5OHo[nFo(-cn]+)F5-5[Hcn-5#C(-c]cH--n#4[c+)F+5co+[)
# [03:39:04] SMILES Parse Error: check for mistakes around position 5:
# [03:39:04] n[4#FnO]+N[5[O)4HFnn5-cH+o3+o4o4cc++-]nc]
# [03:39:04] ~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'n[4#FnO]+N[5[O)4HFnn5-cH+o3+o4o4cc++-]nc]nH[oHn-[n5OHo[nFo(-cn]+)F5-5[Hcn-5#C(-c]cH--n#4[c+)F+5co+[)' for input: 'n[4#FnO]+N[5[O)4HFnn5-cH+o3+o4o4cc++-]nc]nH[oHn-[n5OHo[nFo(-cn]+)F5-5[Hcn-5#C(-c]cH--n#4[c+)F+5co+[)'
# WARNING:__main__:Invalid SMILES at index 728: n[4#FnO]+N[5[O)4HFnn5-cH+o3+o4o4cc++-]nc]nH[oHn-[n5OHo[nFo(-cn]+)F5-5[Hcn-5#C(-c]cH--n#4[c+)F+5co+[)
# [03:39:04] Explicit valence for atom # 5 C, 6, is greater than permitted
# WARNING:__main__:Invalid SMILES at index 729: NC1CCCC11CCCCN#1
# [03:39:04] SMILES Parse Error: extra open parentheses while parsing: CC1C(CCCCCCOOOC
# [03:39:04] SMILES Parse Error: check for mistakes around position 5:
# [03:39:04] CC1C(CCCCCCOOOC
# [03:39:04] ~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC1C(CCCCCCOOOC' for input: 'CC1C(CCCCCCOOOC'
# WARNING:__main__:Invalid SMILES at index 730: CC1C(CCCCCCOOOC
# [03:39:04] SMILES Parse Error: unclosed ring for input: 'CC=22CCCCC12C3ON'
# WARNING:__main__:Invalid SMILES at index 731: CC=22CCCCC12C3ON
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: CC1C2NO)CCC2==42
# [03:39:04] SMILES Parse Error: check for mistakes around position 8:
# [03:39:04] CC1C2NO)CCC2==42
# [03:39:04] ~~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC1C2NO)CCC2==42' for input: 'CC1C2NO)CCC2==42'
# WARNING:__main__:Invalid SMILES at index 732: CC1C2NO)CCC2==42
# [03:39:04] SMILES Parse Error: syntax error while parsing: O#=
# [03:39:04] SMILES Parse Error: check for mistakes around position 3:
# [03:39:04] O#=
# [03:39:04] ~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'O#=' for input: 'O#='
# WARNING:__main__:Invalid SMILES at index 733: O#=
# [03:39:04] SMILES Parse Error: extra close parentheses while parsing: CC1CCCCC4)CC)
# [03:39:04] SMILES Parse Error: check for mistakes around position 10:
# [03:39:04] CC1CCCCC4)CC)
# [03:39:04] ~~~~~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC1CCCCC4)CC)' for input: 'CC1CCCCC4)CC)'
# WARNING:__main__:Invalid SMILES at index 734: CC1CCCCC4)CC)
# [03:39:04] SMILES Parse Error: syntax error while parsing: NCC[()2O2O2C1
# [03:39:04] SMILES Parse Error: check for mistakes around position 5:
# [03:39:04] NCC[()2O2O2C1
# [03:39:04] ~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'NCC[()2O2O2C1' for input: 'NCC[()2O2O2C1'
# WARNING:__main__:Invalid SMILES at index 735: NCC[()2O2O2C1
# [03:39:04] SMILES Parse Error: syntax error while parsing: C[F1N
# [03:39:04] SMILES Parse Error: check for mistakes around position 4:
# [03:39:04] C[F1N
# [03:39:04] ~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'C[F1N' for input: 'C[F1N'
# WARNING:__main__:Invalid SMILES at index 736: C[F1N
# [03:39:04] SMILES Parse Error: syntax error while parsing: 1OC1C1212OC))C
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] 1OC1C1212OC))C
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES '1OC1C1212OC))C' for input: '1OC1C1212OC))C'
# WARNING:__main__:Invalid SMILES at index 737: 1OC1C1212OC))C
# [03:39:04] SMILES Parse Error: syntax error while parsing: nFCH+#N3n2+c5cc5n3[[n<(-)[o(c1N#1CN
# [03:39:04] SMILES Parse Error: check for mistakes around position 4:
# [03:39:04] nFCH+#N3n2+c5cc5n3[[n<(-)[o(c1N#1CN
# [03:39:04] ~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'nFCH+#N3n2+c5cc5n3[[n<(-)[o(c1N#1CN' for input: 'nFCH+#N3n2+c5cc5n3[[n<(-)[o(c1N#1CN'
# WARNING:__main__:Invalid SMILES at index 738: nFCH+#N3n2+c5cc5n3[[n<(-)[o(c1N#1CN
# [03:39:04] SMILES Parse Error: syntax error while parsing: CC(OC(OCC(=3N
# [03:39:04] SMILES Parse Error: check for mistakes around position 12:
# [03:39:04] CC(OC(OCC(=3N
# [03:39:04] ~~~~~~~~~~~^
# [03:39:04] SMILES Parse Error: extra open parentheses while parsing: CC(OC(OCC(=3N
# [03:39:04] SMILES Parse Error: check for mistakes around position 3:
# [03:39:04] CC(OC(OCC(=3N
# [03:39:04] ~~^
# [03:39:04] SMILES Parse Error: extra open parentheses while parsing: CC(OC(OCC(=3N
# [03:39:04] SMILES Parse Error: check for mistakes around position 6:
# [03:39:04] CC(OC(OCC(=3N
# [03:39:04] ~~~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC(OC(OCC(=3N' for input: 'CC(OC(OCC(=3N'
# WARNING:__main__:Invalid SMILES at index 739: CC(OC(OCC(=3N
# [03:39:04] SMILES Parse Error: syntax error while parsing: CC()1C(C(CCCC(CC
# [03:39:04] SMILES Parse Error: check for mistakes around position 4:
# [03:39:04] CC()1C(C(CCCC(CC
# [03:39:04] ~~~^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'CC()1C(C(CCCC(CC' for input: 'CC()1C(C(CCCC(CC'
# WARNING:__main__:Invalid SMILES at index 740: CC()1C(C(CCCC(CC
# [03:39:04] SMILES Parse Error: syntax error while parsing: HCnNon3o2<o[+<5<<<<<<cOCC11(CC==C)2=121C
# [03:39:04] SMILES Parse Error: check for mistakes around position 1:
# [03:39:04] HCnNon3o2<o[+<5<<<<<<cOCC11(CC==C)2=121C
# [03:39:04] ^
# [03:39:04] SMILES Parse Error: Failed parsing SMILES 'HCnNon3o2<o[+<5<<<<<<cOCC11(CC==C)2=121C' for input: 'HCnNon3o2<o[+<5<<<<<<cOCC11(CC==C)2=121C'
# WARNING:__main__:Invalid SMILES at index 741: HCnNon3o2<o[+<5<<<<<<cOCC11(CC==C)2=121C
# 738 molecules not drawn due to invalidity. Drawing 5 molecules...
# Visualization of generated molecules successful. Image saved as: generated_molecules.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x400>

# %% [markdown]
# 7.5 Insights and Discussion: After performing these analyses, we can discuss the results:
#
# * Validity Rate: A high validity rate indicates that our model has learned to
#  generate syntactically correct SMILES strings. However, if it's too high (close to 100%), it might suggest that the model is playing it safe and not exploring the chemical space enough.
# * Novelty Rate: A high novelty rate suggests that our model is not just memorizing the training set but generating new structures. This is crucial for drug discovery applications.
# * Property Distribution: By analyzing the distribution of molecular properties (like molecular weight, LogP, etc.), we can see if our generated molecules are similar to the training set or if they're exploring new areas of chemical space.
# * Visual Inspection: Visualizing the molecules allows for a qualitative assessment of the types of structures being generated. This can help identify any patterns or biases in the generation process.
# * Comparison to Training Set: We can compare the properties of generated molecules to those in the training set to see how well our model has captured the distribution of the original data.
#
# These analyses provide insights into the performance of our VAE model and the characteristics of the generated molecules. They can guide further refinement of the model or selection of promising candidates for more detailed investigation in a drug discovery pipeline.

# %% [markdown]
# ## Conclusion
# This tutorial demonstrates how to use a VAE for molecular generation, combining deep learning techniques with chemical knowledge to create a tool for drug discovery. By understanding and modifying this code, biomedical researchers can adapt it to their specific research needs, potentially accelerating the drug discovery process.
